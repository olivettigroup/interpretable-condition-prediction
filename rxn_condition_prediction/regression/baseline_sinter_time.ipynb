# %%
import json
import re
from pymatgen.core import Composition, Element
import pprint as pp
import copy
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pickle as pkl
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from sklearn.utils import shuffle
from sklearn.model_selection import KFold
import sys, os
sys.path.append('/home/jupyter/CJK/TempTime')
from data_extraction_rxn_classification_all_targets import *
from sklearn.dummy import DummyRegressor

# %%
all_elements = [Element.from_Z(i).symbol for i in range(1, 119)]

# %%
with open('/home/jupyter/CJK/TempTime/data/solid-state_dataset_20200713.json') as f:
    ss_data= json.load(f)
ss_reactions = ss_data["reactions"]
ss_extracted, ss_precursor_nomenclature = extract_solidstate(ss_reactions, max_pre=5)
# Out:
# Returning extracted data of 51574/31782 reactions.

# %%
with open('/home/jupyter/CJK/TempTime/data/ss_extracted_NO_IMPUTATION_precs_all_targets.pkl', 'rb') as f:
    papers = pkl.load(f)

# %%
papers = [x for x in papers if not np.isnan(x['temp_time_vector'][5])]

# %%
papers
# Out:
# [{'DOI': '10.1149/1.1828243',
#   'target': 'NdCoO3',
#   'precursors': ['Co3O4', 'Nd2O3'],
#   'operation_types': ['StartingSynthesis',
#    'HeatingOperation',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'DryingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['synthesized',
#    'fired',
#    'reground',
#    'pressed',
#    'sintered',
#    'regrinding',
#    'dissolved',
#    'dried',
#    'fired',
#    'ground',
#    'pressed',
#    'sintered'],
#   'operation_times': [None,
#    12,
#    None,
#    None,
#    24,
#    None,
#    None,
#    None,
#    5,
#    None,
#    None,
#    24],
#   'operation_temps': [None,
#    900.0,
#    None,
#    None,
#    1200.0,
#    None,
#    None,
#    None,
#    500.0,
#    None,
#    None,
#    1200.0],
#   'temp_time_vector': array([  nan, 1200.,   nan,   nan,   nan,   24.,   nan,   nan])},
#  {'DOI': '10.1149/1.1828243',
#   'target': 'Sr0.5Nd0.5CoO3',
#   'precursors': ['Co3O4', 'Nd2O3', 'SrCO3'],
#   'operation_types': ['StartingSynthesis',
#    'HeatingOperation',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'DryingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['synthesized',
#    'fired',
#    'reground',
#    'pressed',
#    'sintered',
#    'regrinding',
#    'dissolved',
#    'dried',
#    'fired',
#    'ground',
#    'pressed',
#    'sintered'],
#   'operation_times': [None,
#    12,
#    None,
#    None,
#    24,
#    None,
#    None,
#    None,
#    5,
#    None,
#    None,
#    24],
#   'operation_temps': [None,
#    900.0,
#    None,
#    None,
#    1200.0,
#    None,
#    None,
#    None,
#    500.0,
#    None,
#    None,
#    1200.0],
#   'temp_time_vector': array([  nan, 1200.,   nan,   nan,   nan,   24.,   nan,   nan])},
#  {'DOI': '10.1149/1.2103727',
#   'target': 'Sr0.4Pr0.6CoO3',
#   'precursors': ['Co2O3', 'Pr6O11', 'SrCO3'],
#   'operation_types': ['StartingSynthesis',
#    'StartingSynthesis',
#    'MixingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['prepared',
#    'synthesized',
#    'crushed',
#    'ballmilled',
#    'adding',
#    'sintered'],
#   'operation_times': [None, None, None, None, None, 5],
#   'operation_temps': [None, None, None, None, None, 1050.0],
#   'temp_time_vector': array([  nan, 1050.,   nan,   nan,   nan,    5.,   nan,   nan])},
#  {'DOI': '10.1149/1.2103727',
#   'target': 'Sr0.4Gd0.6CoO3',
#   'precursors': ['Co2O3', 'Gd2O3', 'SrCO3'],
#   'operation_types': ['StartingSynthesis',
#    'StartingSynthesis',
#    'MixingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['prepared',
#    'synthesized',
#    'crushed',
#    'ballmilled',
#    'adding',
#    'sintered'],
#   'operation_times': [None, None, None, None, None, 5],
#   'operation_temps': [None, None, None, None, None, 1050.0],
#   'temp_time_vector': array([  nan, 1050.,   nan,   nan,   nan,    5.,   nan,   nan])},
#  {'DOI': '10.1039/c2cp44394e',
#   'target': 'Li1.3Mn0.65Ni0.35O2.3',
#   'precursors': ['LiHO', 'MnO2', 'Ni(NO3)2'],
#   'operation_types': ['StartingSynthesis',
#    'MixingOperation',
#    'DryingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'StartingSynthesis',
#    'MixingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'DryingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'DryingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'DryingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['prepared',
#    'dispersed',
#    'evaporated',
#    'stirring',
#    'ground',
#    'heated',
#    'prepared',
#    'dissolved',
#    'adding',
#    'stirring',
#    'dried',
#    'stirring',
#    'treated',
#    'ground',
#    'dried',
#    'sintered',
#    'milled',
#    'dried',
#    'annealed'],
#   'operation_times': [None,
#    None,
#    None,
#    None,
#    None,
#    10,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    10,
#    None,
#    None,
#    10,
#    10,
#    None,
#    24],
#   'operation_temps': [None,
#    None,
#    50.0,
#    None,
#    None,
#    800.0,
#    None,
#    None,
#    None,
#    None,
#    120.0,
#    None,
#    400.0,
#    None,
#    80.0,
#    800.0,
#    None,
#    None,
#    800.0],
#   'temp_time_vector': array([ nan, 800., 800.,  80.,  nan,  10.,  24.,  nan])},
#  {'DOI': '10.1039/c5cp06742a',
#   'target': 'Sr0.19La0.76MnO3',
#   'precursors': ['La2O3', 'MnO2', 'SrCO3'],
#   'operation_types': ['StartingSynthesis',
#    'StartingSynthesis',
#    'MixingOperation',
#    'StartingSynthesis',
#    'MixingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['synthesized',
#    'synthesized',
#    'mixing',
#    'prepared',
#    'mixed',
#    'sintered'],
#   'operation_times': [None, None, 10, None, None, 3],
#   'operation_temps': [None, None, 1100.0, None, None, 800.0],
#   'temp_time_vector': array([ nan, 800.,  nan,  nan,  nan,   3.,  nan,  nan])},
#  {'DOI': '10.1021/nn405246h',
#   'target': 'Ca2.86Mg0.14P2O8',
#   'precursors': ['Ca(HO)2', 'Mg(HO)2', 'PH3O4'],
#   'operation_types': ['StartingSynthesis',
#    'MixingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'ShapingOperation',
#    'DryingOperation',
#    'StartingSynthesis',
#    'StartingSynthesis',
#    'MixingOperation',
#    'MixingOperation',
#    'ShapingOperation',
#    'DryingOperation',
#    'StartingSynthesis',
#    'StartingSynthesis',
#    'MixingOperation',
#    'MixingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['synthesized',
#    'mixed',
#    'added',
#    'stirring',
#    'pressed',
#    'dried',
#    'synthesized',
#    'prepared',
#    'added',
#    'stirring',
#    'pressed',
#    'dried',
#    'synthesized',
#    'prepared',
#    'mixed',
#    'milled',
#    'sintered'],
#   'operation_times': [None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    48,
#    2],
#   'operation_temps': [None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    1100.0],
#   'temp_time_vector': array([  nan, 1100.,   nan,   nan,   nan,    2.,   nan,   nan])},
#  {'DOI': '10.1021/cm800892z',
#   'target': 'Sr0.8La1.2CuO4',
#   'precursors': ['CuO', 'La2O3', 'SrCO3'],
#   'operation_types': ['StartingSynthesis',
#    'StartingSynthesis',
#    'MixingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'StartingSynthesis',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['synthesized',
#    'prepared',
#    'mixed',
#    'calcined',
#    'sintered',
#    'annealed',
#    'prepared',
#    'mixed',
#    'pressed',
#    'fired',
#    'postannealed',
#    'annealed'],
#   'operation_times': [None,
#    None,
#    None,
#    12,
#    20,
#    48,
#    None,
#    None,
#    None,
#    12,
#    24,
#    None],
#   'operation_temps': [None,
#    None,
#    None,
#    950.0,
#    1100.0,
#    500.0,
#    None,
#    None,
#    None,
#    1050.0,
#    1000.0,
#    None],
#   'temp_time_vector': array([ 950., 1100.,  500.,   nan,   12.,   20.,   48.,   nan])},
#  {'DOI': '10.1021/cm800892z',
#   'target': 'Sr2CuO4',
#   'precursors': ['CuO', 'SrCO3'],
#   'operation_types': ['StartingSynthesis',
#    'StartingSynthesis',
#    'MixingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'StartingSynthesis',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['synthesized',
#    'prepared',
#    'mixed',
#    'calcined',
#    'sintered',
#    'annealed',
#    'prepared',
#    'mixed',
#    'pressed',
#    'fired',
#    'postannealed',
#    'annealed'],
#   'operation_times': [None,
#    None,
#    None,
#    12,
#    20,
#    48,
#    None,
#    None,
#    None,
#    12,
#    24,
#    None],
#   'operation_temps': [None,
#    None,
#    None,
#    950.0,
#    1100.0,
#    500.0,
#    None,
#    None,
#    None,
#    1050.0,
#    1000.0,
#    None],
#   'temp_time_vector': array([ 950., 1100.,  500.,   nan,   12.,   20.,   48.,   nan])},
#  {'DOI': '10.1021/cm800892z',
#   'target': 'Sr1.2La0.8CuO4',
#   'precursors': ['CuO', 'La2O3', 'SrCO3'],
#   'operation_types': ['StartingSynthesis',
#    'StartingSynthesis',
#    'MixingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'StartingSynthesis',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['synthesized',
#    'prepared',
#    'mixed',
#    'calcined',
#    'sintered',
#    'annealed',
#    'prepared',
#    'mixed',
#    'pressed',
#    'fired',
#    'postannealed',
#    'annealed'],
#   'operation_times': [None,
#    None,
#    None,
#    12,
#    20,
#    48,
#    None,
#    None,
#    None,
#    12,
#    24,
#    None],
#   'operation_temps': [None,
#    None,
#    None,
#    950.0,
#    1100.0,
#    500.0,
#    None,
#    None,
#    None,
#    1050.0,
#    1000.0,
#    None],
#   'temp_time_vector': array([ 950., 1100.,  500.,   nan,   12.,   20.,   48.,   nan])},
#  {'DOI': '10.1021/cm800892z',
#   'target': 'Sr1.6La0.4CuO4',
#   'precursors': ['CuO', 'La2O3', 'SrCO3'],
#   'operation_types': ['StartingSynthesis',
#    'StartingSynthesis',
#    'MixingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'StartingSynthesis',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['synthesized',
#    'prepared',
#    'mixed',
#    'calcined',
#    'sintered',
#    'annealed',
#    'prepared',
#    'mixed',
#    'pressed',
#    'fired',
#    'postannealed',
#    'annealed'],
#   'operation_times': [None,
#    None,
#    None,
#    12,
#    20,
#    48,
#    None,
#    None,
#    None,
#    12,
#    24,
#    None],
#   'operation_temps': [None,
#    None,
#    None,
#    950.0,
#    1100.0,
#    500.0,
#    None,
#    None,
#    None,
#    1050.0,
#    1000.0,
#    None],
#   'temp_time_vector': array([ 950., 1100.,  500.,   nan,   12.,   20.,   48.,   nan])},
#  {'DOI': '10.1021/cm800892z',
#   'target': 'La2CuO4',
#   'precursors': ['CuO', 'La2O3'],
#   'operation_types': ['StartingSynthesis',
#    'StartingSynthesis',
#    'MixingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'StartingSynthesis',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['synthesized',
#    'prepared',
#    'mixed',
#    'calcined',
#    'sintered',
#    'annealed',
#    'prepared',
#    'mixed',
#    'pressed',
#    'fired',
#    'postannealed',
#    'annealed'],
#   'operation_times': [None,
#    None,
#    None,
#    12,
#    20,
#    48,
#    None,
#    None,
#    None,
#    12,
#    24,
#    None],
#   'operation_temps': [None,
#    None,
#    None,
#    950.0,
#    1100.0,
#    500.0,
#    None,
#    None,
#    None,
#    1050.0,
#    1000.0,
#    None],
#   'temp_time_vector': array([ 950., 1100.,  500.,   nan,   12.,   20.,   48.,   nan])},
#  {'DOI': '10.1021/cm800892z',
#   'target': 'Sr0.4La1.6CuO4',
#   'precursors': ['CuO', 'La2O3', 'SrCO3'],
#   'operation_types': ['StartingSynthesis',
#    'StartingSynthesis',
#    'MixingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'StartingSynthesis',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['synthesized',
#    'prepared',
#    'mixed',
#    'calcined',
#    'sintered',
#    'annealed',
#    'prepared',
#    'mixed',
#    'pressed',
#    'fired',
#    'postannealed',
#    'annealed'],
#   'operation_times': [None,
#    None,
#    None,
#    12,
#    20,
#    48,
#    None,
#    None,
#    None,
#    12,
#    24,
#    None],
#   'operation_temps': [None,
#    None,
#    None,
#    950.0,
#    1100.0,
#    500.0,
#    None,
#    None,
#    None,
#    1050.0,
#    1000.0,
#    None],
#   'temp_time_vector': array([ 950., 1100.,  500.,   nan,   12.,   20.,   48.,   nan])},
#  {'DOI': '10.1021/cm800892z',
#   'target': 'Nd0.8Ce1.2CuO4',
#   'precursors': ['Ce(NO3)3', 'CuO', 'Nd2O3'],
#   'operation_types': ['StartingSynthesis',
#    'StartingSynthesis',
#    'MixingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'StartingSynthesis',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['synthesized',
#    'prepared',
#    'mixed',
#    'calcined',
#    'sintered',
#    'annealed',
#    'prepared',
#    'mixed',
#    'pressed',
#    'fired',
#    'postannealed',
#    'annealed'],
#   'operation_times': [None,
#    None,
#    None,
#    12,
#    20,
#    48,
#    None,
#    None,
#    None,
#    12,
#    24,
#    None],
#   'operation_temps': [None,
#    None,
#    None,
#    950.0,
#    1100.0,
#    500.0,
#    None,
#    None,
#    None,
#    1050.0,
#    1000.0,
#    None],
#   'temp_time_vector': array([ 950., 1100.,  500.,   nan,   12.,   20.,   48.,   nan])},
#  {'DOI': '10.1021/cm800892z',
#   'target': 'Nd1.6Ce0.4CuO4',
#   'precursors': ['Ce(NO3)3', 'CuO', 'Nd2O3'],
#   'operation_types': ['StartingSynthesis',
#    'StartingSynthesis',
#    'MixingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'StartingSynthesis',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['synthesized',
#    'prepared',
#    'mixed',
#    'calcined',
#    'sintered',
#    'annealed',
#    'prepared',
#    'mixed',
#    'pressed',
#    'fired',
#    'postannealed',
#    'annealed'],
#   'operation_times': [None,
#    None,
#    None,
#    12,
#    20,
#    48,
#    None,
#    None,
#    None,
#    12,
#    24,
#    None],
#   'operation_temps': [None,
#    None,
#    None,
#    950.0,
#    1100.0,
#    500.0,
#    None,
#    None,
#    None,
#    1050.0,
#    1000.0,
#    None],
#   'temp_time_vector': array([ 950., 1100.,  500.,   nan,   12.,   20.,   48.,   nan])},
#  {'DOI': '10.1021/cm800892z',
#   'target': 'Nd2CuO4',
#   'precursors': ['CuO', 'Nd2O3'],
#   'operation_types': ['StartingSynthesis',
#    'StartingSynthesis',
#    'MixingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'StartingSynthesis',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['synthesized',
#    'prepared',
#    'mixed',
#    'calcined',
#    'sintered',
#    'annealed',
#    'prepared',
#    'mixed',
#    'pressed',
#    'fired',
#    'postannealed',
#    'annealed'],
#   'operation_times': [None,
#    None,
#    None,
#    12,
#    20,
#    48,
#    None,
#    None,
#    None,
#    12,
#    24,
#    None],
#   'operation_temps': [None,
#    None,
#    None,
#    950.0,
#    1100.0,
#    500.0,
#    None,
#    None,
#    None,
#    1050.0,
#    1000.0,
#    None],
#   'temp_time_vector': array([ 950., 1100.,  500.,   nan,   12.,   20.,   48.,   nan])},
#  {'DOI': '10.1021/cm800892z',
#   'target': 'Nd1.2Ce0.8CuO4',
#   'precursors': ['Ce(NO3)3', 'CuO', 'Nd2O3'],
#   'operation_types': ['StartingSynthesis',
#    'StartingSynthesis',
#    'MixingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'StartingSynthesis',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['synthesized',
#    'prepared',
#    'mixed',
#    'calcined',
#    'sintered',
#    'annealed',
#    'prepared',
#    'mixed',
#    'pressed',
#    'fired',
#    'postannealed',
#    'annealed'],
#   'operation_times': [None,
#    None,
#    None,
#    12,
#    20,
#    48,
#    None,
#    None,
#    None,
#    12,
#    24,
#    None],
#   'operation_temps': [None,
#    None,
#    None,
#    950.0,
#    1100.0,
#    500.0,
#    None,
#    None,
#    None,
#    1050.0,
#    1000.0,
#    None],
#   'temp_time_vector': array([ 950., 1100.,  500.,   nan,   12.,   20.,   48.,   nan])},
#  {'DOI': '10.1021/cm800892z',
#   'target': 'Ce2CuO4',
#   'precursors': ['Ce(NO3)3', 'CuO'],
#   'operation_types': ['StartingSynthesis',
#    'StartingSynthesis',
#    'MixingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'StartingSynthesis',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['synthesized',
#    'prepared',
#    'mixed',
#    'calcined',
#    'sintered',
#    'annealed',
#    'prepared',
#    'mixed',
#    'pressed',
#    'fired',
#    'postannealed',
#    'annealed'],
#   'operation_times': [None,
#    None,
#    None,
#    12,
#    20,
#    48,
#    None,
#    None,
#    None,
#    12,
#    24,
#    None],
#   'operation_temps': [None,
#    None,
#    None,
#    950.0,
#    1100.0,
#    500.0,
#    None,
#    None,
#    None,
#    1050.0,
#    1000.0,
#    None],
#   'temp_time_vector': array([ 950., 1100.,  500.,   nan,   12.,   20.,   48.,   nan])},
#  {'DOI': '10.1021/cm800892z',
#   'target': 'Nd0.4Ce1.6CuO4',
#   'precursors': ['Ce(NO3)3', 'CuO', 'Nd2O3'],
#   'operation_types': ['StartingSynthesis',
#    'StartingSynthesis',
#    'MixingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'StartingSynthesis',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['synthesized',
#    'prepared',
#    'mixed',
#    'calcined',
#    'sintered',
#    'annealed',
#    'prepared',
#    'mixed',
#    'pressed',
#    'fired',
#    'postannealed',
#    'annealed'],
#   'operation_times': [None,
#    None,
#    None,
#    12,
#    20,
#    48,
#    None,
#    None,
#    None,
#    12,
#    24,
#    None],
#   'operation_temps': [None,
#    None,
#    None,
#    950.0,
#    1100.0,
#    500.0,
#    None,
#    None,
#    None,
#    1050.0,
#    1000.0,
#    None],
#   'temp_time_vector': array([ 950., 1100.,  500.,   nan,   12.,   20.,   48.,   nan])},
#  {'DOI': '10.1021/cm401394x',
#   'target': 'BaCa0.1Y0.9Co2O5.5',
#   'precursors': ['BaCO3', 'CaCO3', 'Co(NO3)2', 'Y2O3'],
#   'operation_types': ['StartingSynthesis',
#    'MixingOperation',
#    'DryingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'DryingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'ShapingOperation',
#    'HeatingOperation',
#    'QuenchingOperation'],
#   'operation_tokens': ['prepared',
#    'dissolved',
#    'dried',
#    'added',
#    'stirred',
#    'heated',
#    'added',
#    'held',
#    'stirring',
#    'dried',
#    'ground',
#    'calcined',
#    'pressed',
#    'sintered',
#    'cooled'],
#   'operation_times': [None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    50,
#    None,
#    3,
#    None,
#    25,
#    None],
#   'operation_temps': [None,
#    None,
#    None,
#    None,
#    None,
#    80.0,
#    None,
#    None,
#    None,
#    100.0,
#    None,
#    450.0,
#    None,
#    1000.0,
#    None],
#   'temp_time_vector': array([ 450., 1000.,   nan,  100.,    3.,   25.,   nan,   nan])},
#  {'DOI': '10.1021/cm401394x',
#   'target': 'Ca10Y',
#   'precursors': ['CaCO3', 'Y2O3'],
#   'operation_types': ['StartingSynthesis',
#    'MixingOperation',
#    'DryingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'DryingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'ShapingOperation',
#    'HeatingOperation',
#    'QuenchingOperation'],
#   'operation_tokens': ['prepared',
#    'dissolved',
#    'dried',
#    'added',
#    'stirred',
#    'heated',
#    'added',
#    'held',
#    'stirring',
#    'dried',
#    'ground',
#    'calcined',
#    'pressed',
#    'sintered',
#    'cooled'],
#   'operation_times': [None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    50,
#    None,
#    3,
#    None,
#    25,
#    None],
#   'operation_temps': [None,
#    None,
#    None,
#    None,
#    None,
#    80.0,
#    None,
#    None,
#    None,
#    100.0,
#    None,
#    450.0,
#    None,
#    1000.0,
#    None],
#   'temp_time_vector': array([ 450., 1000.,   nan,  100.,    3.,   25.,   nan,   nan])},
#  {'DOI': '10.1021/cm401394x',
#   'target': 'Ba0.9Ca0.1YCo2O5.5',
#   'precursors': ['BaCO3', 'CaCO3', 'Co(NO3)2', 'Y2O3'],
#   'operation_types': ['StartingSynthesis',
#    'MixingOperation',
#    'DryingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'DryingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'ShapingOperation',
#    'HeatingOperation',
#    'QuenchingOperation'],
#   'operation_tokens': ['prepared',
#    'dissolved',
#    'dried',
#    'added',
#    'stirred',
#    'heated',
#    'added',
#    'held',
#    'stirring',
#    'dried',
#    'ground',
#    'calcined',
#    'pressed',
#    'sintered',
#    'cooled'],
#   'operation_times': [None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    50,
#    None,
#    3,
#    None,
#    25,
#    None],
#   'operation_temps': [None,
#    None,
#    None,
#    None,
#    None,
#    80.0,
#    None,
#    None,
#    None,
#    100.0,
#    None,
#    450.0,
#    None,
#    1000.0,
#    None],
#   'temp_time_vector': array([ 450., 1000.,   nan,  100.,    3.,   25.,   nan,   nan])},
#  {'DOI': '10.1021/cm401394x',
#   'target': 'BaCa10',
#   'precursors': ['BaCO3', 'CaCO3'],
#   'operation_types': ['StartingSynthesis',
#    'MixingOperation',
#    'DryingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'DryingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'ShapingOperation',
#    'HeatingOperation',
#    'QuenchingOperation'],
#   'operation_tokens': ['prepared',
#    'dissolved',
#    'dried',
#    'added',
#    'stirred',
#    'heated',
#    'added',
#    'held',
#    'stirring',
#    'dried',
#    'ground',
#    'calcined',
#    'pressed',
#    'sintered',
#    'cooled'],
#   'operation_times': [None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    50,
#    None,
#    3,
#    None,
#    25,
#    None],
#   'operation_temps': [None,
#    None,
#    None,
#    None,
#    None,
#    80.0,
#    None,
#    None,
#    None,
#    100.0,
#    None,
#    450.0,
#    None,
#    1000.0,
#    None],
#   'temp_time_vector': array([ 450., 1000.,   nan,  100.,    3.,   25.,   nan,   nan])},
#  {'DOI': '10.1021/jp511931y',
#   'target': 'LaMnO3',
#   'precursors': ['La(NO3)3', 'Mn2O3'],
#   'operation_types': ['StartingSynthesis',
#    'DryingOperation',
#    'StartingSynthesis',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation',
#    'StartingSynthesis',
#    'MixingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['synthesized',
#    'dried',
#    'prepared',
#    'ground',
#    'pressed',
#    'sintered',
#    'reground',
#    'pressed',
#    'sintered',
#    'synthesized',
#    'dissolved',
#    'added',
#    'heated',
#    'calcined',
#    'ground',
#    'pressed',
#    'sintered',
#    'reground',
#    'pressed',
#    'sintered'],
#   'operation_times': [None,
#    8,
#    None,
#    None,
#    None,
#    12,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    10,
#    None,
#    None,
#    12,
#    None,
#    None,
#    None],
#   'operation_temps': [None,
#    800.0,
#    None,
#    None,
#    None,
#    1100.0,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    400.0,
#    None,
#    None,
#    1100.0,
#    None,
#    None,
#    None],
#   'temp_time_vector': array([ 400., 1100.,   nan,  800.,   10.,   12.,   nan,    8.])},
#  {'DOI': '10.1021/jp511931y',
#   'target': 'LaFeO3',
#   'precursors': ['Fe2O3', 'La(NO3)3'],
#   'operation_types': ['StartingSynthesis',
#    'DryingOperation',
#    'StartingSynthesis',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation',
#    'StartingSynthesis',
#    'MixingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['synthesized',
#    'dried',
#    'prepared',
#    'ground',
#    'pressed',
#    'sintered',
#    'reground',
#    'pressed',
#    'sintered',
#    'synthesized',
#    'dissolved',
#    'added',
#    'heated',
#    'calcined',
#    'ground',
#    'pressed',
#    'sintered',
#    'reground',
#    'pressed',
#    'sintered'],
#   'operation_times': [None,
#    8,
#    None,
#    None,
#    None,
#    12,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    10,
#    None,
#    None,
#    12,
#    None,
#    None,
#    None],
#   'operation_temps': [None,
#    800.0,
#    None,
#    None,
#    None,
#    1100.0,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    400.0,
#    None,
#    None,
#    1100.0,
#    None,
#    None,
#    None],
#   'temp_time_vector': array([ 400., 1100.,   nan,  800.,   10.,   12.,   nan,    8.])},
#  {'DOI': '10.1021/jp511931y',
#   'target': 'LaCoO3',
#   'precursors': ['Co3O4', 'La(NO3)3'],
#   'operation_types': ['StartingSynthesis',
#    'DryingOperation',
#    'StartingSynthesis',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation',
#    'StartingSynthesis',
#    'MixingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['synthesized',
#    'dried',
#    'prepared',
#    'ground',
#    'pressed',
#    'sintered',
#    'reground',
#    'pressed',
#    'sintered',
#    'synthesized',
#    'dissolved',
#    'added',
#    'heated',
#    'calcined',
#    'ground',
#    'pressed',
#    'sintered',
#    'reground',
#    'pressed',
#    'sintered'],
#   'operation_times': [None,
#    8,
#    None,
#    None,
#    None,
#    12,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    10,
#    None,
#    None,
#    12,
#    None,
#    None,
#    None],
#   'operation_temps': [None,
#    800.0,
#    None,
#    None,
#    None,
#    1100.0,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    400.0,
#    None,
#    None,
#    1100.0,
#    None,
#    None,
#    None],
#   'temp_time_vector': array([ 400., 1100.,   nan,  800.,   10.,   12.,   nan,    8.])},
#  {'DOI': '10.1007/s10008-014-2603-z',
#   'target': 'Li2FeSiO4',
#   'precursors': ['Fe(CO2)2', 'LiH3(CO)2', 'SiH20(C2O)4'],
#   'operation_types': ['StartingSynthesis',
#    'MixingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'DryingOperation',
#    'MixingOperation',
#    'DryingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'QuenchingOperation',
#    'MixingOperation',
#    'StartingSynthesis'],
#   'operation_tokens': ['synthesized',
#    'dispersed',
#    'refluxed',
#    'stirring',
#    'dried',
#    'ground',
#    'drying',
#    'calcined',
#    'sintered',
#    'cooling',
#    'ground',
#    'synthesized'],
#   'operation_times': [None,
#    None,
#    24,
#    None,
#    None,
#    None,
#    None,
#    5,
#    10,
#    None,
#    None,
#    None],
#   'operation_temps': [None,
#    None,
#    80.0,
#    None,
#    50.0,
#    None,
#    None,
#    350.0,
#    650.0,
#    None,
#    None,
#    None],
#   'temp_time_vector': array([350., 650.,  nan,  50.,   5.,  10.,  nan,  nan])},
#  {'DOI': '10.1039/c2cp44394e',
#   'target': 'Li1.3Mn0.65Ni0.35O2.3',
#   'precursors': ['LiHO', 'MnO2', 'Ni(NO3)2'],
#   'operation_types': ['StartingSynthesis',
#    'MixingOperation',
#    'DryingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'StartingSynthesis',
#    'MixingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'DryingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'DryingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'DryingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['prepared',
#    'dispersed',
#    'evaporated',
#    'stirring',
#    'ground',
#    'heated',
#    'prepared',
#    'dissolved',
#    'adding',
#    'stirring',
#    'dried',
#    'stirring',
#    'treated',
#    'ground',
#    'dried',
#    'sintered',
#    'milled',
#    'dried',
#    'annealed'],
#   'operation_times': [None,
#    None,
#    None,
#    None,
#    None,
#    10,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    10,
#    None,
#    None,
#    10,
#    10,
#    None,
#    24],
#   'operation_temps': [None,
#    None,
#    50.0,
#    None,
#    None,
#    800.0,
#    None,
#    None,
#    None,
#    None,
#    120.0,
#    None,
#    400.0,
#    None,
#    80.0,
#    800.0,
#    None,
#    None,
#    800.0],
#   'temp_time_vector': array([ nan, 800., 800.,  80.,  nan,  10.,  24.,  nan])},
#  {'DOI': '10.1039/c7tc05422j',
#   'target': 'BaYCo2O',
#   'precursors': ['BaCO3', 'Co3O4', 'Y2O3'],
#   'operation_types': ['StartingSynthesis',
#    'MixingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'MixingOperation'],
#   'operation_tokens': ['prepared',
#    'mixed',
#    'pre-sintering',
#    'sintering',
#    'maintained',
#    'maintained',
#    'adjusted',
#    'adding'],
#   'operation_times': [None, None, 12, 24, None, None, None, None],
#   'operation_temps': [None, None, 950.0, 1100.0, None, None, None, None],
#   'temp_time_vector': array([  nan, 1100.,   nan,   nan,   nan,   24.,   nan,   nan])},
#  {'DOI': '10.1039/c1jm11551k',
#   'target': 'LiFePO4',
#   'precursors': ['FePO4', 'LiH3(CO)2'],
#   'operation_types': ['StartingSynthesis',
#    'MixingOperation',
#    'StartingSynthesis',
#    'MixingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'DryingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'StartingSynthesis'],
#   'operation_tokens': ['prepared',
#    'dissolved',
#    'prepared',
#    'mixed',
#    'stirring',
#    'heated',
#    'dried',
#    'grinding',
#    'sintered',
#    'prepared'],
#   'operation_times': [None, None, None, None, None, None, None, None, 7, None],
#   'operation_temps': [None,
#    60.0,
#    None,
#    None,
#    None,
#    80.0,
#    None,
#    None,
#    650.0,
#    None],
#   'temp_time_vector': array([ nan, 650.,  nan,  nan,  nan,   7.,  nan,  nan])},
#  {'DOI': '10.1039/c5cp06742a',
#   'target': 'Sr0.19La0.76MnO3',
#   'precursors': ['La2O3', 'MnO2', 'SrCO3'],
#   'operation_types': ['StartingSynthesis',
#    'StartingSynthesis',
#    'MixingOperation',
#    'StartingSynthesis',
#    'MixingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['synthesized',
#    'synthesized',
#    'mixing',
#    'prepared',
#    'mixed',
#    'sintered'],
#   'operation_times': [None, None, 10, None, None, 3],
#   'operation_temps': [None, None, 1100.0, None, None, 800.0],
#   'temp_time_vector': array([ nan, 800.,  nan,  nan,  nan,   3.,  nan,  nan])},
#  {'DOI': '10.1016/j.jlumin.2011.05.060',
#   'target': 'Sr4Al14O25',
#   'precursors': ['Al2O3', 'SrCO3'],
#   'operation_types': ['MixingOperation',
#    'HeatingOperation',
#    'StartingSynthesis',
#    'MixingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'DryingOperation',
#    'HeatingOperation',
#    'DryingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['ground',
#    'preheated',
#    'prepared',
#    'dissolved',
#    'heated',
#    'added',
#    'added',
#    'stirred',
#    'concentrating',
#    'raised',
#    'dried',
#    'ground',
#    'preheated',
#    'sintered'],
#   'operation_times': [None,
#    4,
#    None,
#    None,
#    None,
#    None,
#    None,
#    1,
#    None,
#    None,
#    None,
#    None,
#    4,
#    8],
#   'operation_temps': [None,
#    1000.0,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    250.0,
#    120.0,
#    None,
#    1000.0,
#    1400.0],
#   'temp_time_vector': array([  nan, 1400.,   nan,  120.,   nan,    8.,   nan,   nan])},
#  {'DOI': '10.1016/j.optmat.2015.10.019',
#   'target': 'GdOCl',
#   'precursors': ['Gd2O3', 'H4NCl'],
#   'operation_types': ['StartingSynthesis',
#    'MixingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'DryingOperation',
#    'MixingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['prepared',
#    'dissolved',
#    'stirring',
#    'added',
#    'stirred',
#    'dried',
#    'ground',
#    'sintered'],
#   'operation_times': [None, None, None, None, None, 12, None, 1],
#   'operation_temps': [None, None, None, None, None, 80.0, None, 1000.0],
#   'temp_time_vector': array([  nan, 1000.,   nan,   80.,   nan,    1.,   nan,   12.])},
#  {'DOI': '10.1016/j.ssnmr.2012.01.003',
#   'target': 'LaGaO3',
#   'precursors': ['Ga2O3', 'La2O3'],
#   'operation_types': ['StartingSynthesis',
#    'HeatingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['prepared',
#    'heated',
#    'heated',
#    'mixed',
#    'sintered',
#    'ground',
#    're-pressed',
#    're-sintered'],
#   'operation_times': [None, None, None, None, None, None, None, 12],
#   'operation_temps': [None, 1000.0, 1000.0, None, 1500.0, None, None, 1700.0],
#   'temp_time_vector': array([  nan, 1700.,   nan,   nan,   nan,   12.,   nan,   nan])},
#  {'DOI': '10.1016/j.ssnmr.2012.01.003',
#   'target': 'LaAlO3',
#   'precursors': ['Al2O3', 'La2O3'],
#   'operation_types': ['StartingSynthesis',
#    'HeatingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['prepared',
#    'heated',
#    'heated',
#    'mixed',
#    'sintered',
#    'ground',
#    're-pressed',
#    're-sintered'],
#   'operation_times': [None, None, None, None, None, None, None, 12],
#   'operation_temps': [None, 1000.0, 1000.0, None, 1500.0, None, None, 1700.0],
#   'temp_time_vector': array([  nan, 1700.,   nan,   nan,   nan,   12.,   nan,   nan])},
#  {'DOI': '10.1016/j.ssi.2004.03.041',
#   'target': 'SrCe0.95Y0.05O3',
#   'precursors': ['CeO2', 'SrCO3', 'Y2O3'],
#   'operation_types': ['HeatingOperation',
#    'StartingSynthesis',
#    'ShapingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['sintered',
#    'prepared',
#    'pressed',
#    'sintered',
#    'annealed',
#    'annealed',
#    'annealed'],
#   'operation_times': [None, None, None, 20, None, None, None],
#   'operation_temps': [None, None, None, 1250.0, None, None, None],
#   'temp_time_vector': array([  nan, 1250.,   nan,   nan,   nan,   20.,   nan,   nan])},
#  {'DOI': '10.1016/j.ssi.2004.03.041',
#   'target': 'SrCeO3',
#   'precursors': ['CeO2', 'SrCO3'],
#   'operation_types': ['HeatingOperation',
#    'StartingSynthesis',
#    'ShapingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['sintered',
#    'prepared',
#    'pressed',
#    'sintered',
#    'annealed',
#    'annealed',
#    'annealed'],
#   'operation_times': [None, None, None, 20, None, None, None],
#   'operation_temps': [None, None, None, 1250.0, None, None, None],
#   'temp_time_vector': array([  nan, 1250.,   nan,   nan,   nan,   20.,   nan,   nan])},
#  {'DOI': '10.1016/j.ssi.2007.12.027',
#   'target': 'Sr0.5La0.5FeO3',
#   'precursors': ['Fe(NO3)3', 'La2O3', 'SrCO3'],
#   'operation_types': ['StartingSynthesis',
#    'HeatingOperation',
#    'StartingSynthesis',
#    'StartingSynthesis',
#    'StartingSynthesis',
#    'ShapingOperation',
#    'HeatingOperation',
#    'DryingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['synthesized',
#    'annealed',
#    'prepared',
#    'prepared',
#    'fabricated',
#    'pressing',
#    'sintering',
#    'drying',
#    'annealing'],
#   'operation_times': [None, 2, None, None, None, None, 5, None, None],
#   'operation_temps': [None,
#    1200.0,
#    None,
#    None,
#    None,
#    None,
#    1350.0,
#    None,
#    1120.0],
#   'temp_time_vector': array([  nan, 1350., 1120.,   nan,   nan,    5.,   nan,   nan])},
#  {'DOI': '10.1016/j.solidstatesciences.2007.08.017',
#   'target': 'Fe1.96Ni0.8Cu0.12Zn0.12O4',
#   'precursors': ['CuO', 'Fe2O3', 'NiO', 'ZnO'],
#   'operation_types': ['StartingSynthesis',
#    'HeatingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['synthesized',
#    'treated',
#    'mixed',
#    'calcined',
#    'mixed',
#    'milled',
#    'sintered',
#    'sintered'],
#   'operation_times': [None, 2, 12, 2, None, 48, None, 4],
#   'operation_temps': [None, 350.0, None, 750.0, None, None, None, 900.0],
#   'temp_time_vector': array([750., 900.,  nan,  nan,   2.,   4.,  nan,  nan])},
#  {'DOI': '10.1016/j.jpowsour.2011.08.044',
#   'target': 'Na0.05Li2.95V2P3O12',
#   'precursors': ['Li2CO3', 'Na2CO3', 'PH6NO4', 'V2O5'],
#   'operation_types': ['MixingOperation',
#    'StartingSynthesis',
#    'MixingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'DryingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['mixing',
#    'synthesized',
#    'added',
#    'dissolved',
#    'added',
#    'stirring',
#    'added',
#    'stirring',
#    'dissolved',
#    'heated',
#    'stirring',
#    'drying',
#    'decomposed',
#    'reground',
#    'pressed',
#    'sintered'],
#   'operation_times': [None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    5,
#    None,
#    None,
#    10],
#   'operation_temps': [None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    60.0,
#    None,
#    None,
#    None,
#    80.0,
#    350.0,
#    None,
#    None,
#    750.0],
#   'temp_time_vector': array([ nan, 750.,  nan,  80.,  nan,  10.,  nan,  nan])},
#  {'DOI': '10.1016/j.jpowsour.2011.08.044',
#   'target': 'Na0.01Li2.99V2P3O12',
#   'precursors': ['Li2CO3', 'Na2CO3', 'PH6NO4', 'V2O5'],
#   'operation_types': ['MixingOperation',
#    'StartingSynthesis',
#    'MixingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'DryingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['mixing',
#    'synthesized',
#    'added',
#    'dissolved',
#    'added',
#    'stirring',
#    'added',
#    'stirring',
#    'dissolved',
#    'heated',
#    'stirring',
#    'drying',
#    'decomposed',
#    'reground',
#    'pressed',
#    'sintered'],
#   'operation_times': [None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    5,
#    None,
#    None,
#    10],
#   'operation_temps': [None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    60.0,
#    None,
#    None,
#    None,
#    80.0,
#    350.0,
#    None,
#    None,
#    750.0],
#   'temp_time_vector': array([ nan, 750.,  nan,  80.,  nan,  10.,  nan,  nan])},
#  {'DOI': '10.1016/j.jpowsour.2011.08.044',
#   'target': 'Na0.03Li2.97V2P3O12',
#   'precursors': ['Li2CO3', 'Na2CO3', 'PH6NO4', 'V2O5'],
#   'operation_types': ['MixingOperation',
#    'StartingSynthesis',
#    'MixingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'DryingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['mixing',
#    'synthesized',
#    'added',
#    'dissolved',
#    'added',
#    'stirring',
#    'added',
#    'stirring',
#    'dissolved',
#    'heated',
#    'stirring',
#    'drying',
#    'decomposed',
#    'reground',
#    'pressed',
#    'sintered'],
#   'operation_times': [None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    5,
#    None,
#    None,
#    10],
#   'operation_temps': [None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    60.0,
#    None,
#    None,
#    None,
#    80.0,
#    350.0,
#    None,
#    None,
#    750.0],
#   'temp_time_vector': array([ nan, 750.,  nan,  80.,  nan,  10.,  nan,  nan])},
#  {'DOI': '10.1016/j.jpowsour.2011.08.044',
#   'target': 'Li3V2P3O12',
#   'precursors': ['Li2CO3', 'PH6NO4', 'V2O5'],
#   'operation_types': ['MixingOperation',
#    'StartingSynthesis',
#    'MixingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'DryingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['mixing',
#    'synthesized',
#    'added',
#    'dissolved',
#    'added',
#    'stirring',
#    'added',
#    'stirring',
#    'dissolved',
#    'heated',
#    'stirring',
#    'drying',
#    'decomposed',
#    'reground',
#    'pressed',
#    'sintered'],
#   'operation_times': [None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    5,
#    None,
#    None,
#    10],
#   'operation_temps': [None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    60.0,
#    None,
#    None,
#    None,
#    80.0,
#    350.0,
#    None,
#    None,
#    750.0],
#   'temp_time_vector': array([ nan, 750.,  nan,  80.,  nan,  10.,  nan,  nan])},
#  {'DOI': '10.1016/j.electacta.2006.11.044',
#   'target': 'LiMn0.5Ni0.5O2',
#   'precursors': ['Li', 'MnH6(CO)4', 'Ni'],
#   'operation_types': ['StartingSynthesis',
#    'StartingSynthesis',
#    'DryingOperation',
#    'HeatingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['prepared',
#    'synthesized',
#    'dried',
#    'calcined',
#    'sintered'],
#   'operation_times': [None, None, None, 4, 12],
#   'operation_temps': [None, None, None, 450.0, 900.0],
#   'temp_time_vector': array([450., 900.,  nan,  nan,   4.,  12.,  nan,  nan])},
#  {'DOI': '10.1016/j.electacta.2010.08.015',
#   'target': 'LiMn2O4',
#   'precursors': ['LiHO', 'MnO2'],
#   'operation_types': ['StartingSynthesis',
#    'MixingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'DryingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'DryingOperation',
#    'StartingSynthesis',
#    'MixingOperation',
#    'DryingOperation',
#    'MixingOperation',
#    'DryingOperation',
#    'MixingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['prepared',
#    'dissolving',
#    'adding',
#    'filtered',
#    'dried',
#    'ground',
#    'annealed',
#    'dispersed',
#    'adjusted',
#    'heating',
#    'dried',
#    'synthesized',
#    'ground',
#    'dried',
#    'grinding',
#    'drying',
#    'mixed',
#    'sintered'],
#   'operation_times': [None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    12,
#    None,
#    None,
#    5,
#    24,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    10],
#   'operation_temps': [None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    700.0,
#    None,
#    None,
#    200.0,
#    70.0,
#    None,
#    None,
#    110.0,
#    None,
#    None,
#    None,
#    800.0],
#   'temp_time_vector': array([ nan, 800., 700., 110.,  nan,  10.,  12.,  nan])},
#  {'DOI': '10.1016/j.electacta.2011.01.109',
#   'target': 'Li3V2P3O12',
#   'precursors': ['Li2CO3', 'PH6NO4', 'VH4NO3'],
#   'operation_types': ['MixingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'DryingOperation',
#    'MixingOperation',
#    'DryingOperation',
#    'HeatingOperation',
#    'QuenchingOperation',
#    'DryingOperation',
#    'ShapingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['added',
#    'dispersed',
#    'milled',
#    'dried',
#    'stirred',
#    'dried',
#    'maintained',
#    'cooled',
#    'dried',
#    'pressed',
#    'sintered'],
#   'operation_times': [None, None, 5, None, 4, 12, 4, None, None, None, 8],
#   'operation_temps': [None,
#    None,
#    None,
#    60.0,
#    90.0,
#    120.0,
#    220.0,
#    None,
#    60.0,
#    None,
#    750.0],
#   'temp_time_vector': array([ nan, 750.,  nan,  60.,  nan,   8.,  nan,  nan])},
#  {'DOI': '10.1016/j.electacta.2011.06.019',
#   'target': 'LiFePO4',
#   'precursors': ['FePO4', 'LiH3(CO)2'],
#   'operation_types': ['StartingSynthesis',
#    'MixingOperation',
#    'MixingOperation',
#    'StartingSynthesis',
#    'MixingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'StartingSynthesis',
#    'StartingSynthesis'],
#   'operation_tokens': ['prepared',
#    'dissolved',
#    'stirring',
#    'prepared',
#    'mixed',
#    'heated',
#    'stirring',
#    'treated',
#    'sintered',
#    'prepared',
#    'prepared'],
#   'operation_times': [None,
#    1,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    7,
#    None,
#    None],
#   'operation_temps': [None,
#    60.0,
#    None,
#    None,
#    None,
#    40.0,
#    None,
#    300.0,
#    650.0,
#    None,
#    None],
#   'temp_time_vector': array([ nan, 650.,  nan,  nan,  nan,   7.,  nan,  nan])},
#  {'DOI': '10.1016/j.electacta.2014.10.133',
#   'target': 'Li3V2P3O12',
#   'precursors': ['Li2CO3', 'PH6NO4', 'VH4NO3'],
#   'operation_types': ['StartingSynthesis',
#    'MixingOperation',
#    'MixingOperation',
#    'DryingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'QuenchingOperation',
#    'HeatingOperation',
#    'QuenchingOperation'],
#   'operation_tokens': ['synthesized',
#    'added',
#    'milled',
#    'dried',
#    'annealed',
#    'ground',
#    'cooled',
#    'sintered',
#    'cooled'],
#   'operation_times': [None, None, 6, 12, 6, 2, None, 12, None],
#   'operation_temps': [None, None, None, 80.0, 350.0, None, None, 800.0, None],
#   'temp_time_vector': array([ nan, 800., 350.,  80.,  nan,  12.,   6.,  12.])},
#  {'DOI': '10.1016/j.electacta.2014.04.064',
#   'target': 'BaPrCo2O5',
#   'precursors': ['Ba(NO3)2', 'Co(NO3)2', 'Pr6O11'],
#   'operation_types': ['StartingSynthesis',
#    'MixingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'StartingSynthesis'],
#   'operation_tokens': ['prepared',
#    'dissolved',
#    'dissolved',
#    'mixed',
#    'addition',
#    'added',
#    'heated',
#    'stirring',
#    'baked',
#    'calcined',
#    'ground',
#    'sintered',
#    'synthesized'],
#   'operation_times': [None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    8,
#    None,
#    10,
#    None],
#   'operation_temps': [None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    120.0,
#    None,
#    150.0,
#    400.0,
#    None,
#    1000.0,
#    None],
#   'temp_time_vector': array([ 400., 1000.,   nan,   nan,    8.,   10.,   nan,   nan])},
#  {'DOI': '10.1016/j.electacta.2014.04.064',
#   'target': 'Ba0.7Pr1.3Co2O5',
#   'precursors': ['Ba(NO3)2', 'Co(NO3)2', 'Pr6O11'],
#   'operation_types': ['StartingSynthesis',
#    'MixingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'StartingSynthesis'],
#   'operation_tokens': ['prepared',
#    'dissolved',
#    'dissolved',
#    'mixed',
#    'addition',
#    'added',
#    'heated',
#    'stirring',
#    'baked',
#    'calcined',
#    'ground',
#    'sintered',
#    'synthesized'],
#   'operation_times': [None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    8,
#    None,
#    10,
#    None],
#   'operation_temps': [None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    120.0,
#    None,
#    150.0,
#    400.0,
#    None,
#    1000.0,
#    None],
#   'temp_time_vector': array([ 400., 1000.,   nan,   nan,    8.,   10.,   nan,   nan])},
#  {'DOI': '10.1016/j.electacta.2014.11.172',
#   'target': 'Li2V0.03Fe0.97SiO4',
#   'precursors': ['Fe(CO2)2', 'LiH3(CO)2', 'SiH20(C2O)4', 'V2O5'],
#   'operation_types': ['StartingSynthesis',
#    'MixingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'DryingOperation',
#    'MixingOperation',
#    'DryingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'QuenchingOperation',
#    'MixingOperation'],
#   'operation_tokens': ['synthesized',
#    'dispersed',
#    'refluxed',
#    'stirring',
#    'dried',
#    'ground',
#    'drying',
#    'calcined',
#    'sintered',
#    'cooling',
#    'ground'],
#   'operation_times': [None, None, 24, None, None, 7, None, 5, 10, None, None],
#   'operation_temps': [None,
#    None,
#    80.0,
#    None,
#    50.0,
#    None,
#    None,
#    350.0,
#    650.0,
#    None,
#    None],
#   'temp_time_vector': array([350., 650.,  nan,  50.,   5.,  10.,  nan,  nan])},
#  {'DOI': '10.1016/j.electacta.2014.11.172',
#   'target': 'Li2V0.07Fe0.93SiO4',
#   'precursors': ['Fe(CO2)2', 'LiH3(CO)2', 'SiH20(C2O)4', 'V2O5'],
#   'operation_types': ['StartingSynthesis',
#    'MixingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'DryingOperation',
#    'MixingOperation',
#    'DryingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'QuenchingOperation',
#    'MixingOperation'],
#   'operation_tokens': ['synthesized',
#    'dispersed',
# ...
#    'HeatingOperation'],
#   'operation_tokens': ['synthesised',
#    'calcined',
#    'milled',
#    'uniaxially',
#    'sintered'],
#   'operation_times': [None, 15, 24, None, 15],
#   'operation_temps': [None, 1000.0, None, None, 1250.0],
#   'temp_time_vector': array([1000., 1250.,   nan,   nan,   15.,   15.,   nan,   nan])},
#  {'DOI': '10.1016/j.jeurceramsoc.2006.04.069',
#   'target': 'Sr0.6La1.4CoO4',
#   'precursors': ['CoH6(CO)4', 'La2O3', 'Sr(NO3)2'],
#   'operation_types': ['StartingSynthesis',
#    'HeatingOperation',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['synthesised',
#    'calcined',
#    'milled',
#    'uniaxially',
#    'sintered'],
#   'operation_times': [None, 15, 24, None, 15],
#   'operation_temps': [None, 1000.0, None, None, 1250.0],
#   'temp_time_vector': array([1000., 1250.,   nan,   nan,   15.,   15.,   nan,   nan])},
#  {'DOI': '10.1016/j.jeurceramsoc.2006.04.069',
#   'target': 'Sr0.6La1.4Co0.5Ni0.5O4',
#   'precursors': ['CoH6(CO)4', 'La2O3', 'NiH6(CO)4', 'Sr(NO3)2'],
#   'operation_types': ['StartingSynthesis',
#    'HeatingOperation',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['synthesised',
#    'calcined',
#    'milled',
#    'uniaxially',
#    'sintered'],
#   'operation_times': [None, 15, 24, None, 15],
#   'operation_temps': [None, 1000.0, None, None, 1250.0],
#   'temp_time_vector': array([1000., 1250.,   nan,   nan,   15.,   15.,   nan,   nan])},
#  {'DOI': '10.1016/j.jeurceramsoc.2006.04.069',
#   'target': 'SrLaMn0.5Co0.5O4',
#   'precursors': ['CoH6(CO)4', 'La2O3', 'MnH6(CO)4', 'Sr(NO3)2'],
#   'operation_types': ['StartingSynthesis',
#    'HeatingOperation',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['synthesised',
#    'calcined',
#    'milled',
#    'uniaxially',
#    'sintered'],
#   'operation_times': [None, 15, 24, None, 15],
#   'operation_temps': [None, 1000.0, None, None, 1250.0],
#   'temp_time_vector': array([1000., 1250.,   nan,   nan,   15.,   15.,   nan,   nan])},
#  {'DOI': '10.1016/j.jeurceramsoc.2006.04.069',
#   'target': 'SrLaFe0.5Co0.5O4',
#   'precursors': ['CoH6(CO)4', 'Fe(NO3)3', 'La2O3', 'Sr(NO3)2'],
#   'operation_types': ['StartingSynthesis',
#    'HeatingOperation',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['synthesised',
#    'calcined',
#    'milled',
#    'uniaxially',
#    'sintered'],
#   'operation_times': [None, 15, 24, None, 15],
#   'operation_temps': [None, 1000.0, None, None, 1250.0],
#   'temp_time_vector': array([1000., 1250.,   nan,   nan,   15.,   15.,   nan,   nan])},
#  {'DOI': '10.1016/j.jeurceramsoc.2006.04.069',
#   'target': 'SrLaCoO4',
#   'precursors': ['CoH6(CO)4', 'La2O3', 'Sr(NO3)2'],
#   'operation_types': ['StartingSynthesis',
#    'HeatingOperation',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['synthesised',
#    'calcined',
#    'milled',
#    'uniaxially',
#    'sintered'],
#   'operation_times': [None, 15, 24, None, 15],
#   'operation_temps': [None, 1000.0, None, None, 1250.0],
#   'temp_time_vector': array([1000., 1250.,   nan,   nan,   15.,   15.,   nan,   nan])},
#  {'DOI': '10.1016/j.jeurceramsoc.2006.04.069',
#   'target': 'SrLaCo0.5Ni0.5O4',
#   'precursors': ['CoH6(CO)4', 'La2O3', 'NiH6(CO)4', 'Sr(NO3)2'],
#   'operation_types': ['StartingSynthesis',
#    'HeatingOperation',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['synthesised',
#    'calcined',
#    'milled',
#    'uniaxially',
#    'sintered'],
#   'operation_times': [None, 15, 24, None, 15],
#   'operation_temps': [None, 1000.0, None, None, 1250.0],
#   'temp_time_vector': array([1000., 1250.,   nan,   nan,   15.,   15.,   nan,   nan])},
#  {'DOI': '10.1016/j.jeurceramsoc.2006.04.069',
#   'target': 'Sr0.6La1.4Mn0.5Co0.5O4',
#   'precursors': ['CoH6(CO)4', 'La2O3', 'MnH6(CO)4', 'Sr(NO3)2'],
#   'operation_types': ['StartingSynthesis',
#    'HeatingOperation',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['synthesised',
#    'calcined',
#    'milled',
#    'uniaxially',
#    'sintered'],
#   'operation_times': [None, 15, 24, None, 15],
#   'operation_temps': [None, 1000.0, None, None, 1250.0],
#   'temp_time_vector': array([1000., 1250.,   nan,   nan,   15.,   15.,   nan,   nan])},
#  {'DOI': '10.1016/j.jeurceramsoc.2006.04.069',
#   'target': 'Sr0.6La1.4Fe0.5Co0.5O4',
#   'precursors': ['CoH6(CO)4', 'Fe(NO3)3', 'La2O3', 'Sr(NO3)2'],
#   'operation_types': ['StartingSynthesis',
#    'HeatingOperation',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['synthesised',
#    'calcined',
#    'milled',
#    'uniaxially',
#    'sintered'],
#   'operation_times': [None, 15, 24, None, 15],
#   'operation_temps': [None, 1000.0, None, None, 1250.0],
#   'temp_time_vector': array([1000., 1250.,   nan,   nan,   15.,   15.,   nan,   nan])},
#  {'DOI': '10.1016/j.jeurceramsoc.2006.04.069',
#   'target': 'Sr0.6La1.4CoO4',
#   'precursors': ['CoH6(CO)4', 'La2O3', 'Sr(NO3)2'],
#   'operation_types': ['StartingSynthesis',
#    'HeatingOperation',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['synthesised',
#    'calcined',
#    'milled',
#    'uniaxially',
#    'sintered'],
#   'operation_times': [None, 15, 24, None, 15],
#   'operation_temps': [None, 1000.0, None, None, 1250.0],
#   'temp_time_vector': array([1000., 1250.,   nan,   nan,   15.,   15.,   nan,   nan])},
#  {'DOI': '10.1016/j.jeurceramsoc.2006.04.069',
#   'target': 'Sr0.6La1.4Co0.5Ni0.5O4',
#   'precursors': ['CoH6(CO)4', 'La2O3', 'NiH6(CO)4', 'Sr(NO3)2'],
#   'operation_types': ['StartingSynthesis',
#    'HeatingOperation',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['synthesised',
#    'calcined',
#    'milled',
#    'uniaxially',
#    'sintered'],
#   'operation_times': [None, 15, 24, None, 15],
#   'operation_temps': [None, 1000.0, None, None, 1250.0],
#   'temp_time_vector': array([1000., 1250.,   nan,   nan,   15.,   15.,   nan,   nan])},
#  {'DOI': '10.1016/j.jlumin.2005.05.008',
#   'target': 'CaAl4O7',
#   'precursors': ['Al2O3', 'CaCO3'],
#   'operation_types': ['StartingSynthesis',
#    'MixingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['prepared',
#    'mixed',
#    'mixed',
#    'added',
#    'pressed',
#    'sintered',
#    'annealed'],
#   'operation_times': [None, None, None, None, None, 5, None],
#   'operation_temps': [None, None, None, None, None, 1200.0, None],
#   'temp_time_vector': array([  nan, 1200.,   nan,   nan,   nan,    5.,   nan,   nan])},
#  {'DOI': '10.1016/j.jmmm.2015.01.059',
#   'target': 'Ba2Fe12Zn2O22',
#   'precursors': ['BaCO3', 'Fe2O3', 'ZnO'],
#   'operation_types': ['StartingSynthesis',
#    'HeatingOperation',
#    'MixingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['synthesized', 'calcined', 'milled', 'sintered'],
#   'operation_times': [None, 4, None, 4],
#   'operation_temps': [None, 1080.0, None, 1200.0],
#   'temp_time_vector': array([1080., 1200.,   nan,   nan,    4.,    4.,   nan,   nan])},
#  {'DOI': '10.1016/j.jmmm.2015.01.059',
#   'target': 'Ba2Fe12Cu2O22',
#   'precursors': ['BaCO3', 'CuO', 'Fe2O3'],
#   'operation_types': ['StartingSynthesis',
#    'HeatingOperation',
#    'MixingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['synthesized', 'calcined', 'milled', 'sintered'],
#   'operation_times': [None, 4, None, 4],
#   'operation_temps': [None, 1080.0, None, 1200.0],
#   'temp_time_vector': array([1080., 1200.,   nan,   nan,    4.,    4.,   nan,   nan])},
#  {'DOI': '10.1016/j.jpowsour.2005.03.061',
#   'target': 'LiTi2P3O12',
#   'precursors': ['Li2CO3', 'P2O5', 'TiO2'],
#   'operation_types': ['StartingSynthesis',
#    'MixingOperation',
#    'HeatingOperation',
#    'ShapingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['synthesized',
#    'mixed',
#    'heated',
#    'pressed',
#    'sintered'],
#   'operation_times': [None, None, 2, None, 2],
#   'operation_temps': [None, None, 1000.0, None, 1000.0],
#   'temp_time_vector': array([  nan, 1000.,   nan,   nan,   nan,    2.,   nan,   nan])},
#  {'DOI': '10.1016/j.jpowsour.2009.07.009',
#   'target': 'Mn27Zn72.5AlO128',
#   'precursors': ['Al2O3', 'MnO2', 'ZnO'],
#   'operation_types': ['StartingSynthesis',
#    'StartingSynthesis',
#    'MixingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['prepared', 'prepared', 'mixing', 'sintered'],
#   'operation_times': [None, None, None, 2],
#   'operation_temps': [None, None, None, 1350.0],
#   'temp_time_vector': array([  nan, 1350.,   nan,   nan,   nan,    2.,   nan,   nan])},
#  {'DOI': '10.1016/j.jpowsour.2010.06.072',
#   'target': 'Mn27Zn72.5AlO128',
#   'precursors': ['Al2O3', 'MnO2', 'ZnO'],
#   'operation_types': ['StartingSynthesis',
#    'StartingSynthesis',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['prepared',
#    'prepared',
#    'mixing',
#    'pressing',
#    'sintered'],
#   'operation_times': [None, None, None, None, 2],
#   'operation_temps': [None, None, None, None, 1350.0],
#   'temp_time_vector': array([  nan, 1350.,   nan,   nan,   nan,    2.,   nan,   nan])},
#  {'DOI': '10.1016/j.jpowsour.2009.08.071',
#   'target': 'Ba0.5Sr0.5GdCo2O5',
#   'precursors': ['Ba(NO3)2', 'Co(NO3)2', 'Gd2O3', 'Sr(NO3)2'],
#   'operation_types': ['StartingSynthesis',
#    'HeatingOperation',
#    'MixingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['synthesized', 'calcination', 'mixed', 'sintered'],
#   'operation_times': [None, 5, None, 5],
#   'operation_temps': [None, 1000.0, None, 1000.0],
#   'temp_time_vector': array([1000., 1000.,   nan,   nan,    5.,    5.,   nan,   nan])},
#  {'DOI': '10.1016/j.jpowsour.2016.01.070',
#   'target': 'NiAl2O4',
#   'precursors': ['Al2O3', 'NiO'],
#   'operation_types': ['StartingSynthesis',
#    'MixingOperation',
#    'MixingOperation',
#    'DryingOperation',
#    'HeatingOperation',
#    'StartingSynthesis'],
#   'operation_tokens': ['prepared',
#    'mixing',
#    'grinding',
#    'drying',
#    'sintered',
#    'prepared'],
#   'operation_times': [None, None, 1, None, 2, None],
#   'operation_temps': [None, None, None, None, 1400.0, None],
#   'temp_time_vector': array([  nan, 1400.,   nan,   nan,   nan,    2.,   nan,   nan])},
#  {'DOI': '10.1016/j.jssc.2007.09.011',
#   'target': 'ZrW0.7Mo1.3O8',
#   'precursors': ['Mo', 'W', 'Zr'],
#   'operation_types': ['StartingSynthesis',
#    'StartingSynthesis',
#    'DryingOperation',
#    'MixingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['prepared', 'obtained', 'dried', 'ground', 'sintered'],
#   'operation_times': [None, None, None, None, 3],
#   'operation_temps': [None, None, 100.0, None, 600.0],
#   'temp_time_vector': array([ nan, 600.,  nan, 100.,  nan,   3.,  nan,  nan])},
#  {'DOI': '10.1016/j.jssc.2007.09.011',
#   'target': 'ZrW2O8',
#   'precursors': ['W', 'Zr'],
#   'operation_types': ['StartingSynthesis',
#    'StartingSynthesis',
#    'DryingOperation',
#    'MixingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['prepared', 'obtained', 'dried', 'ground', 'sintered'],
#   'operation_times': [None, None, None, None, 3],
#   'operation_temps': [None, None, 100.0, None, 600.0],
#   'temp_time_vector': array([ nan, 600.,  nan, 100.,  nan,   3.,  nan,  nan])},
#  {'DOI': '10.1016/j.matchemphys.2009.01.023',
#   'target': 'Ba0.9Ca0.1TiO3',
#   'precursors': ['BaH6(CO)4', 'CaH6(CO)4', 'TiH36(C4O)4'],
#   'operation_types': ['StartingSynthesis',
#    'MixingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'DryingOperation',
#    'ShapingOperation',
#    'HeatingOperation',
#    'QuenchingOperation'],
#   'operation_tokens': ['prepared',
#    'dissolved',
#    'calcined',
#    'grinding',
#    'annealed',
#    'dried',
#    'pressed',
#    'sintered',
#    'cooled'],
#   'operation_times': [None, None, 2, None, None, None, None, 2, None],
#   'operation_temps': [None,
#    None,
#    1100.0,
#    None,
#    None,
#    None,
#    None,
#    1250.0,
#    None],
#   'temp_time_vector': array([1100., 1250.,   nan,   nan,    2.,    2.,   nan,   nan])},
#  {'DOI': '10.1016/j.materresbull.2007.12.017',
#   'target': 'CsTi0.5W1.5O6',
#   'precursors': ['CsNO3', 'TiO2', 'WO3'],
#   'operation_types': ['StartingSynthesis',
#    'HeatingOperation',
#    'MixingOperation',
#    'DryingOperation',
#    'ShapingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['prepared',
#    'sintering',
#    'milled',
#    'dried',
#    'pressed',
#    'fired'],
#   'operation_times': [None, 24, 16, None, None, 96],
#   'operation_temps': [None, 850.0, None, 90.0, None, 850.0],
#   'temp_time_vector': array([ nan, 850.,  nan,  90.,  nan,  24.,  nan,  nan])},
#  {'DOI': '10.1016/j.matlet.2004.11.021',
#   'target': 'ZnGa2O4',
#   'precursors': ['Ga2O3', 'ZnO'],
#   'operation_types': ['StartingSynthesis',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['fabricated', 'mixed', 'pressed', 'sintered'],
#   'operation_times': [None, None, None, 5],
#   'operation_temps': [None, None, None, 1350.0],
#   'temp_time_vector': array([  nan, 1350.,   nan,   nan,   nan,    5.,   nan,   nan])},
#  {'DOI': '10.1016/j.matlet.2004.11.021',
#   'target': 'Mn0.006Zn0.994Ga2O4',
#   'precursors': ['Ga2O3', 'MnO', 'ZnO'],
#   'operation_types': ['StartingSynthesis',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['fabricated', 'mixed', 'pressed', 'sintered'],
#   'operation_times': [None, None, None, 5],
#   'operation_temps': [None, None, None, 1350.0],
#   'temp_time_vector': array([  nan, 1350.,   nan,   nan,   nan,    5.,   nan,   nan])},
#  {'DOI': '10.1016/j.matlet.2004.11.021',
#   'target': 'ZnGa2O4',
#   'precursors': ['Ga2O3', 'ZnO'],
#   'operation_types': ['StartingSynthesis',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['fabricated', 'mixed', 'pressed', 'sintered'],
#   'operation_times': [None, None, None, 5],
#   'operation_temps': [None, None, None, 1350.0],
#   'temp_time_vector': array([  nan, 1350.,   nan,   nan,   nan,    5.,   nan,   nan])},
#  {'DOI': '10.1016/j.matlet.2004.11.021',
#   'target': 'Mn0.006Zn0.994Ga2O4',
#   'precursors': ['Ga2O3', 'MnO', 'ZnO'],
#   'operation_types': ['StartingSynthesis',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['fabricated', 'mixed', 'pressed', 'sintered'],
#   'operation_times': [None, None, None, 5],
#   'operation_temps': [None, None, None, 1350.0],
#   'temp_time_vector': array([  nan, 1350.,   nan,   nan,   nan,    5.,   nan,   nan])},
#  {'DOI': '10.1016/j.matlet.2012.05.056',
#   'target': 'LiMgNbAl2O7',
#   'precursors': ['Al(NO3)3', 'LiH3(CO)2', 'Mg(NO3)2', 'NbH25(C2O)5'],
#   'operation_types': ['StartingSynthesis',
#    'DryingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['synthesized',
#    'dried',
#    'calcined',
#    'ground',
#    'sintered',
#    'reground',
#    'pressed',
#    'heated'],
#   'operation_times': [None, None, 2, None, 24, None, None, 4],
#   'operation_temps': [None, 120.0, 900.0, None, 1200.0, None, None, 500.0],
#   'temp_time_vector': array([ 900., 1200.,   nan,  120.,    2.,   24.,   nan,   nan])},
#  {'DOI': '10.1016/j.msea.2007.06.080',
#   'target': 'Y2Al2O6',
#   'precursors': ['Al2O3', 'Y2O3'],
#   'operation_types': ['StartingSynthesis',
#    'MixingOperation',
#    'StartingSynthesis',
#    'HeatingOperation'],
#   'operation_tokens': ['prepared', 'mixing', 'prepared', 'sintering'],
#   'operation_times': [None, None, None, 2],
#   'operation_temps': [None, None, None, 1500.0],
#   'temp_time_vector': array([  nan, 1500.,   nan,   nan,   nan,    2.,   nan,   nan])},
#  {'DOI': '10.1016/j.optcom.2011.07.020',
#   'target': 'Yb3Al5O12',
#   'precursors': ['Al2O3', 'Yb2O3'],
#   'operation_types': ['MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['milled', 'pressed', 'sintered'],
#   'operation_times': [10, None, 8],
#   'operation_temps': [None, None, 1200.0],
#   'temp_time_vector': array([  nan, 1200.,   nan,   nan,   nan,    8.,   nan,   nan])},
#  ...]

# %%
targets = [x['target'] for x in papers]
precursors = [x['precursors'] for x in papers]
temps = [x['temp_time_vector'][5] for x in papers]
dois = [x['DOI'] for x in papers]

# %%
# get means
only_ss_rxns = []
for target, precs, temps, doi in zip(targets, precursors, temps, dois):
    if len(precs) == 0:
        continue
    found = False
    for result in only_ss_rxns:
        if result["target"] == target and set(result["precursors"]) == set(precs):
            result["ss_sinter_temps"].append(temps)
            result["DOIs"].append(doi)
            found = True
    if not found:
        new_result = {}
        new_result["target"] = target
        new_result["precursors"] = precs
        new_result["ss_sinter_temps"] = [temps]
        new_result["DOIs"] = [doi]
        only_ss_rxns.append(new_result)

# %%
times = [np.mean(x['ss_sinter_temps']) for x in only_ss_rxns]
X = np.zeros(len(times))
times = np.array(times)
X = np.array(X)

# %%
X, times = shuffle(X, times, random_state=42)

# %%
kf = KFold(n_splits=10, shuffle=False)
maes = []
rmses = []
r2s = []
mres = []

for train_index, test_index in kf.split(X):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = times[train_index], times[test_index]
    dummy_regr = DummyRegressor(strategy="mean")
    dummy_regr.fit(X_train, y_train)
    preds = dummy_regr.predict(X_test)
    

    mae = mean_absolute_error(y_test, preds)
    rmse = mean_squared_error(y_test, preds, squared=False)
    r2 = r2_score(y_test, preds)
    mre = np.mean((np.abs(y_test-preds)/y_test)*100)
    
    maes.append(mae)
    rmses.append(rmse)
    r2s.append(r2)
    mres.append(mre)

# %%
print(np.mean(maes), np.std(maes))
print(np.mean(rmses), np.std(rmses))
print(np.mean(r2s), np.std(r2s))
print(np.mean(mres), np.std(mres))
# Out:
# 8.336394074429613 0.27721324773874767
# 11.111730335104058 0.4470473828223249
# -0.0011752857461819755 0.0015930586258989994
# 173.92459043166807 4.619971213979469
