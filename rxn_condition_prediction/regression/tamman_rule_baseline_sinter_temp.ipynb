# %%
import json
import re
from pymatgen.core import Composition, Element
import pprint as pp
import copy
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pickle as pkl
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
import sys, os
sys.path.append('/home/jupyter/CJK/TempTime')
from data_extraction_rxn_classification_all_targets import *

# %%
all_elements = [Element.from_Z(i).symbol for i in range(1, 119)]

# %%
with open('/home/jupyter/CJK/TempTime/data/solid-state_dataset_20200713.json') as f:
    ss_data= json.load(f)
ss_reactions = ss_data["reactions"]
ss_extracted, ss_precursor_nomenclature = extract_solidstate(ss_reactions, max_pre=5)
# Out:
# Returning extracted data of 51574/31782 reactions.

# %%
with open('/home/jupyter/CJK/TempTime/data/ss_extracted_NO_IMPUTATION_precs_all_targets.pkl', 'rb') as f:
    papers = pkl.load(f)

# %%
papers = [x for x in papers if not np.isnan(x['temp_time_vector'][1])]

# %%
papers
# Out:
# [{'DOI': '10.1149/1.1828243',
#   'target': 'NdCoO3',
#   'precursors': ['Co3O4', 'Nd2O3'],
#   'operation_types': ['StartingSynthesis',
#    'HeatingOperation',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'DryingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['synthesized',
#    'fired',
#    'reground',
#    'pressed',
#    'sintered',
#    'regrinding',
#    'dissolved',
#    'dried',
#    'fired',
#    'ground',
#    'pressed',
#    'sintered'],
#   'operation_times': [None,
#    12,
#    None,
#    None,
#    24,
#    None,
#    None,
#    None,
#    5,
#    None,
#    None,
#    24],
#   'operation_temps': [None,
#    900.0,
#    None,
#    None,
#    1200.0,
#    None,
#    None,
#    None,
#    500.0,
#    None,
#    None,
#    1200.0],
#   'temp_time_vector': array([  nan, 1200.,   nan,   nan,   nan,   24.,   nan,   nan])},
#  {'DOI': '10.1149/1.1828243',
#   'target': 'Sr0.5Nd0.5CoO3',
#   'precursors': ['Co3O4', 'Nd2O3', 'SrCO3'],
#   'operation_types': ['StartingSynthesis',
#    'HeatingOperation',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'DryingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['synthesized',
#    'fired',
#    'reground',
#    'pressed',
#    'sintered',
#    'regrinding',
#    'dissolved',
#    'dried',
#    'fired',
#    'ground',
#    'pressed',
#    'sintered'],
#   'operation_times': [None,
#    12,
#    None,
#    None,
#    24,
#    None,
#    None,
#    None,
#    5,
#    None,
#    None,
#    24],
#   'operation_temps': [None,
#    900.0,
#    None,
#    None,
#    1200.0,
#    None,
#    None,
#    None,
#    500.0,
#    None,
#    None,
#    1200.0],
#   'temp_time_vector': array([  nan, 1200.,   nan,   nan,   nan,   24.,   nan,   nan])},
#  {'DOI': '10.1149/1.2103727',
#   'target': 'Sr0.4Pr0.6CoO3',
#   'precursors': ['Co2O3', 'Pr6O11', 'SrCO3'],
#   'operation_types': ['StartingSynthesis',
#    'StartingSynthesis',
#    'MixingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['prepared',
#    'synthesized',
#    'crushed',
#    'ballmilled',
#    'adding',
#    'sintered'],
#   'operation_times': [None, None, None, None, None, 5],
#   'operation_temps': [None, None, None, None, None, 1050.0],
#   'temp_time_vector': array([  nan, 1050.,   nan,   nan,   nan,    5.,   nan,   nan])},
#  {'DOI': '10.1149/1.2103727',
#   'target': 'Sr0.4Gd0.6CoO3',
#   'precursors': ['Co2O3', 'Gd2O3', 'SrCO3'],
#   'operation_types': ['StartingSynthesis',
#    'StartingSynthesis',
#    'MixingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['prepared',
#    'synthesized',
#    'crushed',
#    'ballmilled',
#    'adding',
#    'sintered'],
#   'operation_times': [None, None, None, None, None, 5],
#   'operation_temps': [None, None, None, None, None, 1050.0],
#   'temp_time_vector': array([  nan, 1050.,   nan,   nan,   nan,    5.,   nan,   nan])},
#  {'DOI': '10.1039/c2cp44394e',
#   'target': 'Li1.3Mn0.65Ni0.35O2.3',
#   'precursors': ['LiHO', 'MnO2', 'Ni(NO3)2'],
#   'operation_types': ['StartingSynthesis',
#    'MixingOperation',
#    'DryingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'StartingSynthesis',
#    'MixingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'DryingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'DryingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'DryingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['prepared',
#    'dispersed',
#    'evaporated',
#    'stirring',
#    'ground',
#    'heated',
#    'prepared',
#    'dissolved',
#    'adding',
#    'stirring',
#    'dried',
#    'stirring',
#    'treated',
#    'ground',
#    'dried',
#    'sintered',
#    'milled',
#    'dried',
#    'annealed'],
#   'operation_times': [None,
#    None,
#    None,
#    None,
#    None,
#    10,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    10,
#    None,
#    None,
#    10,
#    10,
#    None,
#    24],
#   'operation_temps': [None,
#    None,
#    50.0,
#    None,
#    None,
#    800.0,
#    None,
#    None,
#    None,
#    None,
#    120.0,
#    None,
#    400.0,
#    None,
#    80.0,
#    800.0,
#    None,
#    None,
#    800.0],
#   'temp_time_vector': array([ nan, 800., 800.,  80.,  nan,  10.,  24.,  nan])},
#  {'DOI': '10.1039/c5cp06742a',
#   'target': 'Sr0.19La0.76MnO3',
#   'precursors': ['La2O3', 'MnO2', 'SrCO3'],
#   'operation_types': ['StartingSynthesis',
#    'StartingSynthesis',
#    'MixingOperation',
#    'StartingSynthesis',
#    'MixingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['synthesized',
#    'synthesized',
#    'mixing',
#    'prepared',
#    'mixed',
#    'sintered'],
#   'operation_times': [None, None, 10, None, None, 3],
#   'operation_temps': [None, None, 1100.0, None, None, 800.0],
#   'temp_time_vector': array([ nan, 800.,  nan,  nan,  nan,   3.,  nan,  nan])},
#  {'DOI': '10.1021/nn405246h',
#   'target': 'Ca2.86Mg0.14P2O8',
#   'precursors': ['Ca(HO)2', 'Mg(HO)2', 'PH3O4'],
#   'operation_types': ['StartingSynthesis',
#    'MixingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'ShapingOperation',
#    'DryingOperation',
#    'StartingSynthesis',
#    'StartingSynthesis',
#    'MixingOperation',
#    'MixingOperation',
#    'ShapingOperation',
#    'DryingOperation',
#    'StartingSynthesis',
#    'StartingSynthesis',
#    'MixingOperation',
#    'MixingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['synthesized',
#    'mixed',
#    'added',
#    'stirring',
#    'pressed',
#    'dried',
#    'synthesized',
#    'prepared',
#    'added',
#    'stirring',
#    'pressed',
#    'dried',
#    'synthesized',
#    'prepared',
#    'mixed',
#    'milled',
#    'sintered'],
#   'operation_times': [None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    48,
#    2],
#   'operation_temps': [None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    1100.0],
#   'temp_time_vector': array([  nan, 1100.,   nan,   nan,   nan,    2.,   nan,   nan])},
#  {'DOI': '10.1021/cm800892z',
#   'target': 'Sr0.8La1.2CuO4',
#   'precursors': ['CuO', 'La2O3', 'SrCO3'],
#   'operation_types': ['StartingSynthesis',
#    'StartingSynthesis',
#    'MixingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'StartingSynthesis',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['synthesized',
#    'prepared',
#    'mixed',
#    'calcined',
#    'sintered',
#    'annealed',
#    'prepared',
#    'mixed',
#    'pressed',
#    'fired',
#    'postannealed',
#    'annealed'],
#   'operation_times': [None,
#    None,
#    None,
#    12,
#    20,
#    48,
#    None,
#    None,
#    None,
#    12,
#    24,
#    None],
#   'operation_temps': [None,
#    None,
#    None,
#    950.0,
#    1100.0,
#    500.0,
#    None,
#    None,
#    None,
#    1050.0,
#    1000.0,
#    None],
#   'temp_time_vector': array([ 950., 1100.,  500.,   nan,   12.,   20.,   48.,   nan])},
#  {'DOI': '10.1021/cm800892z',
#   'target': 'Sr2CuO4',
#   'precursors': ['CuO', 'SrCO3'],
#   'operation_types': ['StartingSynthesis',
#    'StartingSynthesis',
#    'MixingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'StartingSynthesis',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['synthesized',
#    'prepared',
#    'mixed',
#    'calcined',
#    'sintered',
#    'annealed',
#    'prepared',
#    'mixed',
#    'pressed',
#    'fired',
#    'postannealed',
#    'annealed'],
#   'operation_times': [None,
#    None,
#    None,
#    12,
#    20,
#    48,
#    None,
#    None,
#    None,
#    12,
#    24,
#    None],
#   'operation_temps': [None,
#    None,
#    None,
#    950.0,
#    1100.0,
#    500.0,
#    None,
#    None,
#    None,
#    1050.0,
#    1000.0,
#    None],
#   'temp_time_vector': array([ 950., 1100.,  500.,   nan,   12.,   20.,   48.,   nan])},
#  {'DOI': '10.1021/cm800892z',
#   'target': 'Sr1.2La0.8CuO4',
#   'precursors': ['CuO', 'La2O3', 'SrCO3'],
#   'operation_types': ['StartingSynthesis',
#    'StartingSynthesis',
#    'MixingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'StartingSynthesis',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['synthesized',
#    'prepared',
#    'mixed',
#    'calcined',
#    'sintered',
#    'annealed',
#    'prepared',
#    'mixed',
#    'pressed',
#    'fired',
#    'postannealed',
#    'annealed'],
#   'operation_times': [None,
#    None,
#    None,
#    12,
#    20,
#    48,
#    None,
#    None,
#    None,
#    12,
#    24,
#    None],
#   'operation_temps': [None,
#    None,
#    None,
#    950.0,
#    1100.0,
#    500.0,
#    None,
#    None,
#    None,
#    1050.0,
#    1000.0,
#    None],
#   'temp_time_vector': array([ 950., 1100.,  500.,   nan,   12.,   20.,   48.,   nan])},
#  {'DOI': '10.1021/cm800892z',
#   'target': 'Sr1.6La0.4CuO4',
#   'precursors': ['CuO', 'La2O3', 'SrCO3'],
#   'operation_types': ['StartingSynthesis',
#    'StartingSynthesis',
#    'MixingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'StartingSynthesis',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['synthesized',
#    'prepared',
#    'mixed',
#    'calcined',
#    'sintered',
#    'annealed',
#    'prepared',
#    'mixed',
#    'pressed',
#    'fired',
#    'postannealed',
#    'annealed'],
#   'operation_times': [None,
#    None,
#    None,
#    12,
#    20,
#    48,
#    None,
#    None,
#    None,
#    12,
#    24,
#    None],
#   'operation_temps': [None,
#    None,
#    None,
#    950.0,
#    1100.0,
#    500.0,
#    None,
#    None,
#    None,
#    1050.0,
#    1000.0,
#    None],
#   'temp_time_vector': array([ 950., 1100.,  500.,   nan,   12.,   20.,   48.,   nan])},
#  {'DOI': '10.1021/cm800892z',
#   'target': 'La2CuO4',
#   'precursors': ['CuO', 'La2O3'],
#   'operation_types': ['StartingSynthesis',
#    'StartingSynthesis',
#    'MixingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'StartingSynthesis',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['synthesized',
#    'prepared',
#    'mixed',
#    'calcined',
#    'sintered',
#    'annealed',
#    'prepared',
#    'mixed',
#    'pressed',
#    'fired',
#    'postannealed',
#    'annealed'],
#   'operation_times': [None,
#    None,
#    None,
#    12,
#    20,
#    48,
#    None,
#    None,
#    None,
#    12,
#    24,
#    None],
#   'operation_temps': [None,
#    None,
#    None,
#    950.0,
#    1100.0,
#    500.0,
#    None,
#    None,
#    None,
#    1050.0,
#    1000.0,
#    None],
#   'temp_time_vector': array([ 950., 1100.,  500.,   nan,   12.,   20.,   48.,   nan])},
#  {'DOI': '10.1021/cm800892z',
#   'target': 'Sr0.4La1.6CuO4',
#   'precursors': ['CuO', 'La2O3', 'SrCO3'],
#   'operation_types': ['StartingSynthesis',
#    'StartingSynthesis',
#    'MixingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'StartingSynthesis',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['synthesized',
#    'prepared',
#    'mixed',
#    'calcined',
#    'sintered',
#    'annealed',
#    'prepared',
#    'mixed',
#    'pressed',
#    'fired',
#    'postannealed',
#    'annealed'],
#   'operation_times': [None,
#    None,
#    None,
#    12,
#    20,
#    48,
#    None,
#    None,
#    None,
#    12,
#    24,
#    None],
#   'operation_temps': [None,
#    None,
#    None,
#    950.0,
#    1100.0,
#    500.0,
#    None,
#    None,
#    None,
#    1050.0,
#    1000.0,
#    None],
#   'temp_time_vector': array([ 950., 1100.,  500.,   nan,   12.,   20.,   48.,   nan])},
#  {'DOI': '10.1021/cm800892z',
#   'target': 'Nd0.8Ce1.2CuO4',
#   'precursors': ['Ce(NO3)3', 'CuO', 'Nd2O3'],
#   'operation_types': ['StartingSynthesis',
#    'StartingSynthesis',
#    'MixingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'StartingSynthesis',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['synthesized',
#    'prepared',
#    'mixed',
#    'calcined',
#    'sintered',
#    'annealed',
#    'prepared',
#    'mixed',
#    'pressed',
#    'fired',
#    'postannealed',
#    'annealed'],
#   'operation_times': [None,
#    None,
#    None,
#    12,
#    20,
#    48,
#    None,
#    None,
#    None,
#    12,
#    24,
#    None],
#   'operation_temps': [None,
#    None,
#    None,
#    950.0,
#    1100.0,
#    500.0,
#    None,
#    None,
#    None,
#    1050.0,
#    1000.0,
#    None],
#   'temp_time_vector': array([ 950., 1100.,  500.,   nan,   12.,   20.,   48.,   nan])},
#  {'DOI': '10.1021/cm800892z',
#   'target': 'Nd1.6Ce0.4CuO4',
#   'precursors': ['Ce(NO3)3', 'CuO', 'Nd2O3'],
#   'operation_types': ['StartingSynthesis',
#    'StartingSynthesis',
#    'MixingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'StartingSynthesis',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['synthesized',
#    'prepared',
#    'mixed',
#    'calcined',
#    'sintered',
#    'annealed',
#    'prepared',
#    'mixed',
#    'pressed',
#    'fired',
#    'postannealed',
#    'annealed'],
#   'operation_times': [None,
#    None,
#    None,
#    12,
#    20,
#    48,
#    None,
#    None,
#    None,
#    12,
#    24,
#    None],
#   'operation_temps': [None,
#    None,
#    None,
#    950.0,
#    1100.0,
#    500.0,
#    None,
#    None,
#    None,
#    1050.0,
#    1000.0,
#    None],
#   'temp_time_vector': array([ 950., 1100.,  500.,   nan,   12.,   20.,   48.,   nan])},
#  {'DOI': '10.1021/cm800892z',
#   'target': 'Nd2CuO4',
#   'precursors': ['CuO', 'Nd2O3'],
#   'operation_types': ['StartingSynthesis',
#    'StartingSynthesis',
#    'MixingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'StartingSynthesis',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['synthesized',
#    'prepared',
#    'mixed',
#    'calcined',
#    'sintered',
#    'annealed',
#    'prepared',
#    'mixed',
#    'pressed',
#    'fired',
#    'postannealed',
#    'annealed'],
#   'operation_times': [None,
#    None,
#    None,
#    12,
#    20,
#    48,
#    None,
#    None,
#    None,
#    12,
#    24,
#    None],
#   'operation_temps': [None,
#    None,
#    None,
#    950.0,
#    1100.0,
#    500.0,
#    None,
#    None,
#    None,
#    1050.0,
#    1000.0,
#    None],
#   'temp_time_vector': array([ 950., 1100.,  500.,   nan,   12.,   20.,   48.,   nan])},
#  {'DOI': '10.1021/cm800892z',
#   'target': 'Nd1.2Ce0.8CuO4',
#   'precursors': ['Ce(NO3)3', 'CuO', 'Nd2O3'],
#   'operation_types': ['StartingSynthesis',
#    'StartingSynthesis',
#    'MixingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'StartingSynthesis',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['synthesized',
#    'prepared',
#    'mixed',
#    'calcined',
#    'sintered',
#    'annealed',
#    'prepared',
#    'mixed',
#    'pressed',
#    'fired',
#    'postannealed',
#    'annealed'],
#   'operation_times': [None,
#    None,
#    None,
#    12,
#    20,
#    48,
#    None,
#    None,
#    None,
#    12,
#    24,
#    None],
#   'operation_temps': [None,
#    None,
#    None,
#    950.0,
#    1100.0,
#    500.0,
#    None,
#    None,
#    None,
#    1050.0,
#    1000.0,
#    None],
#   'temp_time_vector': array([ 950., 1100.,  500.,   nan,   12.,   20.,   48.,   nan])},
#  {'DOI': '10.1021/cm800892z',
#   'target': 'Ce2CuO4',
#   'precursors': ['Ce(NO3)3', 'CuO'],
#   'operation_types': ['StartingSynthesis',
#    'StartingSynthesis',
#    'MixingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'StartingSynthesis',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['synthesized',
#    'prepared',
#    'mixed',
#    'calcined',
#    'sintered',
#    'annealed',
#    'prepared',
#    'mixed',
#    'pressed',
#    'fired',
#    'postannealed',
#    'annealed'],
#   'operation_times': [None,
#    None,
#    None,
#    12,
#    20,
#    48,
#    None,
#    None,
#    None,
#    12,
#    24,
#    None],
#   'operation_temps': [None,
#    None,
#    None,
#    950.0,
#    1100.0,
#    500.0,
#    None,
#    None,
#    None,
#    1050.0,
#    1000.0,
#    None],
#   'temp_time_vector': array([ 950., 1100.,  500.,   nan,   12.,   20.,   48.,   nan])},
#  {'DOI': '10.1021/cm800892z',
#   'target': 'Nd0.4Ce1.6CuO4',
#   'precursors': ['Ce(NO3)3', 'CuO', 'Nd2O3'],
#   'operation_types': ['StartingSynthesis',
#    'StartingSynthesis',
#    'MixingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'StartingSynthesis',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['synthesized',
#    'prepared',
#    'mixed',
#    'calcined',
#    'sintered',
#    'annealed',
#    'prepared',
#    'mixed',
#    'pressed',
#    'fired',
#    'postannealed',
#    'annealed'],
#   'operation_times': [None,
#    None,
#    None,
#    12,
#    20,
#    48,
#    None,
#    None,
#    None,
#    12,
#    24,
#    None],
#   'operation_temps': [None,
#    None,
#    None,
#    950.0,
#    1100.0,
#    500.0,
#    None,
#    None,
#    None,
#    1050.0,
#    1000.0,
#    None],
#   'temp_time_vector': array([ 950., 1100.,  500.,   nan,   12.,   20.,   48.,   nan])},
#  {'DOI': '10.1021/cm401394x',
#   'target': 'BaCa0.1Y0.9Co2O5.5',
#   'precursors': ['BaCO3', 'CaCO3', 'Co(NO3)2', 'Y2O3'],
#   'operation_types': ['StartingSynthesis',
#    'MixingOperation',
#    'DryingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'DryingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'ShapingOperation',
#    'HeatingOperation',
#    'QuenchingOperation'],
#   'operation_tokens': ['prepared',
#    'dissolved',
#    'dried',
#    'added',
#    'stirred',
#    'heated',
#    'added',
#    'held',
#    'stirring',
#    'dried',
#    'ground',
#    'calcined',
#    'pressed',
#    'sintered',
#    'cooled'],
#   'operation_times': [None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    50,
#    None,
#    3,
#    None,
#    25,
#    None],
#   'operation_temps': [None,
#    None,
#    None,
#    None,
#    None,
#    80.0,
#    None,
#    None,
#    None,
#    100.0,
#    None,
#    450.0,
#    None,
#    1000.0,
#    None],
#   'temp_time_vector': array([ 450., 1000.,   nan,  100.,    3.,   25.,   nan,   nan])},
#  {'DOI': '10.1021/cm401394x',
#   'target': 'Ca10Y',
#   'precursors': ['CaCO3', 'Y2O3'],
#   'operation_types': ['StartingSynthesis',
#    'MixingOperation',
#    'DryingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'DryingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'ShapingOperation',
#    'HeatingOperation',
#    'QuenchingOperation'],
#   'operation_tokens': ['prepared',
#    'dissolved',
#    'dried',
#    'added',
#    'stirred',
#    'heated',
#    'added',
#    'held',
#    'stirring',
#    'dried',
#    'ground',
#    'calcined',
#    'pressed',
#    'sintered',
#    'cooled'],
#   'operation_times': [None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    50,
#    None,
#    3,
#    None,
#    25,
#    None],
#   'operation_temps': [None,
#    None,
#    None,
#    None,
#    None,
#    80.0,
#    None,
#    None,
#    None,
#    100.0,
#    None,
#    450.0,
#    None,
#    1000.0,
#    None],
#   'temp_time_vector': array([ 450., 1000.,   nan,  100.,    3.,   25.,   nan,   nan])},
#  {'DOI': '10.1021/cm401394x',
#   'target': 'Ba0.9Ca0.1YCo2O5.5',
#   'precursors': ['BaCO3', 'CaCO3', 'Co(NO3)2', 'Y2O3'],
#   'operation_types': ['StartingSynthesis',
#    'MixingOperation',
#    'DryingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'DryingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'ShapingOperation',
#    'HeatingOperation',
#    'QuenchingOperation'],
#   'operation_tokens': ['prepared',
#    'dissolved',
#    'dried',
#    'added',
#    'stirred',
#    'heated',
#    'added',
#    'held',
#    'stirring',
#    'dried',
#    'ground',
#    'calcined',
#    'pressed',
#    'sintered',
#    'cooled'],
#   'operation_times': [None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    50,
#    None,
#    3,
#    None,
#    25,
#    None],
#   'operation_temps': [None,
#    None,
#    None,
#    None,
#    None,
#    80.0,
#    None,
#    None,
#    None,
#    100.0,
#    None,
#    450.0,
#    None,
#    1000.0,
#    None],
#   'temp_time_vector': array([ 450., 1000.,   nan,  100.,    3.,   25.,   nan,   nan])},
#  {'DOI': '10.1021/cm401394x',
#   'target': 'BaCa10',
#   'precursors': ['BaCO3', 'CaCO3'],
#   'operation_types': ['StartingSynthesis',
#    'MixingOperation',
#    'DryingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'DryingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'ShapingOperation',
#    'HeatingOperation',
#    'QuenchingOperation'],
#   'operation_tokens': ['prepared',
#    'dissolved',
#    'dried',
#    'added',
#    'stirred',
#    'heated',
#    'added',
#    'held',
#    'stirring',
#    'dried',
#    'ground',
#    'calcined',
#    'pressed',
#    'sintered',
#    'cooled'],
#   'operation_times': [None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    50,
#    None,
#    3,
#    None,
#    25,
#    None],
#   'operation_temps': [None,
#    None,
#    None,
#    None,
#    None,
#    80.0,
#    None,
#    None,
#    None,
#    100.0,
#    None,
#    450.0,
#    None,
#    1000.0,
#    None],
#   'temp_time_vector': array([ 450., 1000.,   nan,  100.,    3.,   25.,   nan,   nan])},
#  {'DOI': '10.1021/jp511931y',
#   'target': 'LaMnO3',
#   'precursors': ['La(NO3)3', 'Mn2O3'],
#   'operation_types': ['StartingSynthesis',
#    'DryingOperation',
#    'StartingSynthesis',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation',
#    'StartingSynthesis',
#    'MixingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['synthesized',
#    'dried',
#    'prepared',
#    'ground',
#    'pressed',
#    'sintered',
#    'reground',
#    'pressed',
#    'sintered',
#    'synthesized',
#    'dissolved',
#    'added',
#    'heated',
#    'calcined',
#    'ground',
#    'pressed',
#    'sintered',
#    'reground',
#    'pressed',
#    'sintered'],
#   'operation_times': [None,
#    8,
#    None,
#    None,
#    None,
#    12,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    10,
#    None,
#    None,
#    12,
#    None,
#    None,
#    None],
#   'operation_temps': [None,
#    800.0,
#    None,
#    None,
#    None,
#    1100.0,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    400.0,
#    None,
#    None,
#    1100.0,
#    None,
#    None,
#    None],
#   'temp_time_vector': array([ 400., 1100.,   nan,  800.,   10.,   12.,   nan,    8.])},
#  {'DOI': '10.1021/jp511931y',
#   'target': 'LaFeO3',
#   'precursors': ['Fe2O3', 'La(NO3)3'],
#   'operation_types': ['StartingSynthesis',
#    'DryingOperation',
#    'StartingSynthesis',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation',
#    'StartingSynthesis',
#    'MixingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['synthesized',
#    'dried',
#    'prepared',
#    'ground',
#    'pressed',
#    'sintered',
#    'reground',
#    'pressed',
#    'sintered',
#    'synthesized',
#    'dissolved',
#    'added',
#    'heated',
#    'calcined',
#    'ground',
#    'pressed',
#    'sintered',
#    'reground',
#    'pressed',
#    'sintered'],
#   'operation_times': [None,
#    8,
#    None,
#    None,
#    None,
#    12,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    10,
#    None,
#    None,
#    12,
#    None,
#    None,
#    None],
#   'operation_temps': [None,
#    800.0,
#    None,
#    None,
#    None,
#    1100.0,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    400.0,
#    None,
#    None,
#    1100.0,
#    None,
#    None,
#    None],
#   'temp_time_vector': array([ 400., 1100.,   nan,  800.,   10.,   12.,   nan,    8.])},
#  {'DOI': '10.1021/jp511931y',
#   'target': 'LaCoO3',
#   'precursors': ['Co3O4', 'La(NO3)3'],
#   'operation_types': ['StartingSynthesis',
#    'DryingOperation',
#    'StartingSynthesis',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation',
#    'StartingSynthesis',
#    'MixingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['synthesized',
#    'dried',
#    'prepared',
#    'ground',
#    'pressed',
#    'sintered',
#    'reground',
#    'pressed',
#    'sintered',
#    'synthesized',
#    'dissolved',
#    'added',
#    'heated',
#    'calcined',
#    'ground',
#    'pressed',
#    'sintered',
#    'reground',
#    'pressed',
#    'sintered'],
#   'operation_times': [None,
#    8,
#    None,
#    None,
#    None,
#    12,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    10,
#    None,
#    None,
#    12,
#    None,
#    None,
#    None],
#   'operation_temps': [None,
#    800.0,
#    None,
#    None,
#    None,
#    1100.0,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    400.0,
#    None,
#    None,
#    1100.0,
#    None,
#    None,
#    None],
#   'temp_time_vector': array([ 400., 1100.,   nan,  800.,   10.,   12.,   nan,    8.])},
#  {'DOI': '10.1007/s10008-014-2603-z',
#   'target': 'Li2FeSiO4',
#   'precursors': ['Fe(CO2)2', 'LiH3(CO)2', 'SiH20(C2O)4'],
#   'operation_types': ['StartingSynthesis',
#    'MixingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'DryingOperation',
#    'MixingOperation',
#    'DryingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'QuenchingOperation',
#    'MixingOperation',
#    'StartingSynthesis'],
#   'operation_tokens': ['synthesized',
#    'dispersed',
#    'refluxed',
#    'stirring',
#    'dried',
#    'ground',
#    'drying',
#    'calcined',
#    'sintered',
#    'cooling',
#    'ground',
#    'synthesized'],
#   'operation_times': [None,
#    None,
#    24,
#    None,
#    None,
#    None,
#    None,
#    5,
#    10,
#    None,
#    None,
#    None],
#   'operation_temps': [None,
#    None,
#    80.0,
#    None,
#    50.0,
#    None,
#    None,
#    350.0,
#    650.0,
#    None,
#    None,
#    None],
#   'temp_time_vector': array([350., 650.,  nan,  50.,   5.,  10.,  nan,  nan])},
#  {'DOI': '10.1038/srep04059',
#   'target': 'Zn3Ga2Ge2O10',
#   'precursors': ['Ga2O3', 'GeO2', 'ZnO'],
#   'operation_types': ['ShapingOperation',
#    'StartingSynthesis',
#    'HeatingOperation',
#    'ShapingOperation',
#    'HeatingOperation',
#    'StartingSynthesis',
#    'MixingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'DryingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['compacted',
#    'produced',
#    'calcination',
#    'pressed',
#    'sintered',
#    'prepared',
#    'dissolving',
#    'stirred',
#    'added',
#    'heated',
#    'dried',
#    'calcinated'],
#   'operation_times': [None,
#    None,
#    4,
#    None,
#    None,
#    None,
#    None,
#    1,
#    None,
#    None,
#    24,
#    3],
#   'operation_temps': [None,
#    None,
#    1000.0,
#    None,
#    1350.0,
#    None,
#    None,
#    None,
#    None,
#    70.0,
#    110.0,
#    900.0],
#   'temp_time_vector': array([ 900., 1350.,   nan,  110.,    3.,   nan,   nan,   24.])},
#  {'DOI': '10.1039/c2cp44394e',
#   'target': 'Li1.3Mn0.65Ni0.35O2.3',
#   'precursors': ['LiHO', 'MnO2', 'Ni(NO3)2'],
#   'operation_types': ['StartingSynthesis',
#    'MixingOperation',
#    'DryingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'StartingSynthesis',
#    'MixingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'DryingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'DryingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'DryingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['prepared',
#    'dispersed',
#    'evaporated',
#    'stirring',
#    'ground',
#    'heated',
#    'prepared',
#    'dissolved',
#    'adding',
#    'stirring',
#    'dried',
#    'stirring',
#    'treated',
#    'ground',
#    'dried',
#    'sintered',
#    'milled',
#    'dried',
#    'annealed'],
#   'operation_times': [None,
#    None,
#    None,
#    None,
#    None,
#    10,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    10,
#    None,
#    None,
#    10,
#    10,
#    None,
#    24],
#   'operation_temps': [None,
#    None,
#    50.0,
#    None,
#    None,
#    800.0,
#    None,
#    None,
#    None,
#    None,
#    120.0,
#    None,
#    400.0,
#    None,
#    80.0,
#    800.0,
#    None,
#    None,
#    800.0],
#   'temp_time_vector': array([ nan, 800., 800.,  80.,  nan,  10.,  24.,  nan])},
#  {'DOI': '10.1039/c7tc05422j',
#   'target': 'BaYCo2O',
#   'precursors': ['BaCO3', 'Co3O4', 'Y2O3'],
#   'operation_types': ['StartingSynthesis',
#    'MixingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'MixingOperation'],
#   'operation_tokens': ['prepared',
#    'mixed',
#    'pre-sintering',
#    'sintering',
#    'maintained',
#    'maintained',
#    'adjusted',
#    'adding'],
#   'operation_times': [None, None, 12, 24, None, None, None, None],
#   'operation_temps': [None, None, 950.0, 1100.0, None, None, None, None],
#   'temp_time_vector': array([  nan, 1100.,   nan,   nan,   nan,   24.,   nan,   nan])},
#  {'DOI': '10.1039/c1jm11551k',
#   'target': 'LiFePO4',
#   'precursors': ['FePO4', 'LiH3(CO)2'],
#   'operation_types': ['StartingSynthesis',
#    'MixingOperation',
#    'StartingSynthesis',
#    'MixingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'DryingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'StartingSynthesis'],
#   'operation_tokens': ['prepared',
#    'dissolved',
#    'prepared',
#    'mixed',
#    'stirring',
#    'heated',
#    'dried',
#    'grinding',
#    'sintered',
#    'prepared'],
#   'operation_times': [None, None, None, None, None, None, None, None, 7, None],
#   'operation_temps': [None,
#    60.0,
#    None,
#    None,
#    None,
#    80.0,
#    None,
#    None,
#    650.0,
#    None],
#   'temp_time_vector': array([ nan, 650.,  nan,  nan,  nan,   7.,  nan,  nan])},
#  {'DOI': '10.1039/c5cp06742a',
#   'target': 'Sr0.19La0.76MnO3',
#   'precursors': ['La2O3', 'MnO2', 'SrCO3'],
#   'operation_types': ['StartingSynthesis',
#    'StartingSynthesis',
#    'MixingOperation',
#    'StartingSynthesis',
#    'MixingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['synthesized',
#    'synthesized',
#    'mixing',
#    'prepared',
#    'mixed',
#    'sintered'],
#   'operation_times': [None, None, 10, None, None, 3],
#   'operation_temps': [None, None, 1100.0, None, None, 800.0],
#   'temp_time_vector': array([ nan, 800.,  nan,  nan,  nan,   3.,  nan,  nan])},
#  {'DOI': '10.1016/j.jnucmat.2013.02.060',
#   'target': 'Li2TiO3',
#   'precursors': ['Li2CO3', 'TiO2'],
#   'operation_types': ['StartingSynthesis',
#    'StartingSynthesis',
#    'HeatingOperation',
#    'MixingOperation',
#    'StartingSynthesis',
#    'HeatingOperation',
#    'StartingSynthesis',
#    'StartingSynthesis',
#    'MixingOperation',
#    'DryingOperation',
#    'HeatingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['synthesized',
#    'synthesized',
#    'calcined',
#    'milled',
#    'fabricated',
#    'sintered',
#    'prepared',
#    'prepared',
#    'washed',
#    'dried',
#    'calcined',
#    'sintered'],
#   'operation_times': [None,
#    None,
#    24,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None],
#   'operation_temps': [None,
#    None,
#    900.0,
#    None,
#    None,
#    900.0,
#    None,
#    None,
#    None,
#    None,
#    None,
#    1000.0],
#   'temp_time_vector': array([ 900., 1000.,   nan,   nan,   24.,   nan,   nan,   nan])},
#  {'DOI': '10.1016/j.jssc.2005.02.003',
#   'target': 'Ba2PrIrO6',
#   'precursors': ['BaCO3', 'Ir', 'Pr6O11'],
#   'operation_types': ['StartingSynthesis',
#    'HeatingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'QuenchingOperation'],
#   'operation_tokens': ['prepared',
#    'reacted',
#    'sintered',
#    'regrinding',
#    'cooled'],
#   'operation_times': [None, None, None, None, None],
#   'operation_temps': [None, 900.0, 1250.0, None, None],
#   'temp_time_vector': array([  nan, 1250.,   nan,   nan,   nan,   nan,   nan,   nan])},
#  {'DOI': '10.1016/j.jssc.2009.04.036',
#   'target': 'Li2Mo2ZnO8',
#   'precursors': ['Li2MoO4', 'ZnMoO4'],
#   'operation_types': ['HeatingOperation',
#    'StartingSynthesis',
#    'StartingSynthesis',
#    'HeatingOperation',
#    'QuenchingOperation'],
#   'operation_tokens': ['calcined',
#    'prepared',
#    'prepared',
#    'sintered',
#    'quenched'],
#   'operation_times': [5, None, None, 83, None],
#   'operation_temps': [500.0, None, None, 600.0, None],
#   'temp_time_vector': array([500., 600.,  nan,  nan,   5.,  nan,  nan,  nan])},
#  {'DOI': '10.1016/j.jlumin.2011.05.060',
#   'target': 'Sr4Al14O25',
#   'precursors': ['Al2O3', 'SrCO3'],
#   'operation_types': ['MixingOperation',
#    'HeatingOperation',
#    'StartingSynthesis',
#    'MixingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'DryingOperation',
#    'HeatingOperation',
#    'DryingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['ground',
#    'preheated',
#    'prepared',
#    'dissolved',
#    'heated',
#    'added',
#    'added',
#    'stirred',
#    'concentrating',
#    'raised',
#    'dried',
#    'ground',
#    'preheated',
#    'sintered'],
#   'operation_times': [None,
#    4,
#    None,
#    None,
#    None,
#    None,
#    None,
#    1,
#    None,
#    None,
#    None,
#    None,
#    4,
#    8],
#   'operation_temps': [None,
#    1000.0,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    250.0,
#    120.0,
#    None,
#    1000.0,
#    1400.0],
#   'temp_time_vector': array([  nan, 1400.,   nan,  120.,   nan,    8.,   nan,   nan])},
#  {'DOI': '10.1016/j.optmat.2015.10.019',
#   'target': 'GdOCl',
#   'precursors': ['Gd2O3', 'H4NCl'],
#   'operation_types': ['StartingSynthesis',
#    'MixingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'DryingOperation',
#    'MixingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['prepared',
#    'dissolved',
#    'stirring',
#    'added',
#    'stirred',
#    'dried',
#    'ground',
#    'sintered'],
#   'operation_times': [None, None, None, None, None, 12, None, 1],
#   'operation_temps': [None, None, None, None, None, 80.0, None, 1000.0],
#   'temp_time_vector': array([  nan, 1000.,   nan,   80.,   nan,    1.,   nan,   12.])},
#  {'DOI': '10.1016/j.ssnmr.2012.01.003',
#   'target': 'LaGaO3',
#   'precursors': ['Ga2O3', 'La2O3'],
#   'operation_types': ['StartingSynthesis',
#    'HeatingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['prepared',
#    'heated',
#    'heated',
#    'mixed',
#    'sintered',
#    'ground',
#    're-pressed',
#    're-sintered'],
#   'operation_times': [None, None, None, None, None, None, None, 12],
#   'operation_temps': [None, 1000.0, 1000.0, None, 1500.0, None, None, 1700.0],
#   'temp_time_vector': array([  nan, 1700.,   nan,   nan,   nan,   12.,   nan,   nan])},
#  {'DOI': '10.1016/j.ssnmr.2012.01.003',
#   'target': 'LaAlO3',
#   'precursors': ['Al2O3', 'La2O3'],
#   'operation_types': ['StartingSynthesis',
#    'HeatingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['prepared',
#    'heated',
#    'heated',
#    'mixed',
#    'sintered',
#    'ground',
#    're-pressed',
#    're-sintered'],
#   'operation_times': [None, None, None, None, None, None, None, 12],
#   'operation_temps': [None, 1000.0, 1000.0, None, 1500.0, None, None, 1700.0],
#   'temp_time_vector': array([  nan, 1700.,   nan,   nan,   nan,   12.,   nan,   nan])},
#  {'DOI': '10.1016/j.ijhydene.2014.12.017',
#   'target': 'BaZrO3',
#   'precursors': ['BaCO3', 'ZrO2'],
#   'operation_types': ['StartingSynthesis',
#    'HeatingOperation',
#    'StartingSynthesis',
#    'StartingSynthesis',
#    'HeatingOperation',
#    'StartingSynthesis',
#    'StartingSynthesis'],
#   'operation_tokens': ['prepared',
#    'calcining',
#    'synthesized',
#    'prepared',
#    'sintering',
#    'prepared',
#    'prepared'],
#   'operation_times': [None, 10, None, None, None, None, None],
#   'operation_temps': [None, 1300.0, None, None, 1327.0, None, None],
#   'temp_time_vector': array([1300., 1327.,   nan,   nan,   10.,   nan,   nan,   nan])},
#  {'DOI': '10.1016/j.ijhydene.2014.12.017',
#   'target': 'BaY0.15Zr0.85O3',
#   'precursors': ['BaCO3', 'Y2O3', 'ZrO2'],
#   'operation_types': ['StartingSynthesis',
#    'HeatingOperation',
#    'StartingSynthesis',
#    'StartingSynthesis',
#    'HeatingOperation',
#    'StartingSynthesis',
#    'StartingSynthesis'],
#   'operation_tokens': ['prepared',
#    'calcining',
#    'synthesized',
#    'prepared',
#    'sintering',
#    'prepared',
#    'prepared'],
#   'operation_times': [None, 10, None, None, None, None, None],
#   'operation_temps': [None, 1300.0, None, None, 1327.0, None, None],
#   'temp_time_vector': array([1300., 1327.,   nan,   nan,   10.,   nan,   nan,   nan])},
#  {'DOI': '10.1016/j.ssi.2004.03.041',
#   'target': 'SrCe0.95Y0.05O3',
#   'precursors': ['CeO2', 'SrCO3', 'Y2O3'],
#   'operation_types': ['HeatingOperation',
#    'StartingSynthesis',
#    'ShapingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['sintered',
#    'prepared',
#    'pressed',
#    'sintered',
#    'annealed',
#    'annealed',
#    'annealed'],
#   'operation_times': [None, None, None, 20, None, None, None],
#   'operation_temps': [None, None, None, 1250.0, None, None, None],
#   'temp_time_vector': array([  nan, 1250.,   nan,   nan,   nan,   20.,   nan,   nan])},
#  {'DOI': '10.1016/j.ssi.2004.03.041',
#   'target': 'SrCeO3',
#   'precursors': ['CeO2', 'SrCO3'],
#   'operation_types': ['HeatingOperation',
#    'StartingSynthesis',
#    'ShapingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['sintered',
#    'prepared',
#    'pressed',
#    'sintered',
#    'annealed',
#    'annealed',
#    'annealed'],
#   'operation_times': [None, None, None, 20, None, None, None],
#   'operation_temps': [None, None, None, 1250.0, None, None, None],
#   'temp_time_vector': array([  nan, 1250.,   nan,   nan,   nan,   20.,   nan,   nan])},
#  {'DOI': '10.1016/j.ssi.2007.12.027',
#   'target': 'Sr0.5La0.5FeO3',
#   'precursors': ['Fe(NO3)3', 'La2O3', 'SrCO3'],
#   'operation_types': ['StartingSynthesis',
#    'HeatingOperation',
#    'StartingSynthesis',
#    'StartingSynthesis',
#    'StartingSynthesis',
#    'ShapingOperation',
#    'HeatingOperation',
#    'DryingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['synthesized',
#    'annealed',
#    'prepared',
#    'prepared',
#    'fabricated',
#    'pressing',
#    'sintering',
#    'drying',
#    'annealing'],
#   'operation_times': [None, 2, None, None, None, None, 5, None, None],
#   'operation_temps': [None,
#    1200.0,
#    None,
#    None,
#    None,
#    None,
#    1350.0,
#    None,
#    1120.0],
#   'temp_time_vector': array([  nan, 1350., 1120.,   nan,   nan,    5.,   nan,   nan])},
#  {'DOI': '10.1016/j.ssi.2013.04.009',
#   'target': 'Nb0.6V1.4Bi4O11',
#   'precursors': ['Bi2O3', 'Nb2O5', 'V2O5'],
#   'operation_types': ['MixingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'DryingOperation',
#    'HeatingOperation',
#    'QuenchingOperation',
#    'HeatingOperation',
#    'ShapingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['dissolving',
#    'added',
#    'added',
#    'stirred',
#    'added',
#    'dried',
#    'annealing',
#    'cooled',
#    'sintered',
#    'pressed',
#    'annealed'],
#   'operation_times': [None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    2],
#   'operation_temps': [None,
#    None,
#    None,
#    None,
#    None,
#    200.0,
#    None,
#    None,
#    830.0,
#    None,
#    820.0],
#   'temp_time_vector': array([ nan, 830., 820., 200.,  nan,  nan,   2.,  nan])},
#  {'DOI': '10.1016/j.ssi.2013.04.009',
#   'target': 'Nb0.4V1.6Bi4O11',
#   'precursors': ['Bi2O3', 'Nb2O5', 'V2O5'],
#   'operation_types': ['MixingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'DryingOperation',
#    'HeatingOperation',
#    'QuenchingOperation',
#    'HeatingOperation',
#    'ShapingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['dissolving',
#    'added',
#    'added',
#    'stirred',
#    'added',
#    'dried',
#    'annealing',
#    'cooled',
#    'sintered',
#    'pressed',
#    'annealed'],
#   'operation_times': [None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    2],
#   'operation_temps': [None,
#    None,
#    None,
#    None,
#    None,
#    200.0,
#    None,
#    None,
#    830.0,
#    None,
#    820.0],
#   'temp_time_vector': array([ nan, 830., 820., 200.,  nan,  nan,   2.,  nan])},
#  {'DOI': '10.1016/j.ssi.2013.04.009',
#   'target': 'NbVBi4O11',
#   'precursors': ['Bi2O3', 'Nb2O5', 'V2O5'],
#   'operation_types': ['MixingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'DryingOperation',
#    'HeatingOperation',
#    'QuenchingOperation',
#    'HeatingOperation',
#    'ShapingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['dissolving',
#    'added',
#    'added',
#    'stirred',
#    'added',
#    'dried',
#    'annealing',
#    'cooled',
#    'sintered',
#    'pressed',
#    'annealed'],
#   'operation_times': [None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    2],
#   'operation_temps': [None,
#    None,
#    None,
#    None,
#    None,
#    200.0,
#    None,
#    None,
#    830.0,
#    None,
#    820.0],
#   'temp_time_vector': array([ nan, 830., 820., 200.,  nan,  nan,   2.,  nan])},
#  {'DOI': '10.1016/j.ssi.2013.04.009',
#   'target': 'V2Bi4O11',
#   'precursors': ['Bi2O3', 'V2O5'],
#   'operation_types': ['MixingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'DryingOperation',
#    'HeatingOperation',
#    'QuenchingOperation',
#    'HeatingOperation',
#    'ShapingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['dissolving',
#    'added',
#    'added',
#    'stirred',
#    'added',
#    'dried',
#    'annealing',
#    'cooled',
#    'sintered',
#    'pressed',
#    'annealed'],
#   'operation_times': [None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    2],
#   'operation_temps': [None,
#    None,
#    None,
#    None,
#    None,
#    200.0,
#    None,
#    None,
#    830.0,
#    None,
#    820.0],
#   'temp_time_vector': array([ nan, 830., 820., 200.,  nan,  nan,   2.,  nan])},
#  {'DOI': '10.1016/j.ssi.2013.04.009',
#   'target': 'Nb0.8V1.2Bi4O11',
#   'precursors': ['Bi2O3', 'Nb2O5', 'V2O5'],
#   'operation_types': ['MixingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'DryingOperation',
#    'HeatingOperation',
#    'QuenchingOperation',
#    'HeatingOperation',
#    'ShapingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['dissolving',
#    'added',
#    'added',
#    'stirred',
#    'added',
#    'dried',
#    'annealing',
#    'cooled',
#    'sintered',
#    'pressed',
#    'annealed'],
#   'operation_times': [None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    2],
#   'operation_temps': [None,
#    None,
#    None,
#    None,
#    None,
#    200.0,
#    None,
#    None,
#    830.0,
#    None,
#    820.0],
#   'temp_time_vector': array([ nan, 830., 820., 200.,  nan,  nan,   2.,  nan])},
#  {'DOI': '10.1016/j.ssi.2013.04.009',
#   'target': 'Nb0.2V1.8Bi4O11',
#   'precursors': ['Bi2O3', 'Nb2O5', 'V2O5'],
#   'operation_types': ['MixingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'DryingOperation',
#    'HeatingOperation',
#    'QuenchingOperation',
#    'HeatingOperation',
#    'ShapingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['dissolving',
#    'added',
#    'added',
#    'stirred',
#    'added',
#    'dried',
#    'annealing',
#    'cooled',
#    'sintered',
#    'pressed',
#    'annealed'],
#   'operation_times': [None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    2],
#   'operation_temps': [None,
#    None,
#    None,
#    None,
#    None,
#    200.0,
#    None,
#    None,
#    830.0,
#    None,
#    820.0],
#   'temp_time_vector': array([ nan, 830., 820., 200.,  nan,  nan,   2.,  nan])},
#  {'DOI': '10.1016/j.ssi.2013.05.001',
#   'target': 'SrTa0.33Fe0.67O3',
#   'precursors': ['Fe2O3', 'SrCO3', 'Ta2O5'],
#   'operation_types': ['HeatingOperation',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['pre-annealed',
#    'mixed',
#    'pressed',
#    'calcined',
#    'regrinding',
#    'sintered'],
#   'operation_times': [None, None, None, 10, None, None],
#   'operation_temps': [None, None, None, 1000.0, None, 1450.0],
#   'temp_time_vector': array([1000., 1450.,   nan,   nan,   10.,   nan,   nan,   nan])},
#  {'DOI': '10.1016/j.apsusc.2011.03.082',
#   'target': 'Tb0.2Y',
#   'precursors': ['Tb2O3', 'Tb4O7', 'Y2O3'],
#   'operation_types': ['StartingSynthesis',
#    'StartingSynthesis',
#    'StartingSynthesis',
#    'MixingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['synthesized',
#    'prepared',
#    'prepared',
#    'suspended',
#    'sintered',
#    'mixed',
#    'fired'],
#   'operation_times': [None, None, None, None, None, None, None],
#   'operation_temps': [None, None, None, None, 1000.0, None, 500.0],
#   'temp_time_vector': array([  nan, 1000.,   nan,   nan,   nan,   nan,   nan,   nan])},
#  {'DOI': '10.1016/j.apsusc.2011.03.082',
#   'target': 'Tb0.4Y',
#   'precursors': ['Tb2O3', 'Tb4O7', 'Y2O3'],
#   'operation_types': ['StartingSynthesis',
#    'StartingSynthesis',
#    'StartingSynthesis',
#    'MixingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['synthesized',
#    'prepared',
#    'prepared',
#    'suspended',
#    'sintered',
#    'mixed',
#    'fired'],
#   'operation_times': [None, None, None, None, None, None, None],
#   'operation_temps': [None, None, None, None, 1000.0, None, 500.0],
#   'temp_time_vector': array([  nan, 1000.,   nan,   nan,   nan,   nan,   nan,   nan])},
#  {'DOI': '10.1016/j.apsusc.2011.03.082',
#   'target': 'Tb0.8Y',
#   'precursors': ['Tb2O3', 'Tb4O7', 'Y2O3'],
#   'operation_types': ['StartingSynthesis',
#    'StartingSynthesis',
#    'StartingSynthesis',
#    'MixingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['synthesized',
#    'prepared',
#    'prepared',
#    'suspended',
#    'sintered',
#    'mixed',
#    'fired'],
#   'operation_times': [None, None, None, None, None, None, None],
#   'operation_temps': [None, None, None, None, 1000.0, None, 500.0],
#   'temp_time_vector': array([  nan, 1000.,   nan,   nan,   nan,   nan,   nan,   nan])},
#  {'DOI': '10.1016/j.apsusc.2011.03.082',
#   'target': 'TbY',
#   'precursors': ['Tb2O3', 'Tb4O7', 'Y2O3'],
#   'operation_types': ['StartingSynthesis',
#    'StartingSynthesis',
#    'StartingSynthesis',
#    'MixingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['synthesized',
#    'prepared',
#    'prepared',
#    'suspended',
#    'sintered',
#    'mixed',
#    'fired'],
#   'operation_times': [None, None, None, None, None, None, None],
#   'operation_temps': [None, None, None, None, 1000.0, None, 500.0],
#   'temp_time_vector': array([  nan, 1000.,   nan,   nan,   nan,   nan,   nan,   nan])},
#  {'DOI': '10.1016/j.apsusc.2011.03.082',
#   'target': 'Tb0.6Y',
#   'precursors': ['Tb2O3', 'Tb4O7', 'Y2O3'],
#   'operation_types': ['StartingSynthesis',
#    'StartingSynthesis',
#    'StartingSynthesis',
#    'MixingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['synthesized',
# ...
#    'MixingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['prepared',
#    'mixed',
#    'heated',
#    'milled',
#    'heated',
#    'sintered'],
#   'operation_times': [None, None, 20, None, 10, 20],
#   'operation_temps': [None, None, 1000.0, None, 1400.0, 1600.0],
#   'temp_time_vector': array([  nan, 1600.,   nan,   nan,   nan,   20.,   nan,   nan])},
#  {'DOI': '10.1016/s0167-2738(02)00511-8',
#   'target': 'Ba3Ca1.25Nb1.75O9',
#   'precursors': ['BaCO3', 'CaCO3', 'Nb2O5'],
#   'operation_types': ['StartingSynthesis',
#    'MixingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['prepared',
#    'mixed',
#    'heated',
#    'milled',
#    'heated',
#    'sintered'],
#   'operation_times': [None, None, 20, None, 10, 20],
#   'operation_temps': [None, None, 1000.0, None, 1400.0, 1600.0],
#   'temp_time_vector': array([  nan, 1600.,   nan,   nan,   nan,   20.,   nan,   nan])},
#  {'DOI': '10.1016/s0167-2738(02)00511-8',
#   'target': 'Ba3Ca1.35Nb1.65O9',
#   'precursors': ['BaCO3', 'CaCO3', 'Nb2O5'],
#   'operation_types': ['StartingSynthesis',
#    'MixingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['prepared',
#    'mixed',
#    'heated',
#    'milled',
#    'heated',
#    'sintered'],
#   'operation_times': [None, None, 20, None, 10, 20],
#   'operation_temps': [None, None, 1000.0, None, 1400.0, 1600.0],
#   'temp_time_vector': array([  nan, 1600.,   nan,   nan,   nan,   20.,   nan,   nan])},
#  {'DOI': '10.1016/j.memsci.2009.08.031',
#   'target': 'SrCe0.8Zr0.2O3',
#   'precursors': ['CeO2', 'SrCO3', 'ZrO2'],
#   'operation_types': ['StartingSynthesis',
#    'StartingSynthesis',
#    'StartingSynthesis',
#    'HeatingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['prepared',
#    'prepared',
#    'synthesized',
#    'pre-sintering',
#    'sintered'],
#   'operation_times': [None, None, None, 10, 5],
#   'operation_temps': [None, None, None, 1100.0, 1450.0],
#   'temp_time_vector': array([  nan, 1450.,   nan,   nan,   nan,    5.,   nan,   nan])},
#  {'DOI': '10.1016/j.memsci.2009.08.031',
#   'target': 'SrEu0.15Ce0.65Zr0.2O3',
#   'precursors': ['CeO2', 'Eu2O3', 'SrCO3', 'ZrO2'],
#   'operation_types': ['StartingSynthesis',
#    'StartingSynthesis',
#    'StartingSynthesis',
#    'HeatingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['prepared',
#    'prepared',
#    'synthesized',
#    'pre-sintering',
#    'sintered'],
#   'operation_times': [None, None, None, 10, 5],
#   'operation_temps': [None, None, None, 1100.0, 1450.0],
#   'temp_time_vector': array([  nan, 1450.,   nan,   nan,   nan,    5.,   nan,   nan])},
#  {'DOI': '10.1016/j.memsci.2009.08.031',
#   'target': 'SrEu0.1Ce0.7Zr0.2O3',
#   'precursors': ['CeO2', 'Eu2O3', 'SrCO3', 'ZrO2'],
#   'operation_types': ['StartingSynthesis',
#    'StartingSynthesis',
#    'StartingSynthesis',
#    'HeatingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['prepared',
#    'prepared',
#    'synthesized',
#    'pre-sintering',
#    'sintered'],
#   'operation_times': [None, None, None, 10, 5],
#   'operation_temps': [None, None, None, 1100.0, 1450.0],
#   'temp_time_vector': array([  nan, 1450.,   nan,   nan,   nan,    5.,   nan,   nan])},
#  {'DOI': '10.1016/j.ssi.2012.05.024',
#   'target': 'BaNd0.1Ce0.675Zr0.225O2.95',
#   'precursors': ['BaCO3', 'CeO2', 'Nd2O3', 'ZrO2'],
#   'operation_types': ['StartingSynthesis',
#    'MixingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['prepared',
#    'milled',
#    'calcined',
#    'milling',
#    'pressed',
#    'sintered'],
#   'operation_times': [None, None, 24, None, None, None],
#   'operation_temps': [None, None, 1200.0, None, None, 1550.0],
#   'temp_time_vector': array([1200., 1550.,   nan,   nan,   24.,   nan,   nan,   nan])},
#  {'DOI': '10.1016/j.ssi.2013.11.033',
#   'target': 'Li7La3Zr2O12',
#   'precursors': ['La2O3', 'Li2CO3', 'ZrO2'],
#   'operation_types': ['StartingSynthesis',
#    'MixingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation',
#    'ShapingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['prepared',
#    'milled',
#    'calcined',
#    'grinded',
#    'pressed',
#    'sintered',
#    'pressed',
#    'heated'],
#   'operation_times': [None, None, 12, None, None, 10, None, None],
#   'operation_temps': [None, None, None, None, None, 1200.0, None, 175.0],
#   'temp_time_vector': array([  nan, 1200.,   nan,   nan,   nan,   10.,   nan,   nan])},
#  {'DOI': '10.1016/j.ssi.2017.03.021',
#   'target': 'Ba2In2O5',
#   'precursors': ['BaCO3', 'In2O3'],
#   'operation_types': ['StartingSynthesis',
#    'HeatingOperation',
#    'ShapingOperation',
#    'HeatingOperation',
#    'StartingSynthesis'],
#   'operation_tokens': ['prepared',
#    'annealed',
#    'pressed',
#    'sintered',
#    'synthesized'],
#   'operation_times': [None, 24, None, 24, None],
#   'operation_temps': [None, None, None, 1400.0, None],
#   'temp_time_vector': array([  nan, 1400.,   nan,   nan,   nan,   24.,   nan,   nan])},
#  {'DOI': '10.1016/j.ssi.2017.03.021',
#   'target': 'Ba2TaInO6',
#   'precursors': ['BaCO3', 'In2O3', 'Ta2O5'],
#   'operation_types': ['StartingSynthesis',
#    'HeatingOperation',
#    'ShapingOperation',
#    'HeatingOperation',
#    'StartingSynthesis'],
#   'operation_tokens': ['prepared',
#    'annealed',
#    'pressed',
#    'sintered',
#    'synthesized'],
#   'operation_times': [None, 24, None, 24, None],
#   'operation_temps': [None, None, None, 1400.0, None],
#   'temp_time_vector': array([  nan, 1400.,   nan,   nan,   nan,   24.,   nan,   nan])},
#  {'DOI': '10.1016/j.ssc.2006.07.002',
#   'target': 'La0.6Mn0.99Sn0.01O3',
#   'precursors': ['La2O3', 'Mn2O3', 'SnO2'],
#   'operation_types': ['StartingSynthesis', 'HeatingOperation'],
#   'operation_tokens': ['prepared', 'sintered'],
#   'operation_times': [None, None],
#   'operation_temps': [None, 1350.0],
#   'temp_time_vector': array([  nan, 1350.,   nan,   nan,   nan,   nan,   nan,   nan])},
#  {'DOI': '10.1016/j.ssc.2006.07.002',
#   'target': 'La0.6Mn0.98Sn0.02O3',
#   'precursors': ['La2O3', 'Mn2O3', 'SnO2'],
#   'operation_types': ['StartingSynthesis', 'HeatingOperation'],
#   'operation_tokens': ['prepared', 'sintered'],
#   'operation_times': [None, None],
#   'operation_temps': [None, 1350.0],
#   'temp_time_vector': array([  nan, 1350.,   nan,   nan,   nan,   nan,   nan,   nan])},
#  {'DOI': '10.1016/j.ssc.2006.07.002',
#   'target': 'La0.67Mn0.99Sn0.01O3',
#   'precursors': ['La2O3', 'Mn2O3', 'SnO2'],
#   'operation_types': ['StartingSynthesis', 'HeatingOperation'],
#   'operation_tokens': ['prepared', 'sintered'],
#   'operation_times': [None, None],
#   'operation_temps': [None, 1350.0],
#   'temp_time_vector': array([  nan, 1350.,   nan,   nan,   nan,   nan,   nan,   nan])},
#  {'DOI': '10.1016/j.ssc.2006.07.002',
#   'target': 'La0.67Mn0.98Sn0.02O3',
#   'precursors': ['La2O3', 'Mn2O3', 'SnO2'],
#   'operation_types': ['StartingSynthesis', 'HeatingOperation'],
#   'operation_tokens': ['prepared', 'sintered'],
#   'operation_times': [None, None],
#   'operation_temps': [None, 1350.0],
#   'temp_time_vector': array([  nan, 1350.,   nan,   nan,   nan,   nan,   nan,   nan])},
#  {'DOI': '10.1016/j.ssc.2017.01.014',
#   'target': 'CrCuO2',
#   'precursors': ['Cr2O3', 'CuO'],
#   'operation_types': ['StartingSynthesis',
#    'MixingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['prepared',
#    'mixed',
#    'calcinated',
#    'ground',
#    'pressed',
#    'sintered'],
#   'operation_times': [None, None, 10, None, None, 10],
#   'operation_temps': [None, None, 1000.0, None, None, 1000.0],
#   'temp_time_vector': array([1000., 1000.,   nan,   nan,   10.,   10.,   nan,   nan])},
#  {'DOI': '10.1016/j.solidstatesciences.2009.12.014',
#   'target': 'Sr2CeSbO6',
#   'precursors': ['Ce2(CO3)3', 'Sb2O5', 'SrCO3'],
#   'operation_types': ['MixingOperation',
#    'HeatingOperation',
#    'QuenchingOperation',
#    'HeatingOperation',
#    'ShapingOperation',
#    'HeatingOperation',
#    'QuenchingOperation'],
#   'operation_tokens': ['mixed',
#    'calcined',
#    'cooling',
#    'calcined',
#    'palletized',
#    'sintered',
#    'cooled'],
#   'operation_times': [10, 15, None, None, None, 5, None],
#   'operation_temps': [None, 1350.0, None, None, None, 1370.0, None],
#   'temp_time_vector': array([1350., 1370.,   nan,   nan,   15.,    5.,   nan,   nan])},
#  {'DOI': '10.1016/j.catcom.2010.01.009',
#   'target': 'Sm0.2Ce0.8O2',
#   'precursors': ['Ce(NO3)2', 'Sm2O3'],
#   'operation_types': ['StartingSynthesis',
#    'StartingSynthesis',
#    'StartingSynthesis',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['prepared',
#    'synthesized',
#    'prepared',
#    'mixed',
#    'pressed',
#    'sintered'],
#   'operation_times': [None, None, None, None, None, 10],
#   'operation_temps': [None, None, None, None, None, 1550.0],
#   'temp_time_vector': array([  nan, 1550.,   nan,   nan,   nan,   10.,   nan,   nan])},
#  {'DOI': '10.1016/j.jpowsour.2014.04.146',
#   'target': 'Li4Ti5O12',
#   'precursors': ['Li2CO3', 'TiH36(C4O)4'],
#   'operation_types': ['StartingSynthesis',
#    'MixingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'MixingOperation'],
#   'operation_tokens': ['synthesized',
#    'mixed',
#    'dispersed',
#    'dispersed',
#    'added',
#    'dispersed',
#    'mixed',
#    'heated',
#    'sintered',
#    'smashed'],
#   'operation_times': [None, None, None, None, None, None, None, 12, 7, 1],
#   'operation_temps': [None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    80.0,
#    800.0,
#    None],
#   'temp_time_vector': array([ nan, 800.,  nan,  nan,  nan,   7.,  nan,  nan])},
#  {'DOI': '10.1016/j.jpowsour.2015.01.116',
#   'target': 'Y2ZrO5',
#   'precursors': ['Y2O3', 'ZrO2'],
#   'operation_types': ['StartingSynthesis',
#    'MixingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'StartingSynthesis',
#    'MixingOperation',
#    'MixingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'ShapingOperation',
#    'HeatingOperation',
#    'StartingSynthesis',
#    'HeatingOperation',
#    'HeatingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['synthesized',
#    'mixed',
#    'milled',
#    'calcined',
#    'prepared',
#    'dissolved',
#    'added',
#    'added',
#    'heated',
#    'stirring',
#    'calcined',
#    'pressed',
#    'co-fired',
#    'prepared',
#    'calcined',
#    'sintered',
#    'maintained'],
#   'operation_times': [None,
#    None,
#    8,
#    2,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    3,
#    None,
#    2,
#    None,
#    2,
#    2,
#    None],
#   'operation_temps': [None,
#    None,
#    None,
#    1450.0,
#    None,
#    None,
#    None,
#    None,
#    80.0,
#    None,
#    1000.0,
#    None,
#    1450.0,
#    None,
#    1300.0,
#    1050.0,
#    None],
#   'temp_time_vector': array([1300., 1050.,   nan,   nan,    2.,    2.,   nan,   nan])},
#  {'DOI': '10.1016/j.jmmm.2013.02.045',
#   'target': 'Y3Fe5O12',
#   'precursors': ['Fe2O3', 'Y2O3'],
#   'operation_types': ['StartingSynthesis',
#    'MixingOperation',
#    'HeatingOperation',
#    'ShapingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['prepared', 'mixed', 'calcined', 'pressed', 'sintered'],
#   'operation_times': [None, None, None, None, 12],
#   'operation_temps': [None, None, None, None, 1300.0],
#   'temp_time_vector': array([  nan, 1300.,   nan,   nan,   nan,   12.,   nan,   nan])},
#  {'DOI': '10.1016/j.jmmm.2013.02.045',
#   'target': 'TmSm2Fe5O12',
#   'precursors': ['Fe2O3', 'Sm2O3', 'Tm2O3'],
#   'operation_types': ['StartingSynthesis',
#    'MixingOperation',
#    'HeatingOperation',
#    'ShapingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['prepared', 'mixed', 'calcined', 'pressed', 'sintered'],
#   'operation_times': [None, None, None, None, 12],
#   'operation_temps': [None, None, None, None, 1300.0],
#   'temp_time_vector': array([  nan, 1300.,   nan,   nan,   nan,   12.,   nan,   nan])},
#  {'DOI': '10.1016/j.jmmm.2013.02.045',
#   'target': 'Tm3Fe5O12',
#   'precursors': ['Fe2O3', 'Tm2O3'],
#   'operation_types': ['StartingSynthesis',
#    'MixingOperation',
#    'HeatingOperation',
#    'ShapingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['prepared', 'mixed', 'calcined', 'pressed', 'sintered'],
#   'operation_times': [None, None, None, None, 12],
#   'operation_temps': [None, None, None, None, 1300.0],
#   'temp_time_vector': array([  nan, 1300.,   nan,   nan,   nan,   12.,   nan,   nan])},
#  {'DOI': '10.1016/j.jmmm.2013.02.045',
#   'target': 'Tm2SmFe5O12',
#   'precursors': ['Fe2O3', 'Sm2O3', 'Tm2O3'],
#   'operation_types': ['StartingSynthesis',
#    'MixingOperation',
#    'HeatingOperation',
#    'ShapingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['prepared', 'mixed', 'calcined', 'pressed', 'sintered'],
#   'operation_times': [None, None, None, None, 12],
#   'operation_temps': [None, None, None, None, 1300.0],
#   'temp_time_vector': array([  nan, 1300.,   nan,   nan,   nan,   12.,   nan,   nan])},
#  {'DOI': '10.1016/j.jmmm.2014.01.037',
#   'target': 'FeTe0.9S0.1',
#   'precursors': ['Fe', 'S', 'Te'],
#   'operation_types': ['StartingSynthesis',
#    'HeatingOperation',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['synthesized',
#    'heated',
#    'reground',
#    'pressed',
#    'sintered'],
#   'operation_times': [None, 20, None, None, 20],
#   'operation_temps': [None, 1050.0, None, None, 800.0],
#   'temp_time_vector': array([ nan, 800.,  nan,  nan,  nan,  20.,  nan,  nan])},
#  {'DOI': '10.1016/j.jmmm.2014.01.037',
#   'target': 'FeTe0.95S0.05',
#   'precursors': ['Fe', 'S', 'Te'],
#   'operation_types': ['StartingSynthesis',
#    'HeatingOperation',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['synthesized',
#    'heated',
#    'reground',
#    'pressed',
#    'sintered'],
#   'operation_times': [None, 20, None, None, 20],
#   'operation_temps': [None, 1050.0, None, None, 800.0],
#   'temp_time_vector': array([ nan, 800.,  nan,  nan,  nan,  20.,  nan,  nan])},
#  {'DOI': '10.1016/j.jmmm.2014.01.037',
#   'target': 'FeTe0.8S0.2',
#   'precursors': ['Fe', 'S', 'Te'],
#   'operation_types': ['StartingSynthesis',
#    'HeatingOperation',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['synthesized',
#    'heated',
#    'reground',
#    'pressed',
#    'sintered'],
#   'operation_times': [None, 20, None, None, 20],
#   'operation_temps': [None, 1050.0, None, None, 800.0],
#   'temp_time_vector': array([ nan, 800.,  nan,  nan,  nan,  20.,  nan,  nan])},
#  {'DOI': '10.1016/j.jmmm.2014.01.037',
#   'target': 'FeTe0.8S0.2',
#   'precursors': ['Fe', 'S', 'Te'],
#   'operation_types': ['StartingSynthesis',
#    'HeatingOperation',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation'],
#   'operation_tokens': ['synthesized',
#    'heated',
#    'reground',
#    'pressed',
#    'sintered'],
#   'operation_times': [None, 20, None, None, 20],
#   'operation_temps': [None, 1050.0, None, None, 800.0],
#   'temp_time_vector': array([ nan, 800.,  nan,  nan,  nan,  20.,  nan,  nan])},
#  {'DOI': '10.1016/j.jmmm.2017.10.020',
#   'target': 'Ca0.85Dy0.15MnO3',
#   'precursors': ['CaO', 'Dy2O3', 'MnH6(CO)4'],
#   'operation_types': ['StartingSynthesis',
#    'MixingOperation',
#    'MixingOperation',
#    'HeatingOperation',
#    'MixingOperation',
#    'ShapingOperation',
#    'HeatingOperation',
#    'HeatingOperation',
#    'QuenchingOperation',
#    'StartingSynthesis',
#    'QuenchingOperation'],
#   'operation_tokens': ['prepared',
#    'mixed',
#    'ground',
#    'heated',
#    'reground',
#    'pelletized',
#    'sintered',
#    'sintered',
#    'cooled',
#    'prepared',
#    'cooled'],
#   'operation_times': [None,
#    None,
#    None,
#    12,
#    None,
#    None,
#    12,
#    12,
#    None,
#    None,
#    None],
#   'operation_temps': [None,
#    None,
#    None,
#    900.0,
#    None,
#    None,
#    1100.0,
#    1200.0,
#    None,
#    None,
#    None],
#   'temp_time_vector': array([  nan, 1200.,   nan,   nan,   nan,   12.,   nan,   nan])},
#  ...]

# %%
targets = [x['target'] for x in papers]
precursors = [x['precursors'] for x in papers]
temps = [x['temp_time_vector'][1] for x in papers]
dois = [x['DOI'] for x in papers]

# %%
# get means
only_ss_rxns = []
for target, precs, temps, doi in zip(targets, precursors, temps, dois):
    if len(precs) == 0:
        continue
    found = False
    for result in only_ss_rxns:
        if result["target"] == target and set(result["precursors"]) == set(precs):
            result["ss_sinter_temps"].append(temps)
            result["DOIs"].append(doi)
            found = True
    if not found:
        new_result = {}
        new_result["target"] = target
        new_result["precursors"] = precs
        new_result["ss_sinter_temps"] = [temps]
        new_result["DOIs"] = [doi]
        only_ss_rxns.append(new_result)

# %%
with open('/home/jupyter/CJK/TempTime/rxn_classification_fraction/data/full_mp.json', 'r') as f:
    full_mp = json.load(f)

# %%
full_mp = {Composition(x): full_mp[x] for x in full_mp}
full_mp_median = np.median(list(full_mp.values()))

# %%
# change precursor functional groups back
for rxn in only_ss_rxns:
    for i in range(len(rxn['precursors'])):
        rxn['precursors'][i] = ss_precursor_nomenclature[Composition(rxn['precursors'][i])]

# %%
temps = []
for rxn in only_ss_rxns:
    mps = [full_mp.get(Composition(x), full_mp_median) for x in rxn["precursors"]]
    min_temp = min(mps)
    min_23 = (2/3)*min_temp
    temps.append([np.mean(rxn['ss_sinter_temps']), min_temp, min_23])

# %%
preds = [rxn[2]+226 for rxn in temps]
real_temps = [rxn[0] for rxn in temps]

# %%
fig, ax = plt.subplots(dpi=100)
ax.scatter(real_temps, preds, alpha=0.5, label="Tamman rule")
ax.set_xlabel('Measured')
ax.set_ylabel('Predicted')
ax.legend()
ax.plot([0, 2000], [0, 2000], "k-", lw=2)
ax.set_xlim([0, 2000])
ax.set_ylim([0, 2000])
plt.show()

# %%
real_temps = np.array(real_temps)
preds = np.array(preds)
mae = mean_absolute_error(real_temps, preds)
rmse = mean_squared_error(real_temps, preds, squared=False)
r2 = r2_score(real_temps, preds)
mre = np.mean((np.abs(preds-real_temps)/real_temps)*100)

# %%
print('Number of samples with all precursor MPs tabulated: {}'.format(len(temps)))
print('RMSE: {}'.format(rmse))
print('MAE: {}'.format(mae))
print('MRE {}'.format(mre))
print('R2 score: {}'.format(r2))
# Out:
# Number of samples with all precursor MPs tabulated: 12296
# RMSE: 660.5110014231553
# MAE: 578.3153522766188
# MRE 49.506350426059385
# R2 score: -6.005581702838448
