# %%
# %load_ext autoreload
# %autoreload 2

import pickle
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from cvae_featurization import *
from sklearn.utils import shuffle
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler
from sklearn.model_selection import train_test_split, KFold
from keras.callbacks import EarlyStopping
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
import sys, os
os.environ["CUDA_VISIBLE_DEVICES"]="3"
from cvae import TempTimeGenerator
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
featurization="pca"
only_ss_rxns, ss_precursor_nomenclature = impute_data()
df, prec_magpie_feats = featurize(featurization, only_ss_rxns, ss_precursor_nomenclature)
# Out:
# Returning extracted data of 51574/31782 reactions.
# HBox(children=(HTML(value='StrToComposition'), FloatProgress(value=0.0, max=31042.0), HTML(value='')))
# HBox(children=(HTML(value='MultipleFeaturizer'), FloatProgress(value=0.0, max=31042.0), HTML(value='')))

# %%
objective = "temp_time_vector"
omit_columns = ['targets', 'precursors', objective, 'composition_obj']
X_columns = [x for x in df.columns if x not in omit_columns]
y_column = objective
X_df = df[X_columns]
X_columns = list(X_df.columns)
X = X_df.values
y = df[y_column].values

if featurization == "mp_fraction":
    X, y, full_df = shuffle(X, y, df, random_state=42)
else:
    X, y, prec_magpie_feats, full_df = shuffle(X, y, prec_magpie_feats, df, random_state=42)

y = np.vstack(y)
print("Shape of X: {}".format(X.shape))
print("Shape of y: {}".format(y.shape))
# Out:
# Shape of X: (31042, 103)
# Shape of y: (31042, 8)

# %%
def get_unique_test_set(df):
    test_results = []
    unique_inds = []
    for i, (target, precs, temps) in enumerate(zip(df['targets'], df['precursors'], df['temp_time_vector'])):
        found = False
        for result in test_results:
            if result["Target"] == target and set(result["Precursors"]) == set(precs):
                result["temp_time_vector"].append(temps)
                found = True
        if not found:
            new_result = {}
            new_result["Target"] = target
            new_result["Precursors"] = precs
            new_result["temp_time_vector"] = [temps]
            test_results.append(new_result)
            unique_inds.append(i)
    return test_results, np.array(unique_inds)

# %%
best_params = []
y_pred_train, y_pred_test = [], []
X_train_k, X_test_k = [], []
y_train_k, y_test_k = [], []
n_pts_train_k, n_pts_test_k = [], []
histories = []

kf = KFold(n_splits=10, shuffle=False)

for train_index, test_index in kf.split(X):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    df_train, df_test = full_df.iloc[train_index], full_df.iloc[test_index]
    
    if featurization == "pca":
        prec_magpie_feats_train, prec_magpie_feats_test = prec_magpie_feats[train_index], prec_magpie_feats[test_index]
        X_train_curr, X_val, y_train_curr, y_val, prec_magpie_feats_train_curr, prec_magpie_feats_val = train_test_split(X_train, y_train, prec_magpie_feats_train, test_size=0.2, shuffle=False)
    else:
        X_train_curr, X_val, y_train_curr, y_val = train_test_split(X_train, y_train, test_size=0.2, shuffle=False)
    
    scaler = StandardScaler()
    scaler.fit(y_train_curr)
    y_train_curr = scaler.transform(y_train_curr)
    y_val = scaler.transform(y_val)
    
    y_train_curr = np.reshape(y_train_curr, (-1, 8, 1))
    y_val = np.reshape(y_val, (-1, 8, 1))
    
    train_inputs = [y_train_curr, X_train_curr, prec_magpie_feats_train_curr]
    train_outputs = [y_train_curr]
    
    val_data = [[y_val, X_val, prec_magpie_feats_val], y_val]
    
    temp_gen = TempTimeGenerator()
    temp_gen.build_nn_model()
    callbacks=[EarlyStopping(monitor='val_loss', min_delta=0, patience=10, verbose=0, mode='auto')]
    history = temp_gen.train(
        inputs=train_inputs, 
        outputs=train_outputs,
        epochs=100,
        val_split=0,
        val_data=val_data,
        batch_size=128,
        callbacks=callbacks,
        verbose=2
    )
    
    histories.append(history)
    
    epochs = len(history['val_loss'])
    
    best_params.append(epochs)
    
    del temp_gen
    
    scaler = StandardScaler()
    scaler.fit(y_train)
    y_train = scaler.transform(y_train)
    y_train = np.reshape(y_train, (-1, 8, 1))
    
    train_inputs = [y_train, X_train, prec_magpie_feats_train]
    train_outputs = [y_train]
    
    temp_gen = TempTimeGenerator()
    temp_gen.build_nn_model()

    history = temp_gen.train(
        inputs=train_inputs, 
        outputs=train_outputs,
        epochs=epochs,
        val_split=0,
        val_data=None,
        batch_size=128,
        callbacks=None,
        verbose=2
    )
    
    test_results, unique_inds = get_unique_test_set(df_test)
    
    results = []
    for i in unique_inds:
        conds = temp_gen.generate_samples(target_material=X_test[i:i+1], precursors=prec_magpie_feats_test[i:i+1], n_samples=1000)
        curr_results = []
        for conditions in conds:
            temp_time = scaler.inverse_transform(conditions.reshape(1, -1)).flatten()
            curr_results.append(temp_time)
        curr_results = np.vstack(curr_results)
        results.append(curr_results)
    results = np.array(results)
    
    y_pred_test.append(results)
    y_test_k.append(test_results)
# Out:
# Train on 22349 samples, validate on 5588 samples
# Epoch 1/100
#  - 8s - loss: 6.8488 - mean_squared_error: 0.8310 - val_loss: 5.7080 - val_mean_squared_error: 0.6765
# Epoch 2/100
#  - 2s - loss: 5.2454 - mean_squared_error: 0.6063 - val_loss: 4.9480 - val_mean_squared_error: 0.5597
# Epoch 3/100
#  - 2s - loss: 4.6671 - mean_squared_error: 0.5133 - val_loss: 4.4779 - val_mean_squared_error: 0.4804
# Epoch 4/100
#  - 2s - loss: 4.4269 - mean_squared_error: 0.4675 - val_loss: 4.2480 - val_mean_squared_error: 0.4318
# Epoch 5/100
#  - 2s - loss: 4.2407 - mean_squared_error: 0.4336 - val_loss: 4.2314 - val_mean_squared_error: 0.4293
# Epoch 6/100
#  - 2s - loss: 4.1114 - mean_squared_error: 0.4111 - val_loss: 4.1006 - val_mean_squared_error: 0.4067
# Epoch 7/100
#  - 2s - loss: 4.0417 - mean_squared_error: 0.3953 - val_loss: 3.8655 - val_mean_squared_error: 0.3759
# Epoch 8/100
#  - 2s - loss: 3.9893 - mean_squared_error: 0.3855 - val_loss: 3.9097 - val_mean_squared_error: 0.3703
# Epoch 9/100
#  - 2s - loss: 3.8302 - mean_squared_error: 0.3644 - val_loss: 3.9578 - val_mean_squared_error: 0.3843
# Epoch 10/100
#  - 2s - loss: 3.7810 - mean_squared_error: 0.3553 - val_loss: 3.8103 - val_mean_squared_error: 0.3584
# Epoch 11/100
#  - 2s - loss: 3.7361 - mean_squared_error: 0.3479 - val_loss: 3.9109 - val_mean_squared_error: 0.3666
# Epoch 12/100
#  - 2s - loss: 3.6787 - mean_squared_error: 0.3364 - val_loss: 3.7448 - val_mean_squared_error: 0.3490
# Epoch 13/100
#  - 2s - loss: 3.5791 - mean_squared_error: 0.3269 - val_loss: 3.5317 - val_mean_squared_error: 0.3228
# Epoch 14/100
#  - 2s - loss: 3.4793 - mean_squared_error: 0.3171 - val_loss: 3.5986 - val_mean_squared_error: 0.3432
# Epoch 15/100
#  - 2s - loss: 3.4780 - mean_squared_error: 0.3141 - val_loss: 3.6067 - val_mean_squared_error: 0.3379
# Epoch 16/100
#  - 2s - loss: 3.5404 - mean_squared_error: 0.3183 - val_loss: 3.7500 - val_mean_squared_error: 0.3494
# Epoch 17/100
#  - 2s - loss: 3.4962 - mean_squared_error: 0.3112 - val_loss: 3.4669 - val_mean_squared_error: 0.3184
# Epoch 18/100
#  - 2s - loss: 3.3725 - mean_squared_error: 0.3000 - val_loss: 3.4408 - val_mean_squared_error: 0.3071
# Epoch 19/100
#  - 2s - loss: 3.3140 - mean_squared_error: 0.2960 - val_loss: 3.5147 - val_mean_squared_error: 0.3254
# Epoch 20/100
#  - 2s - loss: 3.3181 - mean_squared_error: 0.2950 - val_loss: 3.3936 - val_mean_squared_error: 0.3054
# Epoch 21/100
#  - 2s - loss: 3.2883 - mean_squared_error: 0.2885 - val_loss: 3.4281 - val_mean_squared_error: 0.3050
# Epoch 22/100
#  - 2s - loss: 3.2586 - mean_squared_error: 0.2824 - val_loss: 3.4711 - val_mean_squared_error: 0.3144
# Epoch 23/100
#  - 2s - loss: 3.2528 - mean_squared_error: 0.2844 - val_loss: 3.3465 - val_mean_squared_error: 0.2901
# Epoch 24/100
#  - 2s - loss: 3.1841 - mean_squared_error: 0.2753 - val_loss: 3.3327 - val_mean_squared_error: 0.3013
# Epoch 25/100
#  - 2s - loss: 3.1995 - mean_squared_error: 0.2787 - val_loss: 3.4232 - val_mean_squared_error: 0.3110
# Epoch 26/100
#  - 2s - loss: 3.1416 - mean_squared_error: 0.2721 - val_loss: 3.3631 - val_mean_squared_error: 0.2999
# Epoch 27/100
#  - 2s - loss: 3.1387 - mean_squared_error: 0.2733 - val_loss: 3.4378 - val_mean_squared_error: 0.3153
# Epoch 28/100
#  - 2s - loss: 3.2118 - mean_squared_error: 0.2764 - val_loss: 3.4329 - val_mean_squared_error: 0.3061
# Epoch 29/100
#  - 2s - loss: 3.1178 - mean_squared_error: 0.2696 - val_loss: 3.3658 - val_mean_squared_error: 0.2910
# Epoch 30/100
#  - 2s - loss: 3.1041 - mean_squared_error: 0.2647 - val_loss: 3.6122 - val_mean_squared_error: 0.3363
# Epoch 31/100
#  - 2s - loss: 3.1191 - mean_squared_error: 0.2676 - val_loss: 3.2921 - val_mean_squared_error: 0.2802
# Epoch 32/100
#  - 2s - loss: 3.1258 - mean_squared_error: 0.2660 - val_loss: 3.4022 - val_mean_squared_error: 0.3023
# Epoch 33/100
#  - 2s - loss: 3.1079 - mean_squared_error: 0.2648 - val_loss: 3.4732 - val_mean_squared_error: 0.3105
# Epoch 34/100
#  - 2s - loss: 3.0639 - mean_squared_error: 0.2608 - val_loss: 3.3209 - val_mean_squared_error: 0.2876
# Epoch 35/100
#  - 2s - loss: 3.0593 - mean_squared_error: 0.2575 - val_loss: 3.3746 - val_mean_squared_error: 0.2935
# Epoch 36/100
#  - 2s - loss: 2.9951 - mean_squared_error: 0.2560 - val_loss: 3.4763 - val_mean_squared_error: 0.3146
# Epoch 37/100
#  - 2s - loss: 3.0291 - mean_squared_error: 0.2581 - val_loss: 3.4368 - val_mean_squared_error: 0.2958
# Epoch 38/100
#  - 2s - loss: 3.0860 - mean_squared_error: 0.2570 - val_loss: 3.4399 - val_mean_squared_error: 0.2993
# Epoch 39/100
#  - 2s - loss: 3.0451 - mean_squared_error: 0.2567 - val_loss: 3.3153 - val_mean_squared_error: 0.2862
# Epoch 40/100
#  - 2s - loss: 2.9743 - mean_squared_error: 0.2486 - val_loss: 3.3527 - val_mean_squared_error: 0.3069
# Epoch 41/100
#  - 2s - loss: 2.8873 - mean_squared_error: 0.2459 - val_loss: 3.4777 - val_mean_squared_error: 0.3137
# Epoch 1/41
#  - 8s - loss: 6.6777 - mean_squared_error: 0.7990
# Epoch 2/41
#  - 2s - loss: 5.0274 - mean_squared_error: 0.5668
# Epoch 3/41
#  - 2s - loss: 4.3663 - mean_squared_error: 0.4485
# Epoch 4/41
#  - 2s - loss: 4.2042 - mean_squared_error: 0.4116
# Epoch 5/41
#  - 2s - loss: 4.1264 - mean_squared_error: 0.3905
# Epoch 6/41
#  - 2s - loss: 4.0992 - mean_squared_error: 0.3880
# Epoch 7/41
#  - 2s - loss: 3.9103 - mean_squared_error: 0.3674
# Epoch 8/41
#  - 2s - loss: 3.8074 - mean_squared_error: 0.3538
# Epoch 9/41
#  - 2s - loss: 3.7730 - mean_squared_error: 0.3469
# Epoch 10/41
#  - 3s - loss: 3.6951 - mean_squared_error: 0.3370
# Epoch 11/41
#  - 2s - loss: 3.6458 - mean_squared_error: 0.3324
# Epoch 12/41
#  - 2s - loss: 3.5627 - mean_squared_error: 0.3201
# Epoch 13/41
#  - 2s - loss: 3.5444 - mean_squared_error: 0.3197
# Epoch 14/41
#  - 2s - loss: 3.4341 - mean_squared_error: 0.3086
# Epoch 15/41
#  - 2s - loss: 3.4173 - mean_squared_error: 0.3044
# Epoch 16/41
#  - 2s - loss: 3.4133 - mean_squared_error: 0.2997
# Epoch 17/41
#  - 2s - loss: 3.3571 - mean_squared_error: 0.2937
# Epoch 18/41
#  - 2s - loss: 3.3693 - mean_squared_error: 0.2967
# Epoch 19/41
#  - 2s - loss: 3.2697 - mean_squared_error: 0.2878
# Epoch 20/41
#  - 2s - loss: 3.2806 - mean_squared_error: 0.2835
# Epoch 21/41
#  - 2s - loss: 3.2037 - mean_squared_error: 0.2764
# Epoch 22/41
#  - 2s - loss: 3.2186 - mean_squared_error: 0.2759
# Epoch 23/41
#  - 2s - loss: 3.2363 - mean_squared_error: 0.2772
# Epoch 24/41
#  - 2s - loss: 3.1447 - mean_squared_error: 0.2682
# Epoch 25/41
#  - 2s - loss: 3.2096 - mean_squared_error: 0.2711
# Epoch 26/41
#  - 2s - loss: 3.1470 - mean_squared_error: 0.2666
# Epoch 27/41
#  - 2s - loss: 3.0941 - mean_squared_error: 0.2637
# Epoch 28/41
#  - 2s - loss: 3.1222 - mean_squared_error: 0.2671
# Epoch 29/41
#  - 2s - loss: 3.0238 - mean_squared_error: 0.2621
# Epoch 30/41
#  - 2s - loss: 3.1167 - mean_squared_error: 0.2654
# Epoch 31/41
#  - 2s - loss: 3.0698 - mean_squared_error: 0.2593
# Epoch 32/41
#  - 2s - loss: 3.0465 - mean_squared_error: 0.2589
# Epoch 33/41
#  - 2s - loss: 3.0833 - mean_squared_error: 0.2592
# Epoch 34/41
#  - 2s - loss: 3.0021 - mean_squared_error: 0.2526
# Epoch 35/41
#  - 2s - loss: 2.9938 - mean_squared_error: 0.2514
# Epoch 36/41
#  - 2s - loss: 3.0563 - mean_squared_error: 0.2574
# Epoch 37/41
#  - 2s - loss: 3.0146 - mean_squared_error: 0.2524
# Epoch 38/41
#  - 2s - loss: 3.0044 - mean_squared_error: 0.2490
# Epoch 39/41
#  - 2s - loss: 3.0293 - mean_squared_error: 0.2497
# Epoch 40/41
#  - 2s - loss: 2.9968 - mean_squared_error: 0.2490
# Epoch 41/41
#  - 2s - loss: 2.9822 - mean_squared_error: 0.2462
# Train on 22349 samples, validate on 5588 samples
# Epoch 1/100
#  - 8s - loss: 6.7127 - mean_squared_error: 0.8095 - val_loss: 5.7595 - val_mean_squared_error: 0.6813
# Epoch 2/100
#  - 2s - loss: 5.3611 - mean_squared_error: 0.6146 - val_loss: 5.0724 - val_mean_squared_error: 0.5747
# Epoch 3/100
#  - 2s - loss: 4.7609 - mean_squared_error: 0.5132 - val_loss: 4.4628 - val_mean_squared_error: 0.4607
# Epoch 4/100
#  - 2s - loss: 4.3443 - mean_squared_error: 0.4391 - val_loss: 4.5510 - val_mean_squared_error: 0.4585
# Epoch 5/100
#  - 2s - loss: 4.2379 - mean_squared_error: 0.4130 - val_loss: 4.0179 - val_mean_squared_error: 0.3825
# Epoch 6/100
#  - 2s - loss: 4.0928 - mean_squared_error: 0.3957 - val_loss: 3.9269 - val_mean_squared_error: 0.3723
# Epoch 7/100
#  - 2s - loss: 3.9683 - mean_squared_error: 0.3804 - val_loss: 4.1091 - val_mean_squared_error: 0.3993
# Epoch 8/100
#  - 2s - loss: 3.8551 - mean_squared_error: 0.3665 - val_loss: 4.0589 - val_mean_squared_error: 0.3979
# Epoch 9/100
#  - 2s - loss: 3.9070 - mean_squared_error: 0.3710 - val_loss: 3.7421 - val_mean_squared_error: 0.3652
# Epoch 10/100
#  - 2s - loss: 3.8274 - mean_squared_error: 0.3565 - val_loss: 3.7495 - val_mean_squared_error: 0.3412
# Epoch 11/100
#  - 2s - loss: 3.7551 - mean_squared_error: 0.3456 - val_loss: 3.8759 - val_mean_squared_error: 0.3554
# Epoch 12/100
#  - 2s - loss: 3.6454 - mean_squared_error: 0.3345 - val_loss: 3.7548 - val_mean_squared_error: 0.3446
# Epoch 13/100
#  - 2s - loss: 3.5745 - mean_squared_error: 0.3213 - val_loss: 3.6235 - val_mean_squared_error: 0.3404
# Epoch 14/100
#  - 2s - loss: 3.5014 - mean_squared_error: 0.3190 - val_loss: 3.6470 - val_mean_squared_error: 0.3315
# Epoch 15/100
#  - 2s - loss: 3.4362 - mean_squared_error: 0.3086 - val_loss: 3.5453 - val_mean_squared_error: 0.3326
# Epoch 16/100
#  - 2s - loss: 3.3800 - mean_squared_error: 0.3026 - val_loss: 3.5015 - val_mean_squared_error: 0.3154
# Epoch 17/100
#  - 2s - loss: 3.4191 - mean_squared_error: 0.3008 - val_loss: 3.5067 - val_mean_squared_error: 0.3075
# Epoch 18/100
#  - 2s - loss: 3.3310 - mean_squared_error: 0.2891 - val_loss: 3.5626 - val_mean_squared_error: 0.3298
# Epoch 19/100
#  - 2s - loss: 3.3300 - mean_squared_error: 0.2945 - val_loss: 3.4539 - val_mean_squared_error: 0.3110
# Epoch 20/100
#  - 2s - loss: 3.2550 - mean_squared_error: 0.2876 - val_loss: 3.4599 - val_mean_squared_error: 0.3169
# Epoch 21/100
#  - 2s - loss: 3.2870 - mean_squared_error: 0.2851 - val_loss: 3.4314 - val_mean_squared_error: 0.2976
# Epoch 22/100
#  - 2s - loss: 3.1958 - mean_squared_error: 0.2756 - val_loss: 3.4142 - val_mean_squared_error: 0.3049
# Epoch 23/100
#  - 2s - loss: 3.1651 - mean_squared_error: 0.2757 - val_loss: 3.4078 - val_mean_squared_error: 0.3097
# Epoch 24/100
#  - 2s - loss: 3.1894 - mean_squared_error: 0.2770 - val_loss: 3.4589 - val_mean_squared_error: 0.3097
# Epoch 25/100
#  - 2s - loss: 3.1645 - mean_squared_error: 0.2724 - val_loss: 3.6014 - val_mean_squared_error: 0.3421
# Epoch 26/100
#  - 2s - loss: 3.2136 - mean_squared_error: 0.2733 - val_loss: 3.3984 - val_mean_squared_error: 0.2999
# Epoch 27/100
#  - 2s - loss: 3.1265 - mean_squared_error: 0.2717 - val_loss: 3.4336 - val_mean_squared_error: 0.2991
# Epoch 28/100
#  - 2s - loss: 3.1053 - mean_squared_error: 0.2656 - val_loss: 3.5122 - val_mean_squared_error: 0.3127
# Epoch 29/100
#  - 2s - loss: 3.0816 - mean_squared_error: 0.2601 - val_loss: 3.5071 - val_mean_squared_error: 0.3214
# Epoch 30/100
#  - 2s - loss: 3.1387 - mean_squared_error: 0.2652 - val_loss: 3.4622 - val_mean_squared_error: 0.3122
# Epoch 31/100
#  - 2s - loss: 3.1258 - mean_squared_error: 0.2660 - val_loss: 3.4013 - val_mean_squared_error: 0.3042
# Epoch 32/100
#  - 2s - loss: 3.0476 - mean_squared_error: 0.2573 - val_loss: 3.4463 - val_mean_squared_error: 0.3034
# Epoch 33/100
#  - 2s - loss: 3.0487 - mean_squared_error: 0.2573 - val_loss: 3.4192 - val_mean_squared_error: 0.3038
# Epoch 34/100
#  - 2s - loss: 3.0400 - mean_squared_error: 0.2553 - val_loss: 3.4371 - val_mean_squared_error: 0.3087
# Epoch 35/100
#  - 2s - loss: 3.0548 - mean_squared_error: 0.2547 - val_loss: 3.3070 - val_mean_squared_error: 0.2972
# Epoch 36/100
#  - 2s - loss: 3.0490 - mean_squared_error: 0.2568 - val_loss: 3.3829 - val_mean_squared_error: 0.3004
# Epoch 37/100
#  - 2s - loss: 3.0376 - mean_squared_error: 0.2539 - val_loss: 3.4261 - val_mean_squared_error: 0.3067
# Epoch 38/100
#  - 2s - loss: 2.9937 - mean_squared_error: 0.2544 - val_loss: 3.5764 - val_mean_squared_error: 0.3266
# Epoch 39/100
#  - 2s - loss: 2.9971 - mean_squared_error: 0.2504 - val_loss: 3.2729 - val_mean_squared_error: 0.2898
# Epoch 40/100
#  - 2s - loss: 2.9810 - mean_squared_error: 0.2499 - val_loss: 3.4459 - val_mean_squared_error: 0.3080
# Epoch 41/100
#  - 2s - loss: 2.9677 - mean_squared_error: 0.2473 - val_loss: 3.2838 - val_mean_squared_error: 0.2956
# Epoch 42/100
#  - 2s - loss: 3.0028 - mean_squared_error: 0.2528 - val_loss: 3.4786 - val_mean_squared_error: 0.2995
# Epoch 43/100
#  - 2s - loss: 2.9578 - mean_squared_error: 0.2448 - val_loss: 3.3910 - val_mean_squared_error: 0.3057
# Epoch 44/100
#  - 2s - loss: 2.9310 - mean_squared_error: 0.2432 - val_loss: 3.4374 - val_mean_squared_error: 0.3078
# Epoch 45/100
#  - 2s - loss: 2.9643 - mean_squared_error: 0.2449 - val_loss: 3.2959 - val_mean_squared_error: 0.2882
# Epoch 46/100
#  - 2s - loss: 2.9550 - mean_squared_error: 0.2429 - val_loss: 3.4231 - val_mean_squared_error: 0.3099
# Epoch 47/100
#  - 2s - loss: 2.9575 - mean_squared_error: 0.2435 - val_loss: 3.4442 - val_mean_squared_error: 0.3095
# Epoch 48/100
#  - 2s - loss: 2.9555 - mean_squared_error: 0.2429 - val_loss: 3.3543 - val_mean_squared_error: 0.3059
# Epoch 49/100
#  - 2s - loss: 2.8960 - mean_squared_error: 0.2391 - val_loss: 3.4524 - val_mean_squared_error: 0.3139
# Epoch 1/49
#  - 8s - loss: 6.3895 - mean_squared_error: 0.7547
# Epoch 2/49
#  - 2s - loss: 4.9099 - mean_squared_error: 0.5393
# Epoch 3/49
#  - 2s - loss: 4.4597 - mean_squared_error: 0.4742
# Epoch 4/49
#  - 2s - loss: 4.2908 - mean_squared_error: 0.4529
# Epoch 5/49
#  - 2s - loss: 4.1680 - mean_squared_error: 0.4345
# Epoch 6/49
#  - 2s - loss: 4.0974 - mean_squared_error: 0.4243
# Epoch 7/49
#  - 2s - loss: 4.0096 - mean_squared_error: 0.4138
# Epoch 8/49
#  - 2s - loss: 3.9126 - mean_squared_error: 0.4000
# Epoch 9/49
#  - 2s - loss: 3.8790 - mean_squared_error: 0.3921
# Epoch 10/49
#  - 2s - loss: 3.7207 - mean_squared_error: 0.3657
# Epoch 11/49
#  - 2s - loss: 3.5841 - mean_squared_error: 0.3388
# Epoch 12/49
#  - 2s - loss: 3.5736 - mean_squared_error: 0.3339
# Epoch 13/49
#  - 2s - loss: 3.4705 - mean_squared_error: 0.3166
# Epoch 14/49
#  - 2s - loss: 3.4630 - mean_squared_error: 0.3142
# Epoch 15/49
#  - 2s - loss: 3.3578 - mean_squared_error: 0.3010
# Epoch 16/49
#  - 3s - loss: 3.3597 - mean_squared_error: 0.3000
# Epoch 17/49
#  - 3s - loss: 3.2929 - mean_squared_error: 0.2921
# Epoch 18/49
#  - 2s - loss: 3.3183 - mean_squared_error: 0.2936
# Epoch 19/49
#  - 3s - loss: 3.2049 - mean_squared_error: 0.2846
# Epoch 20/49
#  - 3s - loss: 3.2277 - mean_squared_error: 0.2834
# Epoch 21/49
#  - 3s - loss: 3.1831 - mean_squared_error: 0.2774
# Epoch 22/49
#  - 3s - loss: 3.1938 - mean_squared_error: 0.2795
# Epoch 23/49
#  - 3s - loss: 3.1076 - mean_squared_error: 0.2705
# Epoch 24/49
#  - 3s - loss: 3.1527 - mean_squared_error: 0.2723
# Epoch 25/49
#  - 3s - loss: 3.1134 - mean_squared_error: 0.2699
# Epoch 26/49
#  - 3s - loss: 3.0898 - mean_squared_error: 0.2689
# Epoch 27/49
#  - 3s - loss: 3.1003 - mean_squared_error: 0.2669
# Epoch 28/49
#  - 3s - loss: 3.0816 - mean_squared_error: 0.2645
# Epoch 29/49
#  - 2s - loss: 3.0740 - mean_squared_error: 0.2591
# Epoch 30/49
#  - 2s - loss: 3.0529 - mean_squared_error: 0.2615
# Epoch 31/49
#  - 2s - loss: 3.0675 - mean_squared_error: 0.2612
# Epoch 32/49
#  - 2s - loss: 2.9972 - mean_squared_error: 0.2556
# Epoch 33/49
#  - 2s - loss: 3.0417 - mean_squared_error: 0.2579
# Epoch 34/49
#  - 2s - loss: 3.0357 - mean_squared_error: 0.2582
# Epoch 35/49
#  - 2s - loss: 3.0644 - mean_squared_error: 0.2542
# Epoch 36/49
#  - 2s - loss: 3.0363 - mean_squared_error: 0.2584
# Epoch 37/49
#  - 2s - loss: 3.0299 - mean_squared_error: 0.2558
# Epoch 38/49
#  - 2s - loss: 2.9653 - mean_squared_error: 0.2497
# Epoch 39/49
#  - 2s - loss: 2.9826 - mean_squared_error: 0.2494
# Epoch 40/49
#  - 2s - loss: 2.9671 - mean_squared_error: 0.2475
# Epoch 41/49
#  - 2s - loss: 2.9735 - mean_squared_error: 0.2476
# Epoch 42/49
#  - 2s - loss: 2.9327 - mean_squared_error: 0.2464
# Epoch 43/49
#  - 2s - loss: 2.9215 - mean_squared_error: 0.2465
# Epoch 44/49
#  - 2s - loss: 3.0168 - mean_squared_error: 0.2494
# Epoch 45/49
#  - 2s - loss: 2.9502 - mean_squared_error: 0.2452
# Epoch 46/49
#  - 2s - loss: 2.9486 - mean_squared_error: 0.2478
# Epoch 47/49
#  - 2s - loss: 2.8832 - mean_squared_error: 0.2396
# Epoch 48/49
#  - 2s - loss: 2.9499 - mean_squared_error: 0.2473
# Epoch 49/49
#  - 2s - loss: 2.9427 - mean_squared_error: 0.2434
# Train on 22350 samples, validate on 5588 samples
# Epoch 1/100
#  - 9s - loss: 6.6740 - mean_squared_error: 0.8004 - val_loss: 5.4437 - val_mean_squared_error: 0.6232
# Epoch 2/100
#  - 2s - loss: 5.2170 - mean_squared_error: 0.5737 - val_loss: 4.7061 - val_mean_squared_error: 0.5167
# Epoch 3/100
#  - 2s - loss: 4.6878 - mean_squared_error: 0.4925 - val_loss: 4.3051 - val_mean_squared_error: 0.4402
# Epoch 4/100
#  - 2s - loss: 4.3155 - mean_squared_error: 0.4347 - val_loss: 4.2741 - val_mean_squared_error: 0.4216
# Epoch 5/100
#  - 2s - loss: 4.1923 - mean_squared_error: 0.4074 - val_loss: 4.1890 - val_mean_squared_error: 0.4005
# Epoch 6/100
#  - 2s - loss: 4.0849 - mean_squared_error: 0.3916 - val_loss: 4.0720 - val_mean_squared_error: 0.3839
# Epoch 7/100
#  - 2s - loss: 4.0211 - mean_squared_error: 0.3832 - val_loss: 3.9032 - val_mean_squared_error: 0.3681
# Epoch 8/100
#  - 2s - loss: 3.9679 - mean_squared_error: 0.3701 - val_loss: 3.9260 - val_mean_squared_error: 0.3762
# Epoch 9/100
#  - 2s - loss: 3.9585 - mean_squared_error: 0.3723 - val_loss: 4.0193 - val_mean_squared_error: 0.3821
# Epoch 10/100
#  - 2s - loss: 3.8783 - mean_squared_error: 0.3636 - val_loss: 3.7810 - val_mean_squared_error: 0.3393
# Epoch 11/100
#  - 2s - loss: 3.7933 - mean_squared_error: 0.3560 - val_loss: 3.7209 - val_mean_squared_error: 0.3519
# Epoch 12/100
#  - 2s - loss: 3.7218 - mean_squared_error: 0.3472 - val_loss: 3.8512 - val_mean_squared_error: 0.3660
# Epoch 13/100
#  - 2s - loss: 3.7000 - mean_squared_error: 0.3449 - val_loss: 3.8720 - val_mean_squared_error: 0.3700
# Epoch 14/100
#  - 2s - loss: 3.6143 - mean_squared_error: 0.3331 - val_loss: 3.6112 - val_mean_squared_error: 0.3368
# Epoch 15/100
#  - 2s - loss: 3.6386 - mean_squared_error: 0.3302 - val_loss: 3.5624 - val_mean_squared_error: 0.3173
# Epoch 16/100
#  - 2s - loss: 3.5863 - mean_squared_error: 0.3240 - val_loss: 3.7383 - val_mean_squared_error: 0.3350
# Epoch 17/100
#  - 2s - loss: 3.5748 - mean_squared_error: 0.3186 - val_loss: 3.5614 - val_mean_squared_error: 0.3221
# Epoch 18/100
#  - 2s - loss: 3.5207 - mean_squared_error: 0.3156 - val_loss: 3.3946 - val_mean_squared_error: 0.3089
# Epoch 19/100
#  - 2s - loss: 3.4489 - mean_squared_error: 0.3055 - val_loss: 3.6234 - val_mean_squared_error: 0.3287
# Epoch 20/100
#  - 2s - loss: 3.3973 - mean_squared_error: 0.3017 - val_loss: 3.5319 - val_mean_squared_error: 0.3095
# Epoch 21/100
#  - 2s - loss: 3.3659 - mean_squared_error: 0.2982 - val_loss: 3.5049 - val_mean_squared_error: 0.3087
# Epoch 22/100
#  - 2s - loss: 3.3381 - mean_squared_error: 0.2948 - val_loss: 3.7025 - val_mean_squared_error: 0.3376
# Epoch 23/100
#  - 2s - loss: 3.3660 - mean_squared_error: 0.2940 - val_loss: 3.5757 - val_mean_squared_error: 0.3206
# Epoch 24/100
#  - 2s - loss: 3.3101 - mean_squared_error: 0.2881 - val_loss: 3.3750 - val_mean_squared_error: 0.2939
# Epoch 25/100
#  - 2s - loss: 3.2527 - mean_squared_error: 0.2842 - val_loss: 3.5362 - val_mean_squared_error: 0.3173
# Epoch 26/100
#  - 2s - loss: 3.2675 - mean_squared_error: 0.2816 - val_loss: 3.3992 - val_mean_squared_error: 0.3081
# Epoch 27/100
#  - 2s - loss: 3.1940 - mean_squared_error: 0.2805 - val_loss: 3.4504 - val_mean_squared_error: 0.3164
# Epoch 28/100
#  - 2s - loss: 3.1866 - mean_squared_error: 0.2778 - val_loss: 3.3987 - val_mean_squared_error: 0.3016
# Epoch 29/100
#  - 2s - loss: 3.1462 - mean_squared_error: 0.2710 - val_loss: 3.5670 - val_mean_squared_error: 0.3215
# Epoch 30/100
#  - 2s - loss: 3.1673 - mean_squared_error: 0.2721 - val_loss: 3.3990 - val_mean_squared_error: 0.2946
# Epoch 31/100
#  - 2s - loss: 3.1718 - mean_squared_error: 0.2707 - val_loss: 3.4361 - val_mean_squared_error: 0.3106
# Epoch 32/100
#  - 2s - loss: 3.1289 - mean_squared_error: 0.2690 - val_loss: 3.5162 - val_mean_squared_error: 0.3078
# Epoch 33/100
#  - 2s - loss: 3.1530 - mean_squared_error: 0.2661 - val_loss: 3.2930 - val_mean_squared_error: 0.2927
# Epoch 34/100
#  - 2s - loss: 3.1333 - mean_squared_error: 0.2645 - val_loss: 3.2863 - val_mean_squared_error: 0.2896
# Epoch 35/100
#  - 2s - loss: 3.0214 - mean_squared_error: 0.2573 - val_loss: 3.2482 - val_mean_squared_error: 0.2770
# Epoch 36/100
#  - 2s - loss: 3.0708 - mean_squared_error: 0.2600 - val_loss: 3.4463 - val_mean_squared_error: 0.3054
# Epoch 37/100
#  - 2s - loss: 3.0984 - mean_squared_error: 0.2580 - val_loss: 3.4255 - val_mean_squared_error: 0.3003
# Epoch 38/100
#  - 2s - loss: 3.0329 - mean_squared_error: 0.2548 - val_loss: 3.5030 - val_mean_squared_error: 0.3096
# Epoch 39/100
#  - 2s - loss: 3.0741 - mean_squared_error: 0.2579 - val_loss: 3.4009 - val_mean_squared_error: 0.2944
# Epoch 40/100
#  - 2s - loss: 2.9857 - mean_squared_error: 0.2537 - val_loss: 3.4251 - val_mean_squared_error: 0.2946
# Epoch 41/100
#  - 2s - loss: 3.0022 - mean_squared_error: 0.2481 - val_loss: 3.4740 - val_mean_squared_error: 0.2959
# Epoch 42/100
#  - 2s - loss: 3.0343 - mean_squared_error: 0.2516 - val_loss: 3.3291 - val_mean_squared_error: 0.2921
# Epoch 43/100
#  - 2s - loss: 2.9551 - mean_squared_error: 0.2455 - val_loss: 3.4233 - val_mean_squared_error: 0.3094
# Epoch 44/100
#  - 2s - loss: 2.9580 - mean_squared_error: 0.2465 - val_loss: 3.5571 - val_mean_squared_error: 0.3316
# Epoch 45/100
#  - 2s - loss: 2.9673 - mean_squared_error: 0.2472 - val_loss: 3.3310 - val_mean_squared_error: 0.3041
# Epoch 1/45
#  - 8s - loss: 6.5546 - mean_squared_error: 0.7817
# Epoch 2/45
#  - 2s - loss: 5.0241 - mean_squared_error: 0.5577
# Epoch 3/45
#  - 2s - loss: 4.5178 - mean_squared_error: 0.4621
# Epoch 4/45
#  - 2s - loss: 4.2661 - mean_squared_error: 0.4211
# Epoch 5/45
#  - 2s - loss: 4.1405 - mean_squared_error: 0.3988
# Epoch 6/45
#  - 2s - loss: 4.0484 - mean_squared_error: 0.3864
# Epoch 7/45
#  - 2s - loss: 3.9581 - mean_squared_error: 0.3777
# Epoch 8/45
#  - 2s - loss: 4.0005 - mean_squared_error: 0.3761
# Epoch 9/45
#  - 2s - loss: 3.8627 - mean_squared_error: 0.3625
# Epoch 10/45
#  - 2s - loss: 3.7913 - mean_squared_error: 0.3534
# Epoch 11/45
#  - 2s - loss: 3.7685 - mean_squared_error: 0.3490
# Epoch 12/45
#  - 2s - loss: 3.6616 - mean_squared_error: 0.3356
# Epoch 13/45
#  - 2s - loss: 3.5710 - mean_squared_error: 0.3235
# Epoch 14/45
#  - 2s - loss: 3.5891 - mean_squared_error: 0.3258
# Epoch 15/45
#  - 2s - loss: 3.5028 - mean_squared_error: 0.3089
# Epoch 16/45
#  - 2s - loss: 3.4263 - mean_squared_error: 0.3040
# Epoch 17/45
#  - 2s - loss: 3.3712 - mean_squared_error: 0.2948
# Epoch 18/45
#  - 2s - loss: 3.3853 - mean_squared_error: 0.2972
# Epoch 19/45
#  - 2s - loss: 3.3127 - mean_squared_error: 0.2895
# Epoch 20/45
#  - 2s - loss: 3.3034 - mean_squared_error: 0.2871
# Epoch 21/45
#  - 2s - loss: 3.2442 - mean_squared_error: 0.2829
# Epoch 22/45
#  - 2s - loss: 3.2917 - mean_squared_error: 0.2830
# Epoch 23/45
#  - 2s - loss: 3.2571 - mean_squared_error: 0.2797
# Epoch 24/45
#  - 3s - loss: 3.1999 - mean_squared_error: 0.2760
# Epoch 25/45
#  - 3s - loss: 3.1862 - mean_squared_error: 0.2757
# Epoch 26/45
#  - 3s - loss: 3.2487 - mean_squared_error: 0.2756
# Epoch 27/45
#  - 3s - loss: 3.1324 - mean_squared_error: 0.2679
# Epoch 28/45
#  - 3s - loss: 3.1755 - mean_squared_error: 0.2688
# Epoch 29/45
#  - 3s - loss: 3.1395 - mean_squared_error: 0.2657
# Epoch 30/45
#  - 3s - loss: 3.1056 - mean_squared_error: 0.2644
# Epoch 31/45
#  - 3s - loss: 3.0772 - mean_squared_error: 0.2619
# Epoch 32/45
#  - 3s - loss: 3.1178 - mean_squared_error: 0.2632
# Epoch 33/45
#  - 2s - loss: 3.0473 - mean_squared_error: 0.2601
# Epoch 34/45
#  - 3s - loss: 3.1368 - mean_squared_error: 0.2649
# Epoch 35/45
#  - 2s - loss: 3.0858 - mean_squared_error: 0.2588
# Epoch 36/45
#  - 2s - loss: 3.0576 - mean_squared_error: 0.2542
# Epoch 37/45
#  - 3s - loss: 3.0601 - mean_squared_error: 0.2576
# Epoch 38/45
#  - 2s - loss: 2.9815 - mean_squared_error: 0.2488
# Epoch 39/45
#  - 2s - loss: 2.9983 - mean_squared_error: 0.2496
# Epoch 40/45
#  - 2s - loss: 3.0166 - mean_squared_error: 0.2519
# Epoch 41/45
#  - 2s - loss: 3.0286 - mean_squared_error: 0.2516
# Epoch 42/45
#  - 3s - loss: 2.9758 - mean_squared_error: 0.2463
# Epoch 43/45
#  - 3s - loss: 3.0632 - mean_squared_error: 0.2534
# Epoch 44/45
#  - 3s - loss: 2.9617 - mean_squared_error: 0.2445
# Epoch 45/45
#  - 3s - loss: 3.0216 - mean_squared_error: 0.2475
# Train on 22350 samples, validate on 5588 samples
# Epoch 1/100
#  - 9s - loss: 6.7838 - mean_squared_error: 0.8196 - val_loss: 5.5385 - val_mean_squared_error: 0.6516
# Epoch 2/100
#  - 2s - loss: 5.2211 - mean_squared_error: 0.6007 - val_loss: 4.8050 - val_mean_squared_error: 0.5548
# Epoch 3/100
#  - 2s - loss: 4.6010 - mean_squared_error: 0.5122 - val_loss: 4.4530 - val_mean_squared_error: 0.4876
# Epoch 4/100
#  - 2s - loss: 4.3775 - mean_squared_error: 0.4644 - val_loss: 4.1602 - val_mean_squared_error: 0.4381
# Epoch 5/100
#  - 2s - loss: 4.2560 - mean_squared_error: 0.4419 - val_loss: 4.1433 - val_mean_squared_error: 0.4374
# Epoch 6/100
#  - 2s - loss: 4.0554 - mean_squared_error: 0.4060 - val_loss: 4.0599 - val_mean_squared_error: 0.4069
# Epoch 7/100
#  - 2s - loss: 4.0037 - mean_squared_error: 0.3949 - val_loss: 3.9887 - val_mean_squared_error: 0.3830
# Epoch 8/100
#  - 2s - loss: 3.9674 - mean_squared_error: 0.3819 - val_loss: 3.8533 - val_mean_squared_error: 0.3746
# Epoch 9/100
#  - 2s - loss: 3.9062 - mean_squared_error: 0.3750 - val_loss: 3.8978 - val_mean_squared_error: 0.3717
# Epoch 10/100
#  - 2s - loss: 3.8251 - mean_squared_error: 0.3685 - val_loss: 3.8764 - val_mean_squared_error: 0.3657
# Epoch 11/100
#  - 2s - loss: 3.7737 - mean_squared_error: 0.3586 - val_loss: 3.7372 - val_mean_squared_error: 0.3642
# Epoch 12/100
#  - 2s - loss: 3.6976 - mean_squared_error: 0.3535 - val_loss: 3.6321 - val_mean_squared_error: 0.3378
# Epoch 13/100
#  - 2s - loss: 3.6636 - mean_squared_error: 0.3399 - val_loss: 3.7770 - val_mean_squared_error: 0.3498
# Epoch 14/100
#  - 2s - loss: 3.6106 - mean_squared_error: 0.3336 - val_loss: 3.8303 - val_mean_squared_error: 0.3571
# Epoch 15/100
#  - 2s - loss: 3.5860 - mean_squared_error: 0.3278 - val_loss: 3.5459 - val_mean_squared_error: 0.3214
# Epoch 16/100
#  - 2s - loss: 3.5333 - mean_squared_error: 0.3214 - val_loss: 3.5657 - val_mean_squared_error: 0.3271
# Epoch 17/100
#  - 2s - loss: 3.4195 - mean_squared_error: 0.3117 - val_loss: 3.5246 - val_mean_squared_error: 0.3341
# Epoch 18/100
#  - 2s - loss: 3.5165 - mean_squared_error: 0.3183 - val_loss: 3.5508 - val_mean_squared_error: 0.3204
# Epoch 19/100
#  - 2s - loss: 3.3951 - mean_squared_error: 0.3044 - val_loss: 3.4373 - val_mean_squared_error: 0.3075
# Epoch 20/100
#  - 2s - loss: 3.3232 - mean_squared_error: 0.2978 - val_loss: 3.4674 - val_mean_squared_error: 0.3206
# Epoch 21/100
#  - 2s - loss: 3.2888 - mean_squared_error: 0.2942 - val_loss: 3.3827 - val_mean_squared_error: 0.3160
# Epoch 22/100
#  - 2s - loss: 3.3567 - mean_squared_error: 0.3001 - val_loss: 3.5606 - val_mean_squared_error: 0.3275
# Epoch 23/100
#  - 2s - loss: 3.2970 - mean_squared_error: 0.2922 - val_loss: 3.4113 - val_mean_squared_error: 0.3056
# Epoch 24/100
#  - 2s - loss: 3.2581 - mean_squared_error: 0.2875 - val_loss: 3.3455 - val_mean_squared_error: 0.2989
# Epoch 25/100
#  - 2s - loss: 3.1798 - mean_squared_error: 0.2802 - val_loss: 3.6447 - val_mean_squared_error: 0.3412
# Epoch 26/100
#  - 2s - loss: 3.1960 - mean_squared_error: 0.2793 - val_loss: 3.3850 - val_mean_squared_error: 0.3099
# Epoch 27/100
#  - 2s - loss: 3.2018 - mean_squared_error: 0.2801 - val_loss: 3.5017 - val_mean_squared_error: 0.3169
# Epoch 28/100
#  - 2s - loss: 3.2527 - mean_squared_error: 0.2814 - val_loss: 3.6535 - val_mean_squared_error: 0.3306
# Epoch 29/100
#  - 2s - loss: 3.1868 - mean_squared_error: 0.2727 - val_loss: 3.3568 - val_mean_squared_error: 0.2969
# Epoch 30/100
#  - 2s - loss: 3.1316 - mean_squared_error: 0.2704 - val_loss: 3.3717 - val_mean_squared_error: 0.3131
# Epoch 31/100
#  - 2s - loss: 3.1442 - mean_squared_error: 0.2722 - val_loss: 3.3252 - val_mean_squared_error: 0.2978
# Epoch 32/100
#  - 2s - loss: 3.1150 - mean_squared_error: 0.2674 - val_loss: 3.3607 - val_mean_squared_error: 0.3054
# Epoch 33/100
#  - 2s - loss: 3.1072 - mean_squared_error: 0.2685 - val_loss: 3.4514 - val_mean_squared_error: 0.3054
# Epoch 34/100
#  - 2s - loss: 3.0870 - mean_squared_error: 0.2604 - val_loss: 3.4165 - val_mean_squared_error: 0.3058
# Epoch 35/100
#  - 2s - loss: 3.1096 - mean_squared_error: 0.2653 - val_loss: 3.4464 - val_mean_squared_error: 0.3036
# Epoch 36/100
#  - 2s - loss: 3.0615 - mean_squared_error: 0.2619 - val_loss: 3.3025 - val_mean_squared_error: 0.2937
# Epoch 37/100
#  - 2s - loss: 3.0842 - mean_squared_error: 0.2626 - val_loss: 3.3887 - val_mean_squared_error: 0.2925
# Epoch 38/100
#  - 2s - loss: 3.0152 - mean_squared_error: 0.2556 - val_loss: 3.3704 - val_mean_squared_error: 0.2969
# Epoch 39/100
#  - 2s - loss: 3.0512 - mean_squared_error: 0.2567 - val_loss: 3.3240 - val_mean_squared_error: 0.2965
# Epoch 40/100
#  - 2s - loss: 3.0559 - mean_squared_error: 0.2580 - val_loss: 3.3524 - val_mean_squared_error: 0.2949
# Epoch 41/100
#  - 2s - loss: 2.9924 - mean_squared_error: 0.2514 - val_loss: 3.3529 - val_mean_squared_error: 0.3002
# Epoch 42/100
#  - 2s - loss: 3.0414 - mean_squared_error: 0.2545 - val_loss: 3.3815 - val_mean_squared_error: 0.2964
# Epoch 43/100
#  - 2s - loss: 3.0083 - mean_squared_error: 0.2536 - val_loss: 3.3305 - val_mean_squared_error: 0.2919
# Epoch 44/100
#  - 2s - loss: 3.0021 - mean_squared_error: 0.2502 - val_loss: 3.3330 - val_mean_squared_error: 0.2982
# Epoch 45/100
#  - 2s - loss: 2.9230 - mean_squared_error: 0.2450 - val_loss: 3.2755 - val_mean_squared_error: 0.2922
# Epoch 46/100
#  - 2s - loss: 2.9523 - mean_squared_error: 0.2477 - val_loss: 3.3670 - val_mean_squared_error: 0.2987
# Epoch 47/100
#  - 2s - loss: 2.9042 - mean_squared_error: 0.2407 - val_loss: 3.4350 - val_mean_squared_error: 0.3157
# Epoch 48/100
#  - 2s - loss: 2.9688 - mean_squared_error: 0.2503 - val_loss: 3.3414 - val_mean_squared_error: 0.2802
# Epoch 49/100
#  - 2s - loss: 2.9893 - mean_squared_error: 0.2473 - val_loss: 3.4306 - val_mean_squared_error: 0.3015
# Epoch 50/100
#  - 2s - loss: 2.8797 - mean_squared_error: 0.2399 - val_loss: 3.3319 - val_mean_squared_error: 0.3012
# Epoch 51/100
#  - 2s - loss: 2.9297 - mean_squared_error: 0.2453 - val_loss: 3.3883 - val_mean_squared_error: 0.3053
# Epoch 52/100
#  - 2s - loss: 2.9203 - mean_squared_error: 0.2427 - val_loss: 3.2949 - val_mean_squared_error: 0.2891
# Epoch 53/100
#  - 2s - loss: 2.9079 - mean_squared_error: 0.2414 - val_loss: 3.5172 - val_mean_squared_error: 0.3145
# Epoch 54/100
#  - 2s - loss: 2.9367 - mean_squared_error: 0.2421 - val_loss: 3.3905 - val_mean_squared_error: 0.3030
# Epoch 55/100
#  - 2s - loss: 2.9147 - mean_squared_error: 0.2419 - val_loss: 3.4928 - val_mean_squared_error: 0.3116
# Epoch 1/55
#  - 11s - loss: 6.7017 - mean_squared_error: 0.8001
# Epoch 2/55
#  - 3s - loss: 5.0809 - mean_squared_error: 0.5702
# Epoch 3/55
#  - 3s - loss: 4.3863 - mean_squared_error: 0.4527
# Epoch 4/55
#  - 2s - loss: 4.2436 - mean_squared_error: 0.4207
# Epoch 5/55
#  - 3s - loss: 4.0662 - mean_squared_error: 0.3882
# Epoch 6/55
#  - 3s - loss: 3.9764 - mean_squared_error: 0.3784
# Epoch 7/55
#  - 3s - loss: 3.9663 - mean_squared_error: 0.3763
# Epoch 8/55
#  - 3s - loss: 3.7461 - mean_squared_error: 0.3508
# Epoch 9/55
#  - 3s - loss: 3.7466 - mean_squared_error: 0.3465
# Epoch 10/55
#  - 3s - loss: 3.6843 - mean_squared_error: 0.3342
# Epoch 11/55
#  - 3s - loss: 3.5370 - mean_squared_error: 0.3214
# Epoch 12/55
#  - 3s - loss: 3.5225 - mean_squared_error: 0.3214
# Epoch 13/55
#  - 3s - loss: 3.4843 - mean_squared_error: 0.3146
# Epoch 14/55
#  - 3s - loss: 3.4237 - mean_squared_error: 0.3064
# Epoch 15/55
#  - 3s - loss: 3.4024 - mean_squared_error: 0.3029
# Epoch 16/55
#  - 3s - loss: 3.4076 - mean_squared_error: 0.3006
# Epoch 17/55
#  - 3s - loss: 3.2979 - mean_squared_error: 0.2908
# Epoch 18/55
#  - 3s - loss: 3.2819 - mean_squared_error: 0.2894
# Epoch 19/55
#  - 2s - loss: 3.2683 - mean_squared_error: 0.2835
# Epoch 20/55
#  - 3s - loss: 3.2709 - mean_squared_error: 0.2816
# Epoch 21/55
#  - 3s - loss: 3.2705 - mean_squared_error: 0.2791
# Epoch 22/55
#  - 3s - loss: 3.2315 - mean_squared_error: 0.2794
# Epoch 23/55
#  - 3s - loss: 3.1720 - mean_squared_error: 0.2706
# Epoch 24/55
#  - 3s - loss: 3.1316 - mean_squared_error: 0.2715
# Epoch 25/55
#  - 3s - loss: 3.1500 - mean_squared_error: 0.2703
# Epoch 26/55
#  - 3s - loss: 3.0757 - mean_squared_error: 0.2664
# Epoch 27/55
#  - 3s - loss: 3.0574 - mean_squared_error: 0.2622
# Epoch 28/55
#  - 3s - loss: 3.0585 - mean_squared_error: 0.2625
# Epoch 29/55
#  - 3s - loss: 3.1053 - mean_squared_error: 0.2636
# Epoch 30/55
#  - 3s - loss: 3.0501 - mean_squared_error: 0.2572
# Epoch 31/55
#  - 3s - loss: 3.0591 - mean_squared_error: 0.2604
# Epoch 32/55
#  - 3s - loss: 3.1108 - mean_squared_error: 0.2604
# Epoch 33/55
#  - 3s - loss: 3.1203 - mean_squared_error: 0.2605
# Epoch 34/55
#  - 3s - loss: 3.0050 - mean_squared_error: 0.2531
# Epoch 35/55
#  - 3s - loss: 3.0342 - mean_squared_error: 0.2560
# Epoch 36/55
#  - 3s - loss: 2.9704 - mean_squared_error: 0.2527
# Epoch 37/55
#  - 3s - loss: 2.9949 - mean_squared_error: 0.2521
# Epoch 38/55
#  - 3s - loss: 2.9868 - mean_squared_error: 0.2497
# Epoch 39/55
#  - 3s - loss: 3.0236 - mean_squared_error: 0.2529
# Epoch 40/55
#  - 3s - loss: 2.9750 - mean_squared_error: 0.2477
# Epoch 41/55
#  - 3s - loss: 2.9946 - mean_squared_error: 0.2466
# Epoch 42/55
#  - 3s - loss: 2.9860 - mean_squared_error: 0.2500
# Epoch 43/55
#  - 2s - loss: 2.9961 - mean_squared_error: 0.2456
# Epoch 44/55
#  - 2s - loss: 2.9376 - mean_squared_error: 0.2414
# Epoch 45/55
#  - 3s - loss: 2.9276 - mean_squared_error: 0.2471
# Epoch 46/55
#  - 3s - loss: 2.9091 - mean_squared_error: 0.2437
# Epoch 47/55
#  - 3s - loss: 2.9219 - mean_squared_error: 0.2414
# Epoch 48/55
#  - 3s - loss: 2.9090 - mean_squared_error: 0.2400
# Epoch 49/55
#  - 3s - loss: 2.9079 - mean_squared_error: 0.2413
# Epoch 50/55
#  - 3s - loss: 2.9274 - mean_squared_error: 0.2407
# Epoch 51/55
#  - 3s - loss: 2.8826 - mean_squared_error: 0.2375
# Epoch 52/55
#  - 3s - loss: 2.9083 - mean_squared_error: 0.2406
# Epoch 53/55
#  - 3s - loss: 2.8904 - mean_squared_error: 0.2368
# Epoch 54/55
#  - 3s - loss: 2.8994 - mean_squared_error: 0.2408
# Epoch 55/55
#  - 3s - loss: 2.9108 - mean_squared_error: 0.2362
# Train on 22350 samples, validate on 5588 samples
# Epoch 1/100
#  - 11s - loss: 6.9304 - mean_squared_error: 0.8368 - val_loss: 5.5206 - val_mean_squared_error: 0.6485
# Epoch 2/100
#  - 2s - loss: 5.2153 - mean_squared_error: 0.6037 - val_loss: 4.8317 - val_mean_squared_error: 0.5422
# Epoch 3/100
#  - 2s - loss: 4.6552 - mean_squared_error: 0.5117 - val_loss: 4.4856 - val_mean_squared_error: 0.4824
# Epoch 4/100
#  - 2s - loss: 4.4446 - mean_squared_error: 0.4675 - val_loss: 4.2050 - val_mean_squared_error: 0.4399
# Epoch 5/100
#  - 2s - loss: 4.2840 - mean_squared_error: 0.4490 - val_loss: 4.2564 - val_mean_squared_error: 0.4464
# Epoch 6/100
#  - 2s - loss: 4.2317 - mean_squared_error: 0.4317 - val_loss: 3.9838 - val_mean_squared_error: 0.3938
# Epoch 7/100
#  - 2s - loss: 4.0624 - mean_squared_error: 0.4024 - val_loss: 4.1094 - val_mean_squared_error: 0.4082
# Epoch 8/100
#  - 2s - loss: 4.0026 - mean_squared_error: 0.3885 - val_loss: 4.0934 - val_mean_squared_error: 0.4017
# Epoch 9/100
#  - 2s - loss: 3.9187 - mean_squared_error: 0.3769 - val_loss: 3.9260 - val_mean_squared_error: 0.3741
# Epoch 10/100
#  - 2s - loss: 3.8091 - mean_squared_error: 0.3620 - val_loss: 3.9369 - val_mean_squared_error: 0.3786
# Epoch 11/100
#  - 2s - loss: 3.8559 - mean_squared_error: 0.3623 - val_loss: 3.9590 - val_mean_squared_error: 0.3596
# Epoch 12/100
#  - 2s - loss: 3.6639 - mean_squared_error: 0.3442 - val_loss: 3.9397 - val_mean_squared_error: 0.3670
# Epoch 13/100
#  - 2s - loss: 3.6610 - mean_squared_error: 0.3386 - val_loss: 3.5150 - val_mean_squared_error: 0.3146
# Epoch 14/100
#  - 2s - loss: 3.5283 - mean_squared_error: 0.3262 - val_loss: 3.5983 - val_mean_squared_error: 0.3300
# Epoch 15/100
#  - 2s - loss: 3.4982 - mean_squared_error: 0.3204 - val_loss: 3.5555 - val_mean_squared_error: 0.3254
# Epoch 16/100
#  - 2s - loss: 3.4627 - mean_squared_error: 0.3113 - val_loss: 3.5369 - val_mean_squared_error: 0.3333
# Epoch 17/100
#  - 2s - loss: 3.4052 - mean_squared_error: 0.3065 - val_loss: 3.6161 - val_mean_squared_error: 0.3343
# Epoch 18/100
#  - 2s - loss: 3.4063 - mean_squared_error: 0.3023 - val_loss: 3.4407 - val_mean_squared_error: 0.3093
# Epoch 19/100
#  - 2s - loss: 3.3446 - mean_squared_error: 0.2953 - val_loss: 3.5373 - val_mean_squared_error: 0.3239
# Epoch 20/100
#  - 2s - loss: 3.3125 - mean_squared_error: 0.2907 - val_loss: 3.5388 - val_mean_squared_error: 0.3304
# Epoch 21/100
#  - 2s - loss: 3.2326 - mean_squared_error: 0.2888 - val_loss: 3.5785 - val_mean_squared_error: 0.3296
# Epoch 22/100
#  - 2s - loss: 3.2034 - mean_squared_error: 0.2824 - val_loss: 3.3077 - val_mean_squared_error: 0.2984
# Epoch 23/100
#  - 2s - loss: 3.2120 - mean_squared_error: 0.2824 - val_loss: 3.3777 - val_mean_squared_error: 0.2982
# Epoch 24/100
#  - 2s - loss: 3.1543 - mean_squared_error: 0.2763 - val_loss: 3.3572 - val_mean_squared_error: 0.2988
# Epoch 25/100
#  - 2s - loss: 3.1441 - mean_squared_error: 0.2721 - val_loss: 3.3866 - val_mean_squared_error: 0.3057
# Epoch 26/100
#  - 2s - loss: 3.1148 - mean_squared_error: 0.2723 - val_loss: 3.5007 - val_mean_squared_error: 0.3118
# Epoch 27/100
#  - 2s - loss: 3.0809 - mean_squared_error: 0.2650 - val_loss: 3.3905 - val_mean_squared_error: 0.3106
# Epoch 28/100
#  - 2s - loss: 3.0916 - mean_squared_error: 0.2678 - val_loss: 3.3123 - val_mean_squared_error: 0.2931
# Epoch 29/100
#  - 2s - loss: 3.1134 - mean_squared_error: 0.2662 - val_loss: 3.3861 - val_mean_squared_error: 0.3059
# Epoch 30/100
#  - 2s - loss: 3.1258 - mean_squared_error: 0.2652 - val_loss: 3.3337 - val_mean_squared_error: 0.2970
# Epoch 31/100
#  - 2s - loss: 3.0454 - mean_squared_error: 0.2625 - val_loss: 3.4172 - val_mean_squared_error: 0.3060
# Epoch 32/100
#  - 2s - loss: 3.1253 - mean_squared_error: 0.2637 - val_loss: 3.4118 - val_mean_squared_error: 0.3003
# Epoch 1/32
#  - 10s - loss: 6.7250 - mean_squared_error: 0.8038
# Epoch 2/32
#  - 3s - loss: 5.0540 - mean_squared_error: 0.5544
# Epoch 3/32
#  - 3s - loss: 4.3767 - mean_squared_error: 0.4391
# Epoch 4/32
#  - 3s - loss: 4.2489 - mean_squared_error: 0.4155
# Epoch 5/32
#  - 3s - loss: 4.1558 - mean_squared_error: 0.4006
# Epoch 6/32
#  - 3s - loss: 4.1263 - mean_squared_error: 0.3913
# Epoch 7/32
#  - 2s - loss: 4.0224 - mean_squared_error: 0.3824
# Epoch 8/32
#  - 3s - loss: 3.8575 - mean_squared_error: 0.3693
# Epoch 9/32
#  - 3s - loss: 3.8948 - mean_squared_error: 0.3641
# Epoch 10/32
#  - 2s - loss: 3.7867 - mean_squared_error: 0.3525
# Epoch 11/32
#  - 3s - loss: 3.7619 - mean_squared_error: 0.3485
# Epoch 12/32
#  - 3s - loss: 3.6551 - mean_squared_error: 0.3329
# Epoch 13/32
#  - 3s - loss: 3.6007 - mean_squared_error: 0.3253
# Epoch 14/32
#  - 3s - loss: 3.5263 - mean_squared_error: 0.3145
# Epoch 15/32
#  - 3s - loss: 3.5075 - mean_squared_error: 0.3112
# Epoch 16/32
#  - 3s - loss: 3.4494 - mean_squared_error: 0.3076
# Epoch 17/32
#  - 3s - loss: 3.4633 - mean_squared_error: 0.3063
# Epoch 18/32
#  - 3s - loss: 3.3722 - mean_squared_error: 0.2962
# Epoch 19/32
#  - 3s - loss: 3.3663 - mean_squared_error: 0.2957
# Epoch 20/32
#  - 3s - loss: 3.3003 - mean_squared_error: 0.2873
# Epoch 21/32
#  - 3s - loss: 3.2470 - mean_squared_error: 0.2835
# Epoch 22/32
#  - 3s - loss: 3.2820 - mean_squared_error: 0.2838
# Epoch 23/32
#  - 3s - loss: 3.2308 - mean_squared_error: 0.2778
# Epoch 24/32
#  - 3s - loss: 3.2027 - mean_squared_error: 0.2762
# Epoch 25/32
#  - 3s - loss: 3.2111 - mean_squared_error: 0.2707
# Epoch 26/32
#  - 3s - loss: 3.1878 - mean_squared_error: 0.2739
# Epoch 27/32
#  - 3s - loss: 3.1881 - mean_squared_error: 0.2699
# Epoch 28/32
#  - 3s - loss: 3.1123 - mean_squared_error: 0.2643
# Epoch 29/32
#  - 3s - loss: 3.1473 - mean_squared_error: 0.2654
# Epoch 30/32
#  - 3s - loss: 3.0881 - mean_squared_error: 0.2658
# Epoch 31/32
#  - 3s - loss: 3.1026 - mean_squared_error: 0.2631
# Epoch 32/32
#  - 3s - loss: 3.0831 - mean_squared_error: 0.2604
# Train on 22350 samples, validate on 5588 samples
# Epoch 1/100
#  - 13s - loss: 6.9240 - mean_squared_error: 0.8363 - val_loss: 5.6605 - val_mean_squared_error: 0.6483
# Epoch 2/100
#  - 2s - loss: 5.1984 - mean_squared_error: 0.5753 - val_loss: 5.0994 - val_mean_squared_error: 0.5695
# Epoch 3/100
#  - 2s - loss: 4.6164 - mean_squared_error: 0.4872 - val_loss: 4.4829 - val_mean_squared_error: 0.4532
# Epoch 4/100
#  - 2s - loss: 4.3303 - mean_squared_error: 0.4306 - val_loss: 4.3037 - val_mean_squared_error: 0.4262
# Epoch 5/100
#  - 2s - loss: 4.2205 - mean_squared_error: 0.4101 - val_loss: 3.9821 - val_mean_squared_error: 0.3899
# Epoch 6/100
#  - 2s - loss: 4.0888 - mean_squared_error: 0.3949 - val_loss: 4.1676 - val_mean_squared_error: 0.4111
# Epoch 7/100
#  - 2s - loss: 4.0841 - mean_squared_error: 0.3915 - val_loss: 4.0728 - val_mean_squared_error: 0.3822
# Epoch 8/100
#  - 2s - loss: 3.9603 - mean_squared_error: 0.3782 - val_loss: 3.9176 - val_mean_squared_error: 0.3646
# Epoch 9/100
#  - 2s - loss: 3.9808 - mean_squared_error: 0.3734 - val_loss: 3.9686 - val_mean_squared_error: 0.3796
# Epoch 10/100
#  - 2s - loss: 3.8212 - mean_squared_error: 0.3632 - val_loss: 3.9226 - val_mean_squared_error: 0.3736
# Epoch 11/100
#  - 2s - loss: 3.9386 - mean_squared_error: 0.3641 - val_loss: 3.7496 - val_mean_squared_error: 0.3576
# Epoch 12/100
#  - 2s - loss: 3.7949 - mean_squared_error: 0.3542 - val_loss: 3.7507 - val_mean_squared_error: 0.3448
# Epoch 13/100
#  - 2s - loss: 3.7516 - mean_squared_error: 0.3429 - val_loss: 3.9277 - val_mean_squared_error: 0.3709
# Epoch 14/100
#  - 2s - loss: 3.7634 - mean_squared_error: 0.3440 - val_loss: 3.6806 - val_mean_squared_error: 0.3265
# Epoch 15/100
#  - 2s - loss: 3.5917 - mean_squared_error: 0.3256 - val_loss: 3.8754 - val_mean_squared_error: 0.3558
# Epoch 16/100
#  - 2s - loss: 3.5956 - mean_squared_error: 0.3228 - val_loss: 3.6973 - val_mean_squared_error: 0.3423
# Epoch 17/100
#  - 2s - loss: 3.5077 - mean_squared_error: 0.3105 - val_loss: 3.5635 - val_mean_squared_error: 0.3309
# Epoch 18/100
#  - 2s - loss: 3.4773 - mean_squared_error: 0.3084 - val_loss: 3.5143 - val_mean_squared_error: 0.3078
# Epoch 19/100
#  - 2s - loss: 3.3901 - mean_squared_error: 0.3000 - val_loss: 3.4855 - val_mean_squared_error: 0.3016
# Epoch 20/100
#  - 2s - loss: 3.3407 - mean_squared_error: 0.2928 - val_loss: 3.5490 - val_mean_squared_error: 0.3260
# Epoch 21/100
#  - 2s - loss: 3.3182 - mean_squared_error: 0.2905 - val_loss: 3.6229 - val_mean_squared_error: 0.3340
# Epoch 22/100
#  - 2s - loss: 3.3573 - mean_squared_error: 0.2949 - val_loss: 3.5175 - val_mean_squared_error: 0.3063
# Epoch 23/100
#  - 2s - loss: 3.3430 - mean_squared_error: 0.2849 - val_loss: 3.4386 - val_mean_squared_error: 0.3051
# Epoch 24/100
#  - 2s - loss: 3.3418 - mean_squared_error: 0.2877 - val_loss: 3.5592 - val_mean_squared_error: 0.3103
# Epoch 25/100
#  - 2s - loss: 3.1521 - mean_squared_error: 0.2726 - val_loss: 3.6252 - val_mean_squared_error: 0.3365
# Epoch 26/100
#  - 2s - loss: 3.2361 - mean_squared_error: 0.2781 - val_loss: 3.3463 - val_mean_squared_error: 0.2971
# Epoch 27/100
#  - 2s - loss: 3.1759 - mean_squared_error: 0.2755 - val_loss: 3.4651 - val_mean_squared_error: 0.3082
# Epoch 28/100
#  - 2s - loss: 3.2130 - mean_squared_error: 0.2733 - val_loss: 3.3867 - val_mean_squared_error: 0.2955
# Epoch 29/100
#  - 2s - loss: 3.1320 - mean_squared_error: 0.2674 - val_loss: 3.4207 - val_mean_squared_error: 0.2994
# Epoch 30/100
#  - 2s - loss: 3.1374 - mean_squared_error: 0.2666 - val_loss: 3.3286 - val_mean_squared_error: 0.3049
# Epoch 31/100
#  - 2s - loss: 3.1145 - mean_squared_error: 0.2680 - val_loss: 3.3688 - val_mean_squared_error: 0.2961
# Epoch 32/100
#  - 2s - loss: 3.1187 - mean_squared_error: 0.2638 - val_loss: 3.4759 - val_mean_squared_error: 0.3149
# Epoch 33/100
#  - 2s - loss: 3.0631 - mean_squared_error: 0.2593 - val_loss: 3.4038 - val_mean_squared_error: 0.3107
# Epoch 34/100
#  - 2s - loss: 3.1238 - mean_squared_error: 0.2666 - val_loss: 3.5826 - val_mean_squared_error: 0.3208
# Epoch 35/100
#  - 2s - loss: 3.1189 - mean_squared_error: 0.2630 - val_loss: 3.5214 - val_mean_squared_error: 0.3059
# Epoch 36/100
#  - 2s - loss: 3.0129 - mean_squared_error: 0.2533 - val_loss: 3.6522 - val_mean_squared_error: 0.3424
# Epoch 37/100
#  - 2s - loss: 3.0768 - mean_squared_error: 0.2589 - val_loss: 3.4241 - val_mean_squared_error: 0.3015
# Epoch 38/100
#  - 2s - loss: 3.0041 - mean_squared_error: 0.2514 - val_loss: 3.4628 - val_mean_squared_error: 0.3101
# Epoch 39/100
#  - 2s - loss: 3.0766 - mean_squared_error: 0.2561 - val_loss: 3.3708 - val_mean_squared_error: 0.2971
# Epoch 40/100
#  - 2s - loss: 3.0243 - mean_squared_error: 0.2539 - val_loss: 3.4407 - val_mean_squared_error: 0.3041
# Epoch 1/40
#  - 11s - loss: 6.7298 - mean_squared_error: 0.8137
# Epoch 2/40
#  - 3s - loss: 4.8180 - mean_squared_error: 0.5227
# Epoch 3/40
#  - 3s - loss: 4.3252 - mean_squared_error: 0.4269
# Epoch 4/40
#  - 3s - loss: 4.1432 - mean_squared_error: 0.4002
# Epoch 5/40
#  - 3s - loss: 4.1081 - mean_squared_error: 0.3939
# Epoch 6/40
#  - 3s - loss: 4.0327 - mean_squared_error: 0.3833
# Epoch 7/40
#  - 3s - loss: 3.9491 - mean_squared_error: 0.3696
# Epoch 8/40
#  - 3s - loss: 3.8237 - mean_squared_error: 0.3567
# Epoch 9/40
#  - 3s - loss: 3.7097 - mean_squared_error: 0.3445
# Epoch 10/40
#  - 3s - loss: 3.7140 - mean_squared_error: 0.3417
# Epoch 11/40
#  - 3s - loss: 3.6702 - mean_squared_error: 0.3346
# Epoch 12/40
#  - 3s - loss: 3.5697 - mean_squared_error: 0.3235
# Epoch 13/40
#  - 3s - loss: 3.6037 - mean_squared_error: 0.3197
# Epoch 14/40
#  - 3s - loss: 3.5117 - mean_squared_error: 0.3108
# Epoch 15/40
#  - 3s - loss: 3.4707 - mean_squared_error: 0.3069
# Epoch 16/40
#  - 3s - loss: 3.4306 - mean_squared_error: 0.3017
# Epoch 17/40
#  - 2s - loss: 3.3820 - mean_squared_error: 0.2932
# Epoch 18/40
#  - 3s - loss: 3.2978 - mean_squared_error: 0.2905
# Epoch 19/40
#  - 3s - loss: 3.2604 - mean_squared_error: 0.2823
# Epoch 20/40
#  - 3s - loss: 3.2385 - mean_squared_error: 0.2830
# Epoch 21/40
#  - 3s - loss: 3.3056 - mean_squared_error: 0.2858
# Epoch 22/40
#  - 3s - loss: 3.1821 - mean_squared_error: 0.2756
# Epoch 23/40
#  - 3s - loss: 3.1766 - mean_squared_error: 0.2753
# Epoch 24/40
#  - 2s - loss: 3.1968 - mean_squared_error: 0.2771
# Epoch 25/40
#  - 3s - loss: 3.2134 - mean_squared_error: 0.2729
# Epoch 26/40
#  - 2s - loss: 3.1710 - mean_squared_error: 0.2706
# Epoch 27/40
#  - 3s - loss: 3.1653 - mean_squared_error: 0.2690
# Epoch 28/40
#  - 3s - loss: 3.1387 - mean_squared_error: 0.2658
# Epoch 29/40
#  - 3s - loss: 3.2097 - mean_squared_error: 0.2728
# Epoch 30/40
#  - 3s - loss: 3.0960 - mean_squared_error: 0.2618
# Epoch 31/40
#  - 3s - loss: 3.0632 - mean_squared_error: 0.2597
# Epoch 32/40
#  - 3s - loss: 3.1026 - mean_squared_error: 0.2615
# Epoch 33/40
#  - 3s - loss: 3.0393 - mean_squared_error: 0.2565
# Epoch 34/40
#  - 3s - loss: 3.0394 - mean_squared_error: 0.2580
# Epoch 35/40
#  - 3s - loss: 3.0303 - mean_squared_error: 0.2577
# Epoch 36/40
#  - 2s - loss: 3.0060 - mean_squared_error: 0.2529
# Epoch 37/40
#  - 3s - loss: 3.0593 - mean_squared_error: 0.2585
# Epoch 38/40
#  - 2s - loss: 3.0200 - mean_squared_error: 0.2532
# Epoch 39/40
#  - 3s - loss: 2.9763 - mean_squared_error: 0.2515
# Epoch 40/40
#  - 3s - loss: 2.9746 - mean_squared_error: 0.2478
# Train on 22350 samples, validate on 5588 samples
# Epoch 1/100
#  - 12s - loss: 6.8839 - mean_squared_error: 0.8281 - val_loss: 5.4858 - val_mean_squared_error: 0.6267
# Epoch 2/100
#  - 2s - loss: 5.1893 - mean_squared_error: 0.5755 - val_loss: 4.7995 - val_mean_squared_error: 0.5236
# Epoch 3/100
#  - 2s - loss: 4.6839 - mean_squared_error: 0.4950 - val_loss: 4.5278 - val_mean_squared_error: 0.4618
# Epoch 4/100
#  - 2s - loss: 4.3108 - mean_squared_error: 0.4331 - val_loss: 4.3042 - val_mean_squared_error: 0.4459
# Epoch 5/100
#  - 2s - loss: 4.2338 - mean_squared_error: 0.4168 - val_loss: 3.8871 - val_mean_squared_error: 0.3850
# Epoch 6/100
#  - 2s - loss: 4.1778 - mean_squared_error: 0.4030 - val_loss: 3.9864 - val_mean_squared_error: 0.3853
# Epoch 7/100
#  - 2s - loss: 4.0709 - mean_squared_error: 0.3898 - val_loss: 3.8386 - val_mean_squared_error: 0.3580
# Epoch 8/100
#  - 2s - loss: 4.0221 - mean_squared_error: 0.3839 - val_loss: 3.8771 - val_mean_squared_error: 0.3707
# Epoch 9/100
#  - 2s - loss: 4.0298 - mean_squared_error: 0.3823 - val_loss: 3.9390 - val_mean_squared_error: 0.3759
# Epoch 10/100
#  - 2s - loss: 3.8511 - mean_squared_error: 0.3613 - val_loss: 3.7573 - val_mean_squared_error: 0.3544
# Epoch 11/100
#  - 2s - loss: 3.7723 - mean_squared_error: 0.3531 - val_loss: 3.8573 - val_mean_squared_error: 0.3681
# Epoch 12/100
#  - 2s - loss: 3.7359 - mean_squared_error: 0.3477 - val_loss: 3.8111 - val_mean_squared_error: 0.3512
# Epoch 13/100
# ...
# Epoch 6/100
#  - 2s - loss: 4.1442 - mean_squared_error: 0.3986 - val_loss: 4.2125 - val_mean_squared_error: 0.4088
# Epoch 7/100
#  - 2s - loss: 4.1572 - mean_squared_error: 0.4000 - val_loss: 4.0699 - val_mean_squared_error: 0.3828
# Epoch 8/100
#  - 2s - loss: 4.0276 - mean_squared_error: 0.3796 - val_loss: 3.9134 - val_mean_squared_error: 0.3636
# Epoch 9/100
#  - 2s - loss: 3.9759 - mean_squared_error: 0.3738 - val_loss: 3.9134 - val_mean_squared_error: 0.3738
# Epoch 10/100
#  - 2s - loss: 3.9234 - mean_squared_error: 0.3685 - val_loss: 3.9250 - val_mean_squared_error: 0.3716
# Epoch 11/100
#  - 2s - loss: 3.9326 - mean_squared_error: 0.3652 - val_loss: 3.9007 - val_mean_squared_error: 0.3563
# Epoch 12/100
#  - 2s - loss: 3.8501 - mean_squared_error: 0.3545 - val_loss: 3.7935 - val_mean_squared_error: 0.3509
# Epoch 13/100
#  - 2s - loss: 3.7537 - mean_squared_error: 0.3445 - val_loss: 3.7540 - val_mean_squared_error: 0.3596
# Epoch 14/100
#  - 2s - loss: 3.7912 - mean_squared_error: 0.3485 - val_loss: 3.7077 - val_mean_squared_error: 0.3302
# Epoch 15/100
#  - 2s - loss: 3.7018 - mean_squared_error: 0.3344 - val_loss: 4.2230 - val_mean_squared_error: 0.3971
# Epoch 16/100
#  - 2s - loss: 3.6409 - mean_squared_error: 0.3289 - val_loss: 3.7290 - val_mean_squared_error: 0.3415
# Epoch 17/100
#  - 2s - loss: 3.6040 - mean_squared_error: 0.3207 - val_loss: 3.9664 - val_mean_squared_error: 0.3549
# Epoch 18/100
#  - 2s - loss: 3.5470 - mean_squared_error: 0.3144 - val_loss: 3.6365 - val_mean_squared_error: 0.3178
# Epoch 19/100
#  - 2s - loss: 3.4622 - mean_squared_error: 0.3037 - val_loss: 3.4920 - val_mean_squared_error: 0.3167
# Epoch 20/100
#  - 2s - loss: 3.3793 - mean_squared_error: 0.3027 - val_loss: 3.4747 - val_mean_squared_error: 0.3164
# Epoch 21/100
#  - 2s - loss: 3.3654 - mean_squared_error: 0.2982 - val_loss: 3.4539 - val_mean_squared_error: 0.3132
# Epoch 22/100
#  - 2s - loss: 3.3050 - mean_squared_error: 0.2917 - val_loss: 3.3746 - val_mean_squared_error: 0.3020
# Epoch 23/100
#  - 2s - loss: 3.3105 - mean_squared_error: 0.2886 - val_loss: 3.4268 - val_mean_squared_error: 0.3027
# Epoch 24/100
#  - 2s - loss: 3.2679 - mean_squared_error: 0.2843 - val_loss: 3.3905 - val_mean_squared_error: 0.3019
# Epoch 25/100
#  - 2s - loss: 3.2365 - mean_squared_error: 0.2807 - val_loss: 3.4961 - val_mean_squared_error: 0.3041
# Epoch 26/100
#  - 2s - loss: 3.2298 - mean_squared_error: 0.2789 - val_loss: 3.5280 - val_mean_squared_error: 0.3141
# Epoch 27/100
#  - 2s - loss: 3.1892 - mean_squared_error: 0.2722 - val_loss: 3.5551 - val_mean_squared_error: 0.3216
# Epoch 28/100
#  - 2s - loss: 3.2507 - mean_squared_error: 0.2740 - val_loss: 3.4470 - val_mean_squared_error: 0.3104
# Epoch 29/100
#  - 2s - loss: 3.1802 - mean_squared_error: 0.2719 - val_loss: 3.3428 - val_mean_squared_error: 0.2928
# Epoch 30/100
#  - 2s - loss: 3.1442 - mean_squared_error: 0.2674 - val_loss: 3.3930 - val_mean_squared_error: 0.3024
# Epoch 31/100
#  - 2s - loss: 3.1491 - mean_squared_error: 0.2661 - val_loss: 3.3288 - val_mean_squared_error: 0.2995
# Epoch 32/100
#  - 2s - loss: 3.1296 - mean_squared_error: 0.2676 - val_loss: 3.4414 - val_mean_squared_error: 0.3021
# Epoch 33/100
#  - 2s - loss: 3.1538 - mean_squared_error: 0.2647 - val_loss: 3.5386 - val_mean_squared_error: 0.2986
# Epoch 34/100
#  - 2s - loss: 3.0753 - mean_squared_error: 0.2564 - val_loss: 3.3984 - val_mean_squared_error: 0.3027
# Epoch 35/100
#  - 2s - loss: 3.0898 - mean_squared_error: 0.2581 - val_loss: 3.4158 - val_mean_squared_error: 0.3004
# Epoch 36/100
#  - 2s - loss: 3.0082 - mean_squared_error: 0.2534 - val_loss: 3.4104 - val_mean_squared_error: 0.2999
# Epoch 37/100
#  - 2s - loss: 3.0630 - mean_squared_error: 0.2549 - val_loss: 3.4715 - val_mean_squared_error: 0.3126
# Epoch 38/100
#  - 2s - loss: 3.0670 - mean_squared_error: 0.2552 - val_loss: 3.4239 - val_mean_squared_error: 0.2989
# Epoch 39/100
#  - 2s - loss: 3.0249 - mean_squared_error: 0.2535 - val_loss: 3.4318 - val_mean_squared_error: 0.2876
# Epoch 40/100
#  - 2s - loss: 3.0646 - mean_squared_error: 0.2526 - val_loss: 3.3128 - val_mean_squared_error: 0.2889
# Epoch 41/100
#  - 2s - loss: 2.9834 - mean_squared_error: 0.2486 - val_loss: 3.3393 - val_mean_squared_error: 0.2914
# Epoch 42/100
#  - 2s - loss: 3.0793 - mean_squared_error: 0.2523 - val_loss: 3.2996 - val_mean_squared_error: 0.2860
# Epoch 43/100
#  - 2s - loss: 3.0350 - mean_squared_error: 0.2501 - val_loss: 3.3408 - val_mean_squared_error: 0.2862
# Epoch 44/100
#  - 2s - loss: 2.9025 - mean_squared_error: 0.2417 - val_loss: 3.5020 - val_mean_squared_error: 0.3247
# Epoch 45/100
#  - 2s - loss: 2.9768 - mean_squared_error: 0.2488 - val_loss: 3.3384 - val_mean_squared_error: 0.3012
# Epoch 46/100
#  - 2s - loss: 3.0093 - mean_squared_error: 0.2470 - val_loss: 3.3720 - val_mean_squared_error: 0.3011
# Epoch 47/100
#  - 2s - loss: 2.9568 - mean_squared_error: 0.2435 - val_loss: 3.4277 - val_mean_squared_error: 0.3024
# Epoch 48/100
#  - 2s - loss: 2.9775 - mean_squared_error: 0.2414 - val_loss: 3.3953 - val_mean_squared_error: 0.3073
# Epoch 49/100
#  - 2s - loss: 3.0371 - mean_squared_error: 0.2504 - val_loss: 3.5049 - val_mean_squared_error: 0.3046
# Epoch 50/100
#  - 2s - loss: 2.8744 - mean_squared_error: 0.2361 - val_loss: 3.3944 - val_mean_squared_error: 0.3039
# Epoch 51/100
#  - 2s - loss: 2.9373 - mean_squared_error: 0.2411 - val_loss: 3.5019 - val_mean_squared_error: 0.3072
# Epoch 52/100
#  - 2s - loss: 2.9876 - mean_squared_error: 0.2407 - val_loss: 3.5606 - val_mean_squared_error: 0.3133
# Epoch 1/52
#  - 12s - loss: 6.5897 - mean_squared_error: 0.7885
# Epoch 2/52
#  - 3s - loss: 4.9907 - mean_squared_error: 0.5541
# Epoch 3/52
#  - 3s - loss: 4.5564 - mean_squared_error: 0.4662
# Epoch 4/52
#  - 3s - loss: 4.3980 - mean_squared_error: 0.4353
# Epoch 5/52
#  - 3s - loss: 4.1416 - mean_squared_error: 0.4037
# Epoch 6/52
#  - 3s - loss: 4.0348 - mean_squared_error: 0.3872
# Epoch 7/52
#  - 3s - loss: 3.9959 - mean_squared_error: 0.3853
# Epoch 8/52
#  - 3s - loss: 3.9225 - mean_squared_error: 0.3716
# Epoch 9/52
#  - 3s - loss: 3.8808 - mean_squared_error: 0.3621
# Epoch 10/52
#  - 3s - loss: 3.7994 - mean_squared_error: 0.3543
# Epoch 11/52
#  - 3s - loss: 3.7534 - mean_squared_error: 0.3495
# Epoch 12/52
#  - 3s - loss: 3.6247 - mean_squared_error: 0.3334
# Epoch 13/52
#  - 3s - loss: 3.5602 - mean_squared_error: 0.3225
# Epoch 14/52
#  - 3s - loss: 3.5479 - mean_squared_error: 0.3218
# Epoch 15/52
#  - 3s - loss: 3.5136 - mean_squared_error: 0.3165
# Epoch 16/52
#  - 3s - loss: 3.4188 - mean_squared_error: 0.3061
# Epoch 17/52
#  - 3s - loss: 3.4252 - mean_squared_error: 0.3027
# Epoch 18/52
#  - 3s - loss: 3.4354 - mean_squared_error: 0.3014
# Epoch 19/52
#  - 3s - loss: 3.3727 - mean_squared_error: 0.2980
# Epoch 20/52
#  - 3s - loss: 3.3282 - mean_squared_error: 0.2910
# Epoch 21/52
#  - 3s - loss: 3.2651 - mean_squared_error: 0.2847
# Epoch 22/52
#  - 3s - loss: 3.2507 - mean_squared_error: 0.2824
# Epoch 23/52
#  - 3s - loss: 3.2221 - mean_squared_error: 0.2804
# Epoch 24/52
#  - 3s - loss: 3.2100 - mean_squared_error: 0.2757
# Epoch 25/52
#  - 3s - loss: 3.1837 - mean_squared_error: 0.2725
# Epoch 26/52
#  - 3s - loss: 3.1784 - mean_squared_error: 0.2739
# Epoch 27/52
#  - 3s - loss: 3.1116 - mean_squared_error: 0.2671
# Epoch 28/52
#  - 3s - loss: 3.1445 - mean_squared_error: 0.2704
# Epoch 29/52
#  - 3s - loss: 3.1213 - mean_squared_error: 0.2649
# Epoch 30/52
#  - 3s - loss: 3.0967 - mean_squared_error: 0.2628
# Epoch 31/52
#  - 3s - loss: 3.0850 - mean_squared_error: 0.2641
# Epoch 32/52
#  - 3s - loss: 3.1419 - mean_squared_error: 0.2660
# Epoch 33/52
#  - 3s - loss: 3.0352 - mean_squared_error: 0.2560
# Epoch 34/52
#  - 3s - loss: 3.0744 - mean_squared_error: 0.2592
# Epoch 35/52
#  - 3s - loss: 3.1044 - mean_squared_error: 0.2593
# Epoch 36/52
#  - 3s - loss: 3.0771 - mean_squared_error: 0.2555
# Epoch 37/52
#  - 3s - loss: 3.0634 - mean_squared_error: 0.2565
# Epoch 38/52
#  - 3s - loss: 3.0603 - mean_squared_error: 0.2561
# Epoch 39/52
#  - 3s - loss: 3.0534 - mean_squared_error: 0.2545
# Epoch 40/52
#  - 3s - loss: 2.9881 - mean_squared_error: 0.2469
# Epoch 41/52
#  - 3s - loss: 3.0333 - mean_squared_error: 0.2556
# Epoch 42/52
#  - 3s - loss: 2.9997 - mean_squared_error: 0.2482
# Epoch 43/52
#  - 3s - loss: 2.9965 - mean_squared_error: 0.2486
# Epoch 44/52
#  - 3s - loss: 2.9898 - mean_squared_error: 0.2460
# Epoch 45/52
#  - 3s - loss: 2.9952 - mean_squared_error: 0.2471
# Epoch 46/52
#  - 3s - loss: 2.9722 - mean_squared_error: 0.2434
# Epoch 47/52
#  - 3s - loss: 2.9625 - mean_squared_error: 0.2472
# Epoch 48/52
#  - 3s - loss: 3.0108 - mean_squared_error: 0.2470
# Epoch 49/52
#  - 3s - loss: 2.9451 - mean_squared_error: 0.2427
# Epoch 50/52
#  - 3s - loss: 2.9261 - mean_squared_error: 0.2396
# Epoch 51/52
#  - 3s - loss: 2.9795 - mean_squared_error: 0.2438
# Epoch 52/52
#  - 3s - loss: 2.9024 - mean_squared_error: 0.2406
# Train on 22350 samples, validate on 5588 samples
# Epoch 1/100
#  - 14s - loss: 7.0046 - mean_squared_error: 0.8464 - val_loss: 6.1184 - val_mean_squared_error: 0.7151
# Epoch 2/100
#  - 2s - loss: 5.3588 - mean_squared_error: 0.6160 - val_loss: 5.1786 - val_mean_squared_error: 0.5812
# Epoch 3/100
#  - 2s - loss: 4.6129 - mean_squared_error: 0.5020 - val_loss: 4.5581 - val_mean_squared_error: 0.4847
# Epoch 4/100
#  - 2s - loss: 4.4860 - mean_squared_error: 0.4627 - val_loss: 4.2628 - val_mean_squared_error: 0.4284
# Epoch 5/100
#  - 2s - loss: 4.2068 - mean_squared_error: 0.4206 - val_loss: 4.1328 - val_mean_squared_error: 0.4105
# Epoch 6/100
#  - 2s - loss: 4.1089 - mean_squared_error: 0.4040 - val_loss: 4.1051 - val_mean_squared_error: 0.4005
# Epoch 7/100
#  - 2s - loss: 4.0090 - mean_squared_error: 0.3879 - val_loss: 4.0235 - val_mean_squared_error: 0.3871
# Epoch 8/100
#  - 2s - loss: 4.0168 - mean_squared_error: 0.3844 - val_loss: 3.9362 - val_mean_squared_error: 0.3803
# Epoch 9/100
#  - 2s - loss: 3.9694 - mean_squared_error: 0.3781 - val_loss: 4.0106 - val_mean_squared_error: 0.3769
# Epoch 10/100
#  - 2s - loss: 3.9119 - mean_squared_error: 0.3734 - val_loss: 3.8965 - val_mean_squared_error: 0.3616
# Epoch 11/100
#  - 2s - loss: 3.8926 - mean_squared_error: 0.3654 - val_loss: 4.0655 - val_mean_squared_error: 0.3877
# Epoch 12/100
#  - 2s - loss: 3.8067 - mean_squared_error: 0.3575 - val_loss: 3.8406 - val_mean_squared_error: 0.3693
# Epoch 13/100
#  - 2s - loss: 3.7053 - mean_squared_error: 0.3501 - val_loss: 3.6712 - val_mean_squared_error: 0.3471
# Epoch 14/100
#  - 2s - loss: 3.6718 - mean_squared_error: 0.3439 - val_loss: 3.8064 - val_mean_squared_error: 0.3608
# Epoch 15/100
#  - 2s - loss: 3.6785 - mean_squared_error: 0.3368 - val_loss: 3.6136 - val_mean_squared_error: 0.3353
# Epoch 16/100
#  - 2s - loss: 3.5956 - mean_squared_error: 0.3276 - val_loss: 3.8956 - val_mean_squared_error: 0.3625
# Epoch 17/100
#  - 2s - loss: 3.6351 - mean_squared_error: 0.3264 - val_loss: 3.6237 - val_mean_squared_error: 0.3317
# Epoch 18/100
#  - 2s - loss: 3.4560 - mean_squared_error: 0.3155 - val_loss: 3.6560 - val_mean_squared_error: 0.3259
# Epoch 19/100
#  - 2s - loss: 3.4722 - mean_squared_error: 0.3119 - val_loss: 3.6554 - val_mean_squared_error: 0.3352
# Epoch 20/100
#  - 2s - loss: 3.4306 - mean_squared_error: 0.3042 - val_loss: 3.5653 - val_mean_squared_error: 0.3286
# Epoch 21/100
#  - 2s - loss: 3.3569 - mean_squared_error: 0.2995 - val_loss: 3.4267 - val_mean_squared_error: 0.3100
# Epoch 22/100
#  - 2s - loss: 3.3798 - mean_squared_error: 0.2987 - val_loss: 3.4933 - val_mean_squared_error: 0.3099
# Epoch 23/100
#  - 2s - loss: 3.3294 - mean_squared_error: 0.2955 - val_loss: 3.5162 - val_mean_squared_error: 0.3096
# Epoch 24/100
#  - 2s - loss: 3.2713 - mean_squared_error: 0.2858 - val_loss: 3.4564 - val_mean_squared_error: 0.3079
# Epoch 25/100
#  - 2s - loss: 3.2983 - mean_squared_error: 0.2884 - val_loss: 3.5213 - val_mean_squared_error: 0.3099
# Epoch 26/100
#  - 2s - loss: 3.2291 - mean_squared_error: 0.2798 - val_loss: 3.5660 - val_mean_squared_error: 0.3310
# Epoch 27/100
#  - 2s - loss: 3.2375 - mean_squared_error: 0.2799 - val_loss: 3.5437 - val_mean_squared_error: 0.3192
# Epoch 28/100
#  - 2s - loss: 3.1907 - mean_squared_error: 0.2740 - val_loss: 3.5065 - val_mean_squared_error: 0.3183
# Epoch 29/100
#  - 2s - loss: 3.1476 - mean_squared_error: 0.2717 - val_loss: 3.4223 - val_mean_squared_error: 0.3163
# Epoch 30/100
#  - 2s - loss: 3.1859 - mean_squared_error: 0.2763 - val_loss: 3.5691 - val_mean_squared_error: 0.3225
# Epoch 31/100
#  - 2s - loss: 3.1177 - mean_squared_error: 0.2666 - val_loss: 3.2683 - val_mean_squared_error: 0.2890
# Epoch 32/100
#  - 2s - loss: 3.1171 - mean_squared_error: 0.2669 - val_loss: 3.3118 - val_mean_squared_error: 0.2913
# Epoch 33/100
#  - 2s - loss: 3.0734 - mean_squared_error: 0.2623 - val_loss: 3.3516 - val_mean_squared_error: 0.2940
# Epoch 34/100
#  - 2s - loss: 3.0929 - mean_squared_error: 0.2644 - val_loss: 3.5468 - val_mean_squared_error: 0.3226
# Epoch 35/100
#  - 2s - loss: 3.0955 - mean_squared_error: 0.2615 - val_loss: 3.3059 - val_mean_squared_error: 0.2832
# Epoch 36/100
#  - 2s - loss: 3.0686 - mean_squared_error: 0.2591 - val_loss: 3.3586 - val_mean_squared_error: 0.3019
# Epoch 37/100
#  - 2s - loss: 3.0550 - mean_squared_error: 0.2617 - val_loss: 3.3706 - val_mean_squared_error: 0.2977
# Epoch 38/100
#  - 2s - loss: 2.9971 - mean_squared_error: 0.2541 - val_loss: 3.4283 - val_mean_squared_error: 0.3180
# Epoch 39/100
#  - 2s - loss: 3.0432 - mean_squared_error: 0.2584 - val_loss: 3.4638 - val_mean_squared_error: 0.3112
# Epoch 40/100
#  - 2s - loss: 3.0298 - mean_squared_error: 0.2559 - val_loss: 3.3719 - val_mean_squared_error: 0.2909
# Epoch 41/100
#  - 2s - loss: 3.0299 - mean_squared_error: 0.2524 - val_loss: 3.3170 - val_mean_squared_error: 0.2922
# Epoch 1/41
#  - 14s - loss: 7.0293 - mean_squared_error: 0.8580
# Epoch 2/41
#  - 3s - loss: 5.1202 - mean_squared_error: 0.5748
# Epoch 3/41
#  - 3s - loss: 4.6314 - mean_squared_error: 0.4849
# Epoch 4/41
#  - 3s - loss: 4.2033 - mean_squared_error: 0.4214
# Epoch 5/41
#  - 3s - loss: 4.1187 - mean_squared_error: 0.4012
# Epoch 6/41
#  - 3s - loss: 3.9989 - mean_squared_error: 0.3824
# Epoch 7/41
#  - 3s - loss: 4.0207 - mean_squared_error: 0.3822
# Epoch 8/41
#  - 3s - loss: 3.8951 - mean_squared_error: 0.3667
# Epoch 9/41
#  - 3s - loss: 3.8134 - mean_squared_error: 0.3537
# Epoch 10/41
#  - 3s - loss: 3.7335 - mean_squared_error: 0.3442
# Epoch 11/41
#  - 3s - loss: 3.6631 - mean_squared_error: 0.3351
# Epoch 12/41
#  - 3s - loss: 3.6195 - mean_squared_error: 0.3277
# Epoch 13/41
#  - 3s - loss: 3.5391 - mean_squared_error: 0.3143
# Epoch 14/41
#  - 3s - loss: 3.4529 - mean_squared_error: 0.3082
# Epoch 15/41
#  - 3s - loss: 3.3971 - mean_squared_error: 0.2998
# Epoch 16/41
#  - 3s - loss: 3.3836 - mean_squared_error: 0.2971
# Epoch 17/41
#  - 3s - loss: 3.3859 - mean_squared_error: 0.3014
# Epoch 18/41
#  - 3s - loss: 3.3357 - mean_squared_error: 0.2937
# Epoch 19/41
#  - 3s - loss: 3.3426 - mean_squared_error: 0.2918
# Epoch 20/41
#  - 3s - loss: 3.2449 - mean_squared_error: 0.2819
# Epoch 21/41
#  - 3s - loss: 3.2657 - mean_squared_error: 0.2829
# Epoch 22/41
#  - 3s - loss: 3.1841 - mean_squared_error: 0.2754
# Epoch 23/41
#  - 3s - loss: 3.2088 - mean_squared_error: 0.2757
# Epoch 24/41
#  - 3s - loss: 3.1470 - mean_squared_error: 0.2705
# Epoch 25/41
#  - 3s - loss: 3.1624 - mean_squared_error: 0.2719
# Epoch 26/41
#  - 3s - loss: 3.1340 - mean_squared_error: 0.2676
# Epoch 27/41
#  - 3s - loss: 3.1477 - mean_squared_error: 0.2694
# Epoch 28/41
#  - 3s - loss: 3.1498 - mean_squared_error: 0.2662
# Epoch 29/41
#  - 3s - loss: 3.0828 - mean_squared_error: 0.2598
# Epoch 30/41
#  - 3s - loss: 3.0884 - mean_squared_error: 0.2624
# Epoch 31/41
#  - 3s - loss: 3.1490 - mean_squared_error: 0.2649
# Epoch 32/41
#  - 3s - loss: 3.0752 - mean_squared_error: 0.2606
# Epoch 33/41
#  - 3s - loss: 3.0526 - mean_squared_error: 0.2595
# Epoch 34/41
#  - 3s - loss: 3.0252 - mean_squared_error: 0.2553
# Epoch 35/41
#  - 3s - loss: 3.0304 - mean_squared_error: 0.2546
# Epoch 36/41
#  - 3s - loss: 3.0493 - mean_squared_error: 0.2538
# Epoch 37/41
#  - 3s - loss: 3.0461 - mean_squared_error: 0.2539
# Epoch 38/41
#  - 3s - loss: 2.9779 - mean_squared_error: 0.2486
# Epoch 39/41
#  - 3s - loss: 3.0257 - mean_squared_error: 0.2510
# Epoch 40/41
#  - 3s - loss: 3.0245 - mean_squared_error: 0.2543
# Epoch 41/41
#  - 3s - loss: 2.9803 - mean_squared_error: 0.2487

# %%
mapping = {
    "calcine_temp": 0,
    "sinter_temp": 1,
    "anneal_temp": 2,
    "dry_temp": 3,
    "calcine_time": 4,
    "sinter_time": 5,
    "anneal_time": 6,
    "dry_time": 7
}
results = []
for key in mapping:
    i = mapping[key]
    maes, rmses, mres, r2s = [], [], [], []
    contained, pred_contained = [], []
    for fold in range(10):
        y_pred = np.mean(y_pred_test[fold], axis=1)
        y_true = np.vstack([np.mean(x['temp_time_vector'], axis=0) for x in y_test_k[fold]])
        rmses.append(mean_squared_error(y_true[:, i], y_pred[:, i], squared=False))
        maes.append(mean_absolute_error(y_true[:, i], y_pred[:, i]))
        mres.append(np.mean((np.abs(y_true[:, i]-y_pred[:, i])/y_true[:, i])*100))
        r2s.append(r2_score(y_true[:, i], y_pred[:, i]))
        
        num_contained = 0
        num_pred_contained = 0
        num_pred = 0
        true_vals = [x['temp_time_vector'] for x in y_test_k[fold]]
        for ind in range(y_true.shape[0]):
            if min(y_pred_test[fold][ind, :, i]) <= y_true[ind][i] <= max(y_pred_test[fold][ind, :, i]):
                num_contained += 1
            if len(true_vals[ind]) > 5:
                exp_min = min(np.vstack(true_vals[ind])[:, i])
                exp_max = max(np.vstack(true_vals[ind])[:, i])
                num_pred += 1
                if exp_min <= y_pred[ind, i] <= exp_max:
                    num_pred_contained += 1
                    
        pred_contained.append(num_pred_contained / num_pred)
        contained.append(num_contained / y_true.shape[0])
                   
    result = {
        "objective": key,
        "model": "CVAE",
        "featurization": "PCA",
        "MAE": str(np.mean(maes)),
        "MAE_std": str(np.std(maes)),
        "RMSE": str(np.mean(rmses)),
        "RMSE_std": str(np.std(rmses)),
        "MRE": str(np.mean(mres)),
        "MRE_std": str(np.std(mres)),
        "R2": str(np.mean(r2s)),
        "R2_std": str(np.std(r2s)),
        "Percent_exp_means_contained": str(np.mean(contained) * 100),
        "Percent_exp_means_contained_std": str(np.std(contained) * 100),
        "Percent_pred_means_contained": str(np.mean(pred_contained) * 100),
        "Percent_pred_means_contained_std": str(np.std(pred_contained) * 100)
    }
    results.append(result)

# %%
results
# Out:
# [{'objective': 'calcine_temp',
#   'model': 'CVAE',
#   'featurization': 'PCA',
#   'MAE': '120.7849837589007',
#   'MAE_std': '2.8716770110044108',
#   'RMSE': '162.86135210918928',
#   'RMSE_std': '2.518832815313463',
#   'MRE': '14.465894214214208',
#   'MRE_std': '0.4874248231249989',
#   'R2': '0.487982553013757',
#   'R2_std': '0.017390772168171243',
#   'Percent_exp_means_contained': '62.77753207391853',
#   'Percent_exp_means_contained_std': '4.579632397616285',
#   'Percent_pred_means_contained': '96.66233766233766',
#   'Percent_pred_means_contained_std': '5.247155057264257'},
#  {'objective': 'sinter_temp',
#   'model': 'CVAE',
#   'featurization': 'PCA',
#   'MAE': '115.97275766113373',
#   'MAE_std': '2.243014879910936',
#   'RMSE': '158.3833678237741',
#   'RMSE_std': '2.6937494195667915',
#   'MRE': '12.181855510522846',
#   'MRE_std': '0.6187637905599901',
#   'R2': '0.655172651708513',
#   'R2_std': '0.007171192925364303',
#   'Percent_exp_means_contained': '72.72934027728715',
#   'Percent_exp_means_contained_std': '7.666347030095524',
#   'Percent_pred_means_contained': '98.09090909090908',
#   'Percent_pred_means_contained_std': '3.8235892445114708'},
#  {'objective': 'anneal_temp',
#   'model': 'CVAE',
#   'featurization': 'PCA',
#   'MAE': '213.13009013866468',
#   'MAE_std': '4.915786608890329',
#   'RMSE': '268.82559453064175',
#   'RMSE_std': '5.9809292885121215',
#   'MRE': '43.12313395730149',
#   'MRE_std': '4.400005190913198',
#   'R2': '0.21413012093713268',
#   'R2_std': '0.022009052085349305',
#   'Percent_exp_means_contained': '97.66193086578012',
#   'Percent_exp_means_contained_std': '1.8489086525030167',
#   'Percent_pred_means_contained': '93.87662337662339',
#   'Percent_pred_means_contained_std': '5.531092530120139'},
#  {'objective': 'dry_temp',
#   'model': 'CVAE',
#   'featurization': 'PCA',
#   'MAE': '174.46887015666755',
#   'MAE_std': '2.4990102767603357',
#   'RMSE': '219.61749411679025',
#   'RMSE_std': '2.2919927427200055',
#   'MRE': '434.753623760776',
#   'MRE_std': '43.144685010436625',
#   'R2': '0.033475505987405826',
#   'R2_std': '0.016964703564839218',
#   'Percent_exp_means_contained': '97.53747887581135',
#   'Percent_exp_means_contained_std': '1.959684593836016',
#   'Percent_pred_means_contained': '97.22222222222221',
#   'Percent_pred_means_contained_std': '5.692750425533109'},
#  {'objective': 'calcine_time',
#   'model': 'CVAE',
#   'featurization': 'PCA',
#   'MAE': '6.642044297380433',
#   'MAE_std': '0.21071466768978112',
#   'RMSE': '9.49206654300448',
#   'RMSE_std': '0.2740826156122665',
#   'MRE': '133.10992835477242',
#   'MRE_std': '10.018133319380976',
#   'R2': '0.09429814484541264',
#   'R2_std': '0.007775025026523894',
#   'Percent_exp_means_contained': '89.91692647926153',
#   'Percent_exp_means_contained_std': '3.314409940763443',
#   'Percent_pred_means_contained': '92.73376623376623',
#   'Percent_pred_means_contained_std': '9.045506340045774'},
#  {'objective': 'sinter_time',
#   'model': 'CVAE',
#   'featurization': 'PCA',
#   'MAE': '9.178446962787442',
#   'MAE_std': '0.19639264973780457',
#   'RMSE': '13.05257269424142',
#   'RMSE_std': '0.3922884285911948',
#   'MRE': '184.07079254484478',
#   'MRE_std': '10.723238463228622',
#   'R2': '0.1640451503382378',
#   'R2_std': '0.023141090589550727',
#   'Percent_exp_means_contained': '95.04639692644791',
#   'Percent_exp_means_contained_std': '3.1954626551941687',
#   'Percent_pred_means_contained': '92.13419913419914',
#   'Percent_pred_means_contained_std': '7.200321128332946'},
#  {'objective': 'anneal_time',
#   'model': 'CVAE',
#   'featurization': 'PCA',
#   'MAE': '13.282442902671027',
#   'MAE_std': '0.2218097047005212',
#   'RMSE': '17.221346358700814',
#   'RMSE_std': '0.27646412959835315',
#   'MRE': '298.04344734741437',
#   'MRE_std': '21.584424388278972',
#   'R2': '0.08937528152128207',
#   'R2_std': '0.014004361621059414',
#   'Percent_exp_means_contained': '95.04745491831403',
#   'Percent_exp_means_contained_std': '4.065490734050208',
#   'Percent_pred_means_contained': '91.34126984126985',
#   'Percent_pred_means_contained_std': '14.471301127107175'},
#  {'objective': 'dry_time',
#   'model': 'CVAE',
#   'featurization': 'PCA',
#   'MAE': '7.027571627395403',
#   'MAE_std': '0.12624500554836932',
#   'RMSE': '8.836218475856242',
#   'RMSE_std': '0.126894177179466',
#   'MRE': '132.61341642200006',
#   'MRE_std': '8.827506056783886',
#   'R2': '0.01898823463843563',
#   'R2_std': '0.016972619882847352',
#   'Percent_exp_means_contained': '94.99717366014796',
#   'Percent_exp_means_contained_std': '2.396197328350719',
#   'Percent_pred_means_contained': '94.92424242424242',
#   'Percent_pred_means_contained_std': '10.027796537505761'}]

# %%
temp = np.vstack([np.mean(x['temp_time_vector'], axis=0) for x in y_test_k[fold]])
true_scatter = []
for i in range(500, 800):
    mean = np.mean(y_pred_test[fold][i, :, 5])
    # sns.kdeplot(y_pred_test[fold][i, :, 1] - mean, color = (0.1, 0.3, 0.5, 0.15))
    sns.kdeplot(y_pred_test[fold][i, :, 5])
    true_scatter.append(temp[i][1] - mean)
# for i in range(100):
#      plt.axvline(x=true_scatter[i], color='r', linewidth=2, alpha=0.1)

# %%
np.vstack([x['temp_time_vector'] for x in y_test_k[fold]][5])[:, 1]
# Out:
# array([1000., 1250.])
